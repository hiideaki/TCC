# %%
import pickle as pkl
import seaborn as sns
import matplotlib.pyplot as plt
import re
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import math
import dateutil

from tqdm import tqdm_notebook
from collections import Counter
from glob import glob
from unidecode import unidecode
from nltk.corpus import stopwords
from datetime import datetime

import utils

# %matplotlib inline

sns.set(style="darkgrid")

# %%
PATH = '../'

PROCESSED_DATA_PATH = os.path.join(PATH, 'data/processed/')

DF_USP_PATH = os.path.join(PROCESSED_DATA_PATH, 'df_usp_clean.pkl')
DF_USP_TRUNCATED_PATH = os.path.join(PROCESSED_DATA_PATH, 'df_usp_truncated_clean.pkl')


STOPWORDS = utils.get_stopwords()

CLASS_DICT = {
    0: 'Notícias verdadeiras',
    1: 'Notícias falsas'
}

# %%
df_trunc = pkl.load(open(DF_USP_TRUNCATED_PATH, 'rb'))

# %%
df = pkl.load(open(DF_USP_PATH, 'rb'))

# %%
df
# Out:
#                                                    TEXT  FAKE  \
# 0     Kátia Abreu diz que vai colocar sua expulsão e...     1
# 1     Alckmin diz que por ele PSDB desembarca, mas...     1
# 2     Cara de pau não tem limites: Zé Celso aciona M...     1
# 3     Temer resolve o problema de Luislinda: liberd...     1
# 4     Moro está certo ao não se arrepender de divulg...     1
# 5     Hoje completou um ano da morte de um dos psico...     1
# 6     Palocci vai contar que Lula pagou propina a ex...     1
# 7     Dr. Ray peita Bolsonaro, chama-o de conservad...     1
# 8     Garotinho ganha prêmio após teatro sobre surr...     1
# 9     Dilma finge solidariedade a Katia Abreu mas nã...     1
# 10    Gilmar Mendes age como masoquista ao permitir ...     1
# 11    Raquel Dodge faz o que Janot não fazia: pediu ...     1
# 12    Garotinho se supera no teatro ao chutar parede...     1
# 13    Kátia Abreu conseguiu a proeza de ter uma biog...     1
# 14    Joesley chorou ao entrar na cela e está sem co...     1
# 15    O partido mais corrupto do Brasil não é o PT. ...     1
# 16    Malafaia chama eleitores de Bolsonaro de gays ...     1
# 17    Bolsonaro vai militarizar todas as escolas do ...     1
# 18    Maria do Rosário pode tirar Bolsonaro da dispu...     1
# 19    O próximo presidente será de centro-direita,...     1
# 20    Marido de Dilma acaba de morrer. Será que mata...     1
# 21    Sobrinho atira no tio após galinhas comerem se...     1
# 22    Temer está articulando a candidatura de Dória ...     1
# 23    Deputada Maria do Rosário é intimada pelo STF ...     1
# 24    Ciro Gomes ataca Bolsonaro, Dória, Dilma e Lul...     1
# 25    João Dória está deixando o PSDB, saiba qual se...     1
# 26    Movimento Ovos na Cara é a versão atualizada...     1
# 27    Deus mandou votar a favor de Temer, disseram...     1
# 28    Deputada chamada de gostosa no plenário vai pr...     1
# 29    Temer vai punir Sergio Reis e Tiririca por tra...     1
# ...                                                 ...   ...
# 4148  Segunda-feira, 18 de dezembro de 2017. Boa noi...     0
# 4149  Zara Larsson junta dance pop e feminismo: Qual...     0
# 4150  FGTS: Temer anuncia liberação para saque de co...     0
# 4151  Justiça condena advogado a mais de 60 anos de ...     0
# 4152   Em propaganda partidária veiculada anteontem ...     0
# 4153  Quinta-feira, 9 de novembro. Bom dia! Aqui est...     0
# 4154  Não vai parar, diz delegado em BO de junho de ...     0
# 4155  Gerações têm visões distintas de Fidel. Pai, f...     0
# 4156  Líderes dos caminhoneiros grevistas vão a Bras...     0
# 4157  O avanço de Kim. Por um grande paradoxo, sançõ...     0
# 4158  Na contramão do setor, construtora de Ribeirão...     0
# 4159  Peritos afirmam que partes importantes da grav...     0
# 4160   Foi para se livrar das pressões de parlamenta...     0
# 4161  Gosto quando dizem que sou caso de marketing: ...     0
# 4162  Aposentado mineiro baleado em protesto contra ...     0
# 4163  Entenda a crise política no Paraguai após apro...     0
# 4164  Não dá para culpar militares se intervenção no...     0
# 4165  Em SP, Obama diz que Coreia do Norte é perigo ...     0
# 4166  Como celulares roubados no carnaval são desblo...     0
# 4167   O duplamente covarde atentado terrorista do E...     0
# 4168  Governo corta R$ 42 bi em gastos e eleva impos...     0
# 4169  Hamas convoca nova intifada após anúncio de Tr...     0
# 4170  PF vê indícios de organização criminosa em inv...     0
# 4171   A defesa de Aécio Neves exigiu que o STF afas...     0
# 4172  Ficou longe das notícias no fim de ano? Veja o...     0
# 4173   A nova denúncia contra o ex-presidente Luiz I...     0
# 4174  Como a Bahia virou uma potência mundial do mar...     0
# 4175  Alvo da Lava Jato, Bendine tinha passagem comp...     0
# 4176  Chefs convidados do Encontro Mundial das Cidad...     0
# 4177   As lições de educação moral e cívica, que o b...     0
#
#                                                     URL  \
# 0     https://ceticismopolitico.com/2017/11/30/katia...
# 1     https://ceticismopolitico.com/2017/11/28/alckm...
# 2     https://ceticismopolitico.com/2017/11/28/cara-...
# 3     https://ceticismopolitico.com/2017/11/27/temer...
# 4     https://ceticismopolitico.com/2017/11/27/moro-...
# 5     https://ceticismopolitico.com/2017/11/25/hoje-...
# 6     https://ceticismopolitico.com/2017/11/25/paloc...
# 7     https://ceticismopolitico.com/2017/11/24/dr-ra...
# 8     https://ceticismopolitico.com/2017/11/24/garot...
# 9     https://ceticismopolitico.com/2017/11/24/dilma...
# 10    https://ceticismopolitico.com/2017/11/24/gilma...
# 11    https://ceticismopolitico.com/2017/11/24/raque...
# 12    https://ceticismopolitico.com/2017/11/24/garot...
# 13    https://ceticismopolitico.com/2017/11/23/advog...
# 14    https://afolhabrasil.com.br/politica/joesley-c...
# 15    https://afolhabrasil.com.br/politica/o-partido...
# 16    https://afolhabrasil.com.br/politica/malafaia-...
# 17    https://afolhabrasil.com.br/politica/bolsonaro...
# 18    https://afolhabrasil.com.br/politica/acabou-ma...
# 19    https://afolhabrasil.com.br/politica/o-proximo...
# 20    https://afolhabrasil.com.br/politica/marido-de...
# 21    https://afolhabrasil.com.br/politica/sobrinho-...
# 22    https://afolhabrasil.com.br/politica/temer-est...
# 23    https://afolhabrasil.com.br/politica/deputada-...
# 24    https://afolhabrasil.com.br/politica/ciro-gome...
# 25    https://afolhabrasil.com.br/politica/joao-dori...
# 26    https://afolhabrasil.com.br/politica/movimento...
# 27    https://afolhabrasil.com.br/politica/deus-mand...
# 28    https://afolhabrasil.com.br/politica/deputada-...
# 29    https://afolhabrasil.com.br/politica/temer-vai...
# ...                                                 ...
# 4148  http://politica.estadao.com.br/blogs/neumanne/...
# 4149  https://g1.globo.com/politica/noticia/corte-es...
# 4150  https://g1.globo.com/resumo-do-dia/noticia/seg...
# 4151  https://g1.globo.com/economia/noticia/temer-an...
# 4152  https://g1.globo.com/sao-paulo/noticia/haddad-...
# 4153  https://g1.globo.com/sp/sorocaba-jundiai/notic...
# 4154  http://politica.estadao.com.br/blogs/neumanne/...
# 4155  https://g1.globo.com/economia/concursos-e-empr...
# 4156  http://internacional.estadao.com.br/noticias/g...
# 4157  http://politica.estadao.com.br/blogs/neumanne/...
# 4158  http://economia.estadao.com.br/noticias/geral,...
# 4159  http://internacional.estadao.com.br/noticias/g...
# 4160  https://g1.globo.com/politica/noticia/lideres-...
# 4161  https://g1.globo.com/rio-de-janeiro/carnaval/2...
# 4162  http://politica.estadao.com.br/blogs/coluna-do...
# 4163  http://politica.estadao.com.br/blogs/neumanne/...
# 4164  https://g1.globo.com/resumo-do-dia/noticia/sex...
# 4165  https://g1.globo.com/resumo-do-dia/noticia/ter...
# 4166  http://economia.estadao.com.br/noticias/geral,...
# 4167  https://g1.globo.com/economia/tecnologia/notic...
# 4168  http://politica.estadao.com.br/blogs/neumanne/...
# 4169  http://politica.estadao.com.br/blogs/neumanne/...
# 4170  https://g1.globo.com/economia/noticia/governo-...
# 4171  https://g1.globo.com/mundo/noticia/hamas-convo...
# 4172  https://g1.globo.com/politica/noticia/pf-ve-in...
# 4173  http://politica.estadao.com.br/blogs/neumanne/...
# 4174  https://g1.globo.com/resumo-do-dia/noticia/fic...
# 4175  http://politica.estadao.com.br/blogs/fausto-ma...
# 4176  https://g1.globo.com/politica/noticia/como-a-b...
# 4177  https://g1.globo.com/pr/parana/noticia/alvo-da...
#
#                           DATE
# 0                   2017-11-30
# 1                   2017-11-28
# 2                   2017-11-28
# 3                   2017-11-27
# 4                   2017-11-27
# 5                   2017-11-25
# 6                   2017-11-25
# 7                   2017-11-24
# 8                   2017-11-24
# 9                   2017-11-24
# 10                  2017-11-24
# 11                  2017-11-24
# 12                  2017-11-24
# 13                  2017-11-23
# 14                  2017-09-11
# 15                  2017-09-08
# 16                  2017-08-29
# 17                  2017-08-28
# 18                  2017-08-15
# 19                  2017-08-12
# 20                  2017-08-12
# 21                  2017-08-11
# 22                  2017-08-11
# 23                  2017-08-10
# 24                  2017-08-10
# 25                  2017-08-09
# 26                  2017-08-08
# 27                  2017-08-06
# 28                  2017-08-05
# 29                  2017-08-04
# ...                        ...
# 4148    23 de outubro de 2017
# 4149         06/12/2017 16h16
# 4150         18/12/2017 19h41
# 4151         22/12/2016 09h34
# 4152         31/12/2016 00h01
# 4153         23/11/2017 09h49
# 4154   30 de novembro de 2017
# 4155         29/03/2018 04h01
# 4156   11 de dezembro de 2016
# 4157   16 de novembro de 2017
# 4158   10 de novembro de 2015
# 4159   17 de setembro de 2017
# 4160         14/01/2017 05h00
# 4161         18/07/2017 06h01
# 4162   25 de novembro de 2017
# 4163   23 de novembro de 2017
# 4164         15/12/2017 19h27
# 4165         26/09/2017 19h40
# 4166   05 de setembro de 2017
# 4167         20/02/2018 18h11
# 4168      26 de junho de 2017
# 4169     18 de agosto de 2017
# 4170         29/03/2017 20h15
# 4171         07/12/2017 06h31
# 4172         11/09/2017 18h52
# 4173    03 de outubro de 2017
# 4174         02/01/2018 06h00
# 4175   09 de dezembro de 2016
# 4176         21/01/2018 09h41
# 4177         27/07/2017 10h49
#
# [4178 rows x 4 columns]

# %%
from googletrans import Translator
translator = Translator()

# %%
date_normalized = []
for i in tqdm_notebook(df['DATE']):
    try:
        date_normalized.append(dateutil.parser.parse(translator.translate(i, src='pt', dest='en').text))
    except:
        date_normalized.append(i)
# Out:
# HBox(children=(IntProgress(value=0, max=4178), HTML(value='')))

# %%
translator.translate('16 de novembro de 2017', src='pt', dest='en')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-20-27a7129f66f5> in <module>
# ----> 1 translator.translate('16 de novembro de 2017', src='pt', dest='en')
#
# D:\Anaconda\lib\site-packages\googletrans\client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# D:\Anaconda\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src)
#      79         r = self.session.get(url, params=params)
#      80
# ---> 81         data = utils.format_json(r.text)
#      82         return data
#      83
#
# D:\Anaconda\lib\site-packages\googletrans\utils.py in format_json(original)
#      60         converted = json.loads(original)
#      61     except ValueError:
# ---> 62         converted = legacy_format_json(original)
#      63
#      64     return converted
#
# D:\Anaconda\lib\site-packages\googletrans\utils.py in legacy_format_json(original)
#      52             text = text[:p] + states[j][1] + text[nxt:]
#      53
# ---> 54     converted = json.loads(text)
#      55     return converted
#      56
#
# D:\Anaconda\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# D:\Anaconda\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# D:\Anaconda\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
news_dates = []
for item in tqdm_notebook(date_normalized):
    try:
        date = dateutil.parser.parse(item)
        news_dates.append('{}/{}'.format(date.month, date.year))
    except:
        translator = Translator()
        print(item)
        aux = dateutil.parser.parse(translator.translate(item, src='pt', dest='en').text)
        print(aux)
        print()
        news_dates.append(aux)
# Out:
# HBox(children=(IntProgress(value=0, max=4178), HTML(value='')))
#  16 de novembro de 2017
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-22-eb4fe3e9c17b> in <module>
#       7         translator = Translator()
#       8         print(item)
# ----> 9         aux = dateutil.parser.parse(translator.translate(item, src='pt', dest='en').text)
#      10         print(aux)
#      11         print()
#
# D:\Anaconda\lib\site-packages\googletrans\client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# D:\Anaconda\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src)
#      79         r = self.session.get(url, params=params)
#      80
# ---> 81         data = utils.format_json(r.text)
#      82         return data
#      83
#
# D:\Anaconda\lib\site-packages\googletrans\utils.py in format_json(original)
#      60         converted = json.loads(original)
#      61     except ValueError:
# ---> 62         converted = legacy_format_json(original)
#      63
#      64     return converted
#
# D:\Anaconda\lib\site-packages\googletrans\utils.py in legacy_format_json(original)
#      52             text = text[:p] + states[j][1] + text[nxt:]
#      53
# ---> 54     converted = json.loads(text)
#      55     return converted
#      56
#
# D:\Anaconda\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# D:\Anaconda\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# D:\Anaconda\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
sites = []
for i, item in df[df['FAKE'] == 1].iterrows():
    sites.append(item['URL'].split('/')[2])

# %%
Counter(sites).most_common()
# Out:
# [('www.diariodobrasil.org', 1879),
#  ('afolhabrasil.com.br', 141),
#  ('www.thejornalbrasil.com.br', 54),
#  ('ceticismopolitico.com', 14),
#  ('www.topfivetv.com', 1)]

# %%
# Contagem para cada fonte

# %%
x = ['G1', 'El País', 'boatos.org']
y = [len(df[df['SOURCE'] == x[0]]),
     len(df[df['SOURCE'] == x[1]]),
     len(df[df['SOURCE'] == x[2]])]

fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.barplot(x, y)
ax.set_ylim(0, 13000)
ax.text(0, y[0] + 50, y[0], fontsize=14, horizontalalignment="center")
ax.text(1, y[1] + 50, y[1], fontsize=14, horizontalalignment="center")
ax.text(2, y[2] + 50, y[2], fontsize=14, horizontalalignment="center")
# ax.set_title("Quantidade de dados de cada fonte", fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SOURCE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-951ccdd5e64a> in <module>
#       1 x = ['G1', 'El País', 'boatos.org']
# ----> 2 y = [len(df[df['SOURCE'] == x[0]]),
#       3      len(df[df['SOURCE'] == x[1]]),
#       4      len(df[df['SOURCE'] == x[2]])]
#       5
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SOURCE'

# %%
x = ['Notícias verdadeiras', 'Notícias falsas']
y = [len(df[df['FAKE'] == 0]),
     len(df[df['FAKE'] == 1])]

fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.barplot(x, y)
ax.set_ylim(0, 2500)
ax.text(0, y[0] + 50, y[0], fontsize=14, horizontalalignment="center")
ax.text(1, y[1] + 50, y[1], fontsize=14, horizontalalignment="center")
# ax.set_title("Quantidade de dados de cada classe", fontsize=16)
# Out:
# Text(1, 2139, '2089')

# %%
print("{:.2f}%".format(min(y) / max(y) * 100))
max(y) / min(y)
# Out:
# 100.00%
# 1.0

# %%
start_date = datetime.strptime('01/2016', '%m/%Y')
end_date = datetime.strptime('01/2019', '%m/%Y')

# %%
df[(df['FAKE'] == 1) & (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) < start_date)].shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MONTH_YEAR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-eaa96ad561f9> in <module>
# ----> 1 df[(df['FAKE'] == 1) & (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) < start_date)].shape
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MONTH_YEAR'

# %%
df[(df['FAKE'] == 1) & (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) > end_date)].shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MONTH_YEAR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-0f424bd85130> in <module>
# ----> 1 df[(df['FAKE'] == 1) & (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) > end_date)].shape
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MONTH_YEAR'

# %%
date_fake = Counter(sorted(df[(df['FAKE'] == 1) &
                              (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) >= start_date) &
                              (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) < end_date)]['MONTH_YEAR'], key=lambda x: datetime.strptime(x, '%m/%Y')))

date_true = Counter(sorted(df[(df['FAKE'] == 0) &
                              (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) >= start_date) &
                              (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) < end_date)]['MONTH_YEAR'], key=lambda x: datetime.strptime(x, '%m/%Y')))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MONTH_YEAR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-d00d0f602920> in <module>
#       1 date_fake = Counter(sorted(df[(df['FAKE'] == 1) &
# ----> 2                               (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) >= start_date) &
#       3                               (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) < end_date)]['MONTH_YEAR'], key=lambda x: datetime.strptime(x, '%m/%Y')))
#       4
#       5 date_true = Counter(sorted(df[(df['FAKE'] == 0) &
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MONTH_YEAR'

# %%
all_dates = sorted(set(date_fake.keys()).union(set(date_true.keys())), key=lambda x: datetime.strptime(x, '%m/%Y'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-28035683a309> in <module>
# ----> 1 all_dates = sorted(set(date_fake.keys()).union(set(date_true.keys())), key=lambda x: datetime.strptime(x, '%m/%Y'))
#
# NameError: name 'date_fake' is not defined

# %%
date_fake_final = {}
date_true_final = {}
for date in all_dates:
    if date not in date_fake:
        date_fake_final[date] = 0
    else:
        date_fake_final[date] = date_fake[date]
        
    
    if date not in date_true:
        date_true_final[date] = 0
    else:
        date_true_final[date] = date_true[date]

# %%
df_date = pd.DataFrame({
    'date': list(date_fake_final.keys()) + list(date_true_final.keys()),
    'count': list(date_fake_final.values()) + list(date_true_final.values()),
    'Tipo de Notícia': len(date_fake_final) * ['Notícias falsas'] + len(date_true_final) * ['Notícias verdadeiras']
})

# %%
df_date
# Out:
#        date  count       Tipo de Notícia
# 0   01/2016      1       Notícias falsas
# 1   02/2016      2       Notícias falsas
# 2   03/2016     34       Notícias falsas
# 3   04/2016     24       Notícias falsas
# 4   05/2016     19       Notícias falsas
# 5   06/2016     13       Notícias falsas
# 6   07/2016      9       Notícias falsas
# 7   08/2016      5       Notícias falsas
# 8   09/2016     19       Notícias falsas
# 9   10/2016     12       Notícias falsas
# 10  11/2016     10       Notícias falsas
# 11  12/2016      6       Notícias falsas
# 12  01/2017     16       Notícias falsas
# 13  02/2017     11       Notícias falsas
# 14  03/2017     11       Notícias falsas
# 15  04/2017     16       Notícias falsas
# 16  05/2017     26       Notícias falsas
# 17  06/2017     14       Notícias falsas
# 18  07/2017     12       Notícias falsas
# 19  08/2017     20       Notícias falsas
# 20  09/2017      5       Notícias falsas
# 21  10/2017      0       Notícias falsas
# 22  11/2017      3       Notícias falsas
# 23  12/2017      2       Notícias falsas
# 24  01/2018      4       Notícias falsas
# 25  02/2018      5       Notícias falsas
# 26  03/2018     14       Notícias falsas
# 27  04/2018     28       Notícias falsas
# 28  05/2018     33       Notícias falsas
# 29  06/2018     14       Notícias falsas
# ..      ...    ...                   ...
# 42  07/2016    190  Notícias verdadeiras
# 43  08/2016    155  Notícias verdadeiras
# 44  09/2016    229  Notícias verdadeiras
# 45  10/2016    222  Notícias verdadeiras
# 46  11/2016    238  Notícias verdadeiras
# 47  12/2016    177  Notícias verdadeiras
# 48  01/2017    169  Notícias verdadeiras
# 49  02/2017    143  Notícias verdadeiras
# 50  03/2017    164  Notícias verdadeiras
# 51  04/2017    205  Notícias verdadeiras
# 52  05/2017    229  Notícias verdadeiras
# 53  06/2017    176  Notícias verdadeiras
# 54  07/2017    155  Notícias verdadeiras
# 55  08/2017    133  Notícias verdadeiras
# 56  09/2017    156  Notícias verdadeiras
# 57  10/2017    206  Notícias verdadeiras
# 58  11/2017    136  Notícias verdadeiras
# 59  12/2017    138  Notícias verdadeiras
# 60  01/2018    124  Notícias verdadeiras
# 61  02/2018    112  Notícias verdadeiras
# 62  03/2018    158  Notícias verdadeiras
# 63  04/2018    149  Notícias verdadeiras
# 64  05/2018    132  Notícias verdadeiras
# 65  06/2018    103  Notícias verdadeiras
# 66  07/2018    121  Notícias verdadeiras
# 67  08/2018    162  Notícias verdadeiras
# 68  09/2018    157  Notícias verdadeiras
# 69  10/2018    250  Notícias verdadeiras
# 70  11/2018    156  Notícias verdadeiras
# 71  12/2018    124  Notícias verdadeiras
#
# [72 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.lineplot(x='date', y='count', hue='Tipo de Notícia', data=df_date, sort=False)

plt.legend(fontsize='x-large')
ax.set_xlabel('Mês e ano', fontsize=24)
ax.set_ylabel('Quantidade de notícias', fontsize=24)

for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    tick.set_fontsize(20)
    tick.set_ha('right')
    

    
for tick in ax.get_yticklabels():
    tick.set_fontsize(20)

# %%
df = df[(df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) >= start_date) &
        (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) < end_date)].reset_index(drop=True)

# %%
x = ['Notícias verdadeiras', 'Notícias falsas']
y = [len(df[df['FAKE'] == 0]),
     len(df[df['FAKE'] == 1])]

fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.barplot(x, y)
ax.set_ylim(0, 18000)
ax.text(0, y[0] + 50, y[0], fontsize=14, horizontalalignment="center")
ax.text(1, y[1] + 50, y[1], fontsize=14, horizontalalignment="center")
# ax.set_title("Quantidade de dados de cada classe", fontsize=16)
# Out:
# Text(1, 665, '615')

# %%
def simple_clean_text(text):
    # Making sure we're dealing with strings and lowering the characters
    text = str(text).lower()
    
    # Stripping accents
    text = unidecode(text)
    
    # Removing characters that aren't alphanumeric
    text = re.sub(r'[^a-zA-Z0-9 ]', ' ', text)
    
    # Removing tokens that intercalate between letters and digits
    text = re.sub(r'\w*([a-zA-Z][0-9]|[0-9][a-zA-Z])\w*', ' ', text)
    
    # Removing digits
    text = re.sub(r'\d', ' ', text)
    
    # Removing tokens with letters that appear more than twice in a row
    text = re.sub(r'\w*([a-zA-Z])\1{2,}\w*', ' ', text)
    
    # Removing extra spaces
    text = re.sub('\s+', ' ', text)
    
    # Removing words with length equal or lower than 2 or are in STOPWORDS
    return ' '.join([token for token in text.split() if len(token) > 2 and token not in STOPWORDS])

# %%
# def simple_clean_text(text):
#     # Making sure we're dealing with strings and lowering the characters
#     text = str(text).lower()
    
#     # Stripping accents
#     text = unidecode(text)
    
#     # Removing characters that aren't alphanumeric
#     text = re.sub(r'[^a-zA-Z0-9 ]', ' ', text)
    
#     # Removing extra spaces
#     text = re.sub('\s+', ' ', text)
    
#     # Removing words with length equal or lower than 2 or are in STOPWORDS
#     return ' '.join([token for token in text.split() if len(token) > 2 and token not in STOPWORDS])

# %%
df['SIMPLE_CLEAN_TEXT'] = df['TEXT'].apply(simple_clean_text)

# %%
all_cnt = {}
for key in tqdm_notebook(CLASS_DICT):
    cnt = Counter()
    for text in tqdm_notebook(df[df['FAKE'] == key]['SIMPLE_CLEAN_TEXT']):
        cnt += Counter(str(text).split())

    all_cnt[key] = cnt.most_common()
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2089), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2089), HTML(value='')))

# %%
all_cnt
# Out:
# {0: [('presidente', 8652),
#   ('lula', 5587),
#   ('disse', 4853),
#   ('federal', 4765),
#   ('sobre', 4500),
#   ('anos', 4437),
#   ('governo', 3933),
#   ('segundo', 3931),
#   ('ainda', 3817),
#   ('temer', 3789),
#   ('brasil', 3263),
#   ('ministro', 3217),
#   ('diz', 2930),
#   ('contra', 2928),
#   ('pais', 2885),
#   ('ano', 2725),
#   ('feira', 2628),
#   ('dia', 2623),
#   ('lava', 2592),
#   ('jato', 2587),
#   ('afirmou', 2566),
#   ('pessoas', 2541),
#   ('justica', 2516),
#   ('apos', 2508),
#   ('caso', 2498),
#   ('pode', 2404),
#   ('publico', 2346),
#   ('defesa', 2289),
#   ('policia', 2288),
#   ('porque', 2252),
#   ('estado', 2245),
#   ('milhoes', 2199),
#   ('ministerio', 2175),
#   ('paulo', 2170),
#   ('acordo', 2153),
#   ('dois', 2145),
#   ('processo', 2118),
#   ('tribunal', 2086),
#   ('dinheiro', 2036),
#   ('decisao', 2032),
#   ('odebrecht', 1961),
#   ('nesta', 1953),
#   ('fazer', 1854),
#   ('rio', 1842),
#   ('dilma', 1822),
#   ('todos', 1815),
#   ('operacao', 1795),
#   ('republica', 1792),
#   ('mil', 1766),
#   ('camara', 1729),
#   ('parte', 1701),
#   ('casa', 1700),
#   ('outros', 1691),
#   ('stf', 1688),
#   ('durante', 1665),
#   ('empresa', 1665),
#   ('prisao', 1664),
#   ('corrupcao', 1654),
#   ('juiz', 1634),
#   ('alem', 1623),
#   ('entao', 1609),
#   ('hoje', 1601),
#   ('desde', 1564),
#   ('politica', 1519),
#   ('qualquer', 1518),
#   ('pmdb', 1505),
#   ('geral', 1493),
#   ('nacional', 1492),
#   ('deputado', 1481),
#   ('denuncia', 1449),
#   ('moro', 1447),
#   ('supremo', 1442),
#   ('onde', 1440),
#   ('grupo', 1434),
#   ('antes', 1412),
#   ('dias', 1398),
#   ('tres', 1391),
#   ('grande', 1386),
#   ('seguranca', 1384),
#   ('agora', 1372),
#   ('vez', 1365),
#   ('acao', 1356),
#   ('primeira', 1353),
#   ('pedido', 1351),
#   ('sido', 1346),
#   ('partido', 1341),
#   ('apenas', 1339),
#   ('segunda', 1327),
#   ('meio', 1313),
#   ('norte', 1312),
#   ('lei', 1305),
#   ('maior', 1305),
#   ('momento', 1300),
#   ('bem', 1282),
#   ('delacao', 1281),
#   ('silva', 1271),
#   ('outro', 1264),
#   ('forma', 1263),
#   ('campanha', 1240),
#   ('senador', 1238),
#   ('gente', 1228),
#   ('conta', 1217),
#   ('havia', 1215),
#   ('afirma', 1193),
#   ('menos', 1191),
#   ('petrobras', 1181),
#   ('tempo', 1174),
#   ('nota', 1170),
#   ('relacao', 1169),
#   ('luiz', 1149),
#   ('trabalho', 1141),
#   ('tudo', 1134),
#   ('crime', 1123),
#   ('michel', 1121),
#   ('fez', 1119),
#   ('primeiro', 1101),
#   ('aqui', 1100),
#   ('poder', 1095),
#   ('mundo', 1081),
#   ('sempre', 1080),
#   ('meses', 1080),
#   ('todo', 1077),
#   ('sergio', 1076),
#   ('senado', 1073),
#   ('nome', 1063),
#   ('psdb', 1057),
#   ('estados', 1057),
#   ('sendo', 1052),
#   ('assim', 1050),
#   ('projeto', 1047),
#   ('filho', 1043),
#   ('publica', 1039),
#   ('familia', 1036),
#   ('recursos', 1035),
#   ('cidade', 1035),
#   ('propina', 1035),
#   ('jose', 1025),
#   ('outras', 1021),
#   ('novo', 1018),
#   ('vida', 1016),
#   ('investigacao', 1015),
#   ('deve', 1014),
#   ('duas', 1007),
#   ('janeiro', 1000),
#   ('julgamento', 1000),
#   ('fim', 996),
#   ('empresas', 977),
#   ('sul', 967),
#   ('politico', 961),
#   ('crimes', 957),
#   ('nunca', 956),
#   ('regiao', 952),
#   ('nova', 942),
#   ('cada', 938),
#   ('advogado', 938),
#   ('direito', 927),
#   ('depoimento', 920),
#   ('eleitoral', 916),
#   ('investigacoes', 914),
#   ('semana', 910),
#   ('desta', 909),
#   ('valor', 905),
#   ('presidencia', 900),
#   ('politicos', 899),
#   ('feito', 898),
#   ('preso', 895),
#   ('deputados', 892),
#   ('governador', 886),
#   ('faz', 886),
#   ('reforma', 886),
#   ('civil', 885),
#   ('passado', 884),
#   ('outra', 875),
#   ('joesley', 873),
#   ('todas', 872),
#   ('aecio', 863),
#   ('alguns', 862),
#   ('fato', 862),
#   ('quarta', 853),
#   ('marco', 849),
#   ('neste', 844),
#   ('mulher', 824),
#   ('joao', 822),
#   ('eduardo', 819),
#   ('dentro', 819),
#   ('final', 807),
#   ('cerca', 805),
#   ('brasilia', 804),
#   ('trump', 796),
#   ('situacao', 794),
#   ('marcelo', 793),
#   ('forca', 788),
#   ('congresso', 787),
#   ('procurador', 786),
#   ('ministros', 785),
#   ('exemplo', 784),
#   ('rodrigo', 784),
#   ('instituto', 783),
#   ('disso', 781),
#   ('quatro', 776),
#   ('diretor', 775),
#   ('terca', 771),
#   ('vezes', 771),
#   ('nada', 763),
#   ('dizer', 763),
#   ('casos', 762),
#   ('inicio', 761),
#   ('chegou', 760),
#   ('militar', 755),
#   ('coreia', 753),
#   ('sistema', 752),
#   ('cargo', 750),
#   ('historia', 748),
#   ('informou', 747),
#   ('saude', 738),
#   ('jbs', 737),
#   ('partir', 728),
#   ('possivel', 726),
#   ('base', 721),
#   ('candidato', 720),
#   ('janot', 720),
#   ('empresario', 713),
#   ('recebeu', 711),
#   ('mpf', 707),
#   ('crise', 707),
#   ('veja', 706),
#   ('relator', 706),
#   ('pagamento', 706),
#   ('podem', 701),
#   ('local', 699),
#   ('cunha', 699),
#   ('palocci', 699),
#   ('enquanto', 695),
#   ('eua', 695),
#   ('pena', 695),
#   ('deste', 693),
#   ('provas', 691),
#   ('quinta', 690),
#   ('epoca', 690),
#   ('dar', 687),
#   ('contas', 686),
#   ('lider', 685),
#   ('brasileiro', 684),
#   ('apartamento', 684),
#   ('paises', 682),
#   ('informacoes', 681),
#   ('sexta', 681),
#   ('acoes', 680),
#   ('quanto', 678),
#   ('pessoa', 676),
#   ('questao', 676),
#   ('quer', 675),
#   ('proprio', 675),
#   ('pediu', 673),
#   ('apoio', 669),
#   ('lavagem', 669),
#   ('organizacao', 669),
#   ('lado', 668),
#   ('brasileira', 665),
#   ('sob', 663),
#   ('medida', 663),
#   ('carlos', 662),
#   ('petista', 659),
#   ('pouco', 658),
#   ('cinco', 658),
#   ('inacio', 658),
#   ('mandato', 657),
#   ('bilhoes', 655),
#   ('area', 650),
#   ('numero', 650),
#   ('advogados', 646),
#   ('ficou', 646),
#   ('unidos', 641),
#   ('mes', 640),
#   ('passou', 640),
#   ('fernando', 634),
#   ('roberto', 632),
#   ('proposta', 631),
#   ('sociedade', 628),
#   ('rousseff', 627),
#   ('noite', 623),
#   ('ver', 622),
#   ('instancia', 622),
#   ('dezembro', 621),
#   ('coisa', 621),
#   ('entrevista', 619),
#   ('caixa', 614),
#   ('policiais', 614),
#   ('nenhum', 613),
#   ('sociais', 610),
#   ('vem', 606),
#   ('planalto', 606),
#   ('medidas', 606),
#   ('centro', 606),
#   ('populacao', 605),
#   ('nesse', 604),
#   ('responsavel', 603),
#   ('antonio', 603),
#   ('tipo', 600),
#   ('melhor', 600),
#   ('batista', 598),
#   ('entanto', 593),
#   ('publicos', 587),
#   ('deu', 585),
#   ('presos', 581),
#   ('quase', 581),
#   ('penal', 578),
#   ('eleicao', 574),
#   ('quais', 574),
#   ('estar', 573),
#   ('mesma', 572),
#   ('mae', 571),
#   ('secretaria', 570),
#   ('poderia', 569),
#   ('condenacao', 569),
#   ('importante', 564),
#   ('vao', 563),
#   ('abaixo', 562),
#   ('desse', 561),
#   ('condenado', 561),
#   ('oas', 561),
#   ('social', 559),
#   ('video', 559),
#   ('falar', 558),
#   ('conselho', 556),
#   ('fatos', 553),
#   ('periodo', 552),
#   ('acho', 552),
#   ('renan', 552),
#   ('prefeito', 551),
#   ('votos', 551),
#   ('contratos', 551),
#   ('violencia', 550),
#   ('texto', 549),
#   ('valores', 548),
#   ('frente', 546),
#   ('esquema', 546),
#   ('seis', 545),
#   ('imprensa', 543),
#   ('partidos', 542),
#   ('programa', 542),
#   ('apesar', 542),
#   ('precisa', 542),
#   ('ordem', 542),
#   ('maia', 540),
#   ('vamos', 539),
#   ('corte', 539),
#   ('premiada', 538),
#   ('inquerito', 538),
#   ('capital', 537),
#   ('acusacao', 537),
#   ('problema', 537),
#   ('fachin', 535),
#   ('dados', 535),
#   ('atual', 533),
#   ('mercado', 532),
#   ('toda', 531),
#   ('verdade', 530),
#   ('tanto', 527),
#   ('servicos', 527),
#   ('principais', 526),
#   ('gilmar', 526),
#   ('banco', 526),
#   ('comissao', 524),
#   ('eleicoes', 520),
#   ('palacio', 520),
#   ('homem', 518),
#   ('executivo', 518),
#   ('processos', 518),
#   ('constituicao', 516),
#   ('vice', 516),
#   ('pois', 514),
#   ('ninguem', 511),
#   ('voto', 509),
#   ('sim', 507),
#   ('impeachment', 506),
#   ('dessa', 505),
#   ('possibilidade', 504),
#   ('senhor', 504),
#   ('volta', 502),
#   ('feita', 502),
#   ('previdencia', 502),
#   ('obras', 502),
#   ('uso', 501),
#   ('procuradoria', 500),
#   ('guerra', 500),
#   ('direitos', 499),
#   ('ponto', 498),
#   ('uniao', 497),
#   ('boa', 496),
#   ('ficar', 495),
#   ('receber', 494),
#   ('maio', 494),
#   ('causa', 493),
#   ('morte', 493),
#   ('longo', 493),
#   ('triplex', 493),
#   ('reuniao', 492),
#   ('fevereiro', 492),
#   ('comecou', 492),
#   ('pagamentos', 492),
#   ('mendes', 491),
#   ('pai', 491),
#   ('documento', 490),
#   ('maioria', 489),
#   ('rede', 487),
#   ('porem', 487),
#   ('mulheres', 487),
#   ('muitos', 485),
#   ('chefe', 485),
#   ('novembro', 484),
#   ('alvo', 484),
#   ('nenhuma', 479),
#   ('pgr', 477),
#   ('risco', 477),
#   ('curitiba', 476),
#   ('tse', 476),
#   ('ultima', 473),
#   ('internacional', 473),
#   ('setembro', 471),
#   ('autoridades', 471),
#   ('ato', 471),
#   ('diante', 469),
#   ('secretario', 469),
#   ('reportagem', 468),
#   ('criminosa', 468),
#   ('escola', 466),
#   ('educacao', 466),
#   ('favor', 465),
#   ('imovel', 465),
#   ('objetivo', 463),
#   ('propria', 462),
#   ('busca', 462),
#   ('documentos', 461),
#   ('manter', 459),
#   ('manha', 458),
#   ('lugar', 458),
#   ('prefeitura', 457),
#   ('gestao', 457),
#   ('total', 454),
#   ('deixar', 453),
#   ('fica', 451),
#   ('embora', 450),
#   ('assunto', 449),
#   ('algo', 448),
#   ('contou', 447),
#   ('falou', 446),
#   ('abril', 446),
#   ('parlamentares', 446),
#   ('leia', 446),
#   ('plenario', 445),
#   ('recurso', 445),
#   ('falta', 444),
#   ('executivos', 444),
#   ('acesso', 444),
#   ('votacao', 443),
#   ('jornal', 443),
#   ('inclusive', 442),
#   ('ontem', 442),
#   ('neves', 441),
#   ('horas', 440),
#   ('saber', 440),
#   ('deixou', 440),
#   ('conversa', 440),
#   ('pagar', 440),
#   ('ultimos', 440),
#   ('tao', 439),
#   ('respeito', 438),
#   ('bom', 438),
#   ('algumas', 436),
#   ('parlamentar', 434),
#   ('acusado', 432),
#   ('prazo', 432),
#   ('claro', 432),
#   ('movimento', 431),
#   ('preciso', 431),
#   ('militares', 431),
#   ('delacoes', 431),
#   ('acusacoes', 430),
#   ('ideia', 430),
#   ('oficial', 430),
#   ('armas', 430),
#   ('relatorio', 429),
#   ('declarou', 427),
#   ('resultado', 426),
#   ('assessoria', 426),
#   ('troca', 426),
#   ('conforme', 426),
#   ('compra', 425),
#   ('vou', 423),
#   ('sabe', 423),
#   ('procuradores', 423),
#   ('fala', 422),
#   ('liberdade', 422),
#   ('judiciario', 422),
#   ('hospital', 422),
#   ('analise', 422),
#   ('discurso', 420),
#   ('pratica', 419),
#   ('economia', 419),
#   ('plano', 417),
#   ('evitar', 412),
#   ('agosto', 410),
#   ('setor', 410),
#   ('algum', 410),
#   ('varios', 410),
#   ('outubro', 410),
#   ('regional', 409),
#   ('existe', 409),
#   ('regime', 408),
#   ('brasileiros', 407),
#   ('depoimentos', 407),
#   ('trf', 407),
#   ('tentar', 406),
#   ('encontro', 406),
#   ('prova', 406),
#   ('reu', 405),
#   ('passiva', 404),
#   ('forcas', 404),
#   ('muitas', 403),
#   ('palavra', 402),
#   ('redes', 402),
#   ('participacao', 401),
#   ('ocorreu', 400),
#   ('zona', 399),
#   ('ultimo', 399),
#   ('sentenca', 398),
#   ('delatores', 397),
#   ('junto', 397),
#   ('servico', 395),
#   ('alguma', 394),
#   ('povo', 393),
#   ('hora', 393),
#   ('superior', 392),
#   ('campo', 390),
#   ('vista', 390),
#   ('jovem', 389),
#   ('fase', 388),
#   ('muita', 388),
#   ('oliveira', 388),
#   ('especial', 388),
#   ('problemas', 387),
#   ('junho', 387),
#   ('logo', 386),
#   ('aconteceu', 386),
#   ('santos', 385),
#   ('ricardo', 385),
#   ('sete', 385),
#   ('principal', 385),
#   ('razao', 384),
#   ('tarde', 383),
#   ('vitima', 383),
#   ('equipe', 383),
#   ('integra', 381),
#   ('empreiteira', 380),
#   ('julho', 379),
#   ('propinas', 379),
#   ('candidatura', 378),
#   ('comando', 377),
#   ('coisas', 376),
#   ('podera', 374),
#   ('fundo', 374),
#   ('controle', 374),
#   ('decidiu', 373),
#   ('ataque', 372),
#   ('policial', 372),
#   ('sentido', 371),
#   ('atuacao', 371),
#   ('estadual', 370),
#   ('condicoes', 370),
#   ('conseguiu', 370),
#   ('criancas', 369),
#   ('sessao', 368),
#   ('serie', 368),
#   ('sair', 366),
#   ('papel', 366),
#   ('agentes', 365),
#   ('mudanca', 365),
#   ('dem', 365),
#   ('tentativa', 365),
#   ('informacao', 365),
#   ('costa', 364),
#   ('henrique', 364),
#   ('maneira', 364),
#   ('universidade', 364),
#   ('exterior', 363),
#   ('delegado', 363),
#   ('marisa', 363),
#   ('agua', 363),
#   ('campanhas', 362),
#   ('tema', 362),
#   ('projetos', 362),
#   ('neto', 362),
#   ('grandes', 361),
#   ('negou', 360),
#   ('tarefa', 360),
#   ('fazenda', 360),
#   ('espaco', 359),
#   ('mostra', 359),
#   ('novas', 359),
#   ('trata', 358),
#   ('novos', 358),
#   ('porto', 357),
#   ('filha', 356),
#   ('administracao', 355),
#   ('contato', 355),
#   ('bolsonaro', 354),
#   ('crianca', 354),
#   ('contrato', 354),
#   ('dificil', 353),
#   ('economica', 353),
#   ('dizem', 353),
#   ('feitas', 353),
#   ('demais', 353),
#   ('sabado', 352),
#   ('corpo', 352),
#   ('deveria', 351),
#   ('delator', 351),
#   ('chegar', 350),
#   ('senadores', 350),
#   ('americano', 350),
#   ('lista', 349),
#   ('somente', 348),
#   ('aprovacao', 347),
#   ('nessa', 346),
#   ('intervencao', 346),
#   ('pedir', 345),
#   ('minas', 345),
#   ('globo', 343),
#   ('lima', 342),
#   ('alguem', 342),
#   ('ouvir', 342),
#   ('edson', 342),
#   ('bbc', 342),
#   ('reformas', 341),
#   ('funcionarios', 341),
#   ('dez', 340),
#   ('turma', 340),
#   ('fazendo', 340),
#   ('politicas', 339),
#   ('evento', 338),
#   ('vara', 337),
#   ('aumento', 336),
#   ('devem', 335),
#   ('publicas', 334),
#   ('rua', 334),
#   ('chapa', 334),
#   ('amigos', 334),
#   ('obra', 334),
#   ('pinheiro', 333),
#   ('pre', 332),
#   ('democracia', 332),
#   ('parece', 331),
#   ('desenvolvimento', 330),
#   ('ajuda', 328),
#   ('pesquisa', 327),
#   ('ira', 327),
#   ('forte', 326),
#   ('suspeita', 326),
#   ('dono', 325),
#   ('filhos', 325),
#   ('homens', 324),
#   ('atos', 324),
#   ('mim', 324),
#   ('domingo', 323),
#   ('parana', 323),
#   ('recebido', 322),
#   ('trabalhadores', 322),
#   ('vitimas', 321),
#   ('construcao', 320),
#   ('grupos', 320),
#   ('amigo', 319),
#   ('interesse', 319),
#   ('atualmente', 317),
#   ('alckmin', 316),
#   ('proximo', 316),
#   ('federais', 316),
#   ('operacoes', 315),
#   ('economico', 314),
#   ('chamado', 314),
#   ('queria', 314),
#   ('investigados', 311),
#   ('unica', 311),
#   ('resposta', 310),
#   ('abuso', 310),
#   ('diferentes', 310),
#   ('responsabilidade', 310),
#   ('data', 310),
#   ('carro', 309),
#   ('pontos', 308),
#   ('oito', 307),
#   ('acabou', 307),
#   ('varias', 307),
#   ('foro', 306),
#   ('judicial', 306),
#   ('relacoes', 306),
#   ('combate', 306),
#   ('cidades', 306),
#   ('oposicao', 306),
#   ('passar', 305),
#   ('discussao', 305),
#   ('maria', 304),
#   ('santana', 304),
#   ('diferente', 302),
#   ('pede', 302),
#   ('central', 302),
#   ('explica', 302),
#   ('sede', 301),
#   ('conhecimento', 301),
#   ('principalmente', 301),
#   ('presidencial', 300),
#   ('pessoal', 300),
#   ('rocha', 300),
#   ('cultura', 299),
#   ('voltou', 298),
#   ('noticias', 297),
#   ('tal', 296),
#   ('membros', 296),
#   ('candidatos', 295),
#   ('modelo', 295),
#   ('declaracao', 295),
#   ('pedidos', 295),
#   ('trabalhar', 295),
#   ('kim', 294),
#   ('milhao', 293),
#   ('investigado', 293),
#   ('atividades', 292),
#   ('garantir', 292),
#   ('abertura', 291),
#   ('entrou', 291),
#   ('morreu', 291),
#   ('seguida', 291),
#   ('necessidade', 291),
#   ('doacoes', 291),
#   ('caminho', 290),
#   ('acima', 290),
#   ('professor', 290),
#   ('levar', 289),
#   ('mal', 289),
#   ('funcao', 288),
#   ('levou', 288),
#   ('orgao', 287),
#   ('posse', 287),
#   ('entrar', 287),
#   ('internet', 287),
#   ('mudancas', 287),
#   ('passada', 286),
#   ('decisoes', 286),
#   ('capacidade', 286),
#   ('sabia', 286),
#   ('delcidio', 285),
#   ('seguinte', 285),
#   ('suspeito', 285),
#   ('livro', 285),
#   ('integrantes', 284),
#   ('questoes', 283),
#   ('areas', 283),
#   ('explicou', 282),
#   ('juca', 281),
#   ('medico', 281),
#   ('pedro', 281),
#   ('talvez', 281),
#   ('nomes', 280),
#   ('unico', 280),
#   ('passa', 279),
#   ('defende', 279),
#   ('saida', 278),
#   ('via', 278),
#   ('russia', 278),
#   ('criminal', 276),
#   ('serem', 275),
#   ('envolvendo', 275),
#   ('atencao', 275),
#   ('alta', 274),
#   ('votar', 273),
#   ('continua', 273),
#   ('tornou', 273),
#   ('denuncias', 273),
#   ('fiscal', 272),
#   ('jamais', 272),
#   ('disputa', 272),
#   ('estatal', 272),
#   ('posicao', 271),
#   ('municipal', 271),
#   ('futuro', 271),
#   ('sei', 271),
#   ('china', 271),
#   ('agencia', 270),
#   ('humanos', 270),
#   ('menor', 270),
#   ('cenario', 270),
#   ('alegre', 270),
#   ('associacao', 270),
#   ('juizes', 270),
#   ('questionado', 269),
#   ('conseguir', 269),
#   ('mao', 269),
#   ('luis', 269),
#   ('governos', 269),
#   ('venda', 268),
#   ('beneficios', 267),
#   ('ruas', 267),
#   ('reus', 267),
#   ('exercito', 267),
#   ('cargos', 266),
#   ('desses', 266),
#   ('destacou', 265),
#   ('carmen', 265),
#   ('lucia', 265),
#   ('trafico', 265),
#   ('ministra', 264),
#   ('quero', 264),
#   ('influencia', 264),
#   ('nega', 263),
#   ('instituicoes', 263),
#   ('ambito', 263),
#   ('certo', 262),
#   ('bndes', 262),
#   ('meirelles', 261),
#   ('grave', 261),
#   ('dirceu', 261),
#   ('mudar', 260),
#   ('popular', 260),
#   ('especie', 260),
#   ('companhia', 259),
#   ('colaboracao', 259),
#   ('acidente', 259),
#   ('casal', 259),
#   ('geddel', 258),
#   ('cabral', 258),
#   ('lideres', 257),
#   ('defender', 257),
#   ('reducao', 257),
#   ('filme', 257),
#   ('magistrado', 256),
#   ('unidade', 256),
#   ('irregularidades', 256),
#   ('cabeca', 256),
#   ('gerais', 256),
#   ('linha', 255),
#   ('dona', 255),
#   ('onu', 255),
#   ('mortes', 255),
#   ('usar', 254),
#   ('regras', 254),
#   ('servidores', 254),
#   ('empresarios', 254),
#   ('continuar', 254),
#   ('fazem', 254),
#   ('investimentos', 253),
#   ('diversos', 253),
#   ('calheiros', 253),
#   ('eldorado', 253),
#   ('agenda', 252),
#   ('curso', 252),
#   ('apresentou', 252),
#   ('ali', 251),
#   ('departamento', 251),
#   ('afastamento', 250),
#   ('jovens', 250),
#   ('possa', 249),
#   ('opiniao', 249),
#   ('drogas', 249),
#   ('esquerda', 248),
#   ('imagens', 248),
#   ('minutos', 248),
#   ('estadao', 248),
#   ('ocasiao', 247),
#   ('saiu', 247),
#   ('tendo', 247),
#   ('dizendo', 247),
#   ('especialistas', 247),
#   ('origem', 246),
#   ('espera', 246),
#   ('ajudar', 246),
#   ('aliados', 246),
#   ('porta', 246),
#   ('intencao', 246),
#   ('presenca', 246),
#   ('determinou', 246),
#   ('nuclear', 246),
#   ('apresentar', 245),
#   ('diversas', 245),
#   ('terra', 245),
#   ('fizeram', 244),
#   ('manifestantes', 244),
#   ('monica', 244),
#   ('paulista', 243),
#   ('declaracoes', 242),
#   ('imagem', 242),
#   ('contrario', 242),
#   ('criacao', 242),
#   ('condicao', 242),
#   ('dado', 242),
#   ('anunciou', 241),
#   ('avaliacao', 241),
#   ('maiores', 241),
#   ('distrito', 241),
#   ('feitos', 241),
#   ('tomar', 240),
#   ('interior', 240),
#   ('guaruja', 240),
#   ('tratamento', 239),
#   ('facebook', 239),
#   ('cinema', 239),
#   ('carta', 238),
#   ('portanto', 238),
#   ('necessario', 238),
#   ('voltar', 238),
#   ('respondeu', 238),
#   ('americana', 238),
#   ('predio', 238),
#   ('investigadores', 238),
#   ('mortos', 238),
#   ('tecnologia', 238),
#   ('assessor', 237),
#   ('termos', 237),
#   ('ameaca', 237),
#   ('eventual', 237),
#   ('queda', 237),
#   ('negocios', 237),
#   ('dessas', 237),
#   ('testemunhas', 237),
#   ('nove', 236),
#   ('legal', 236),
#   ('bairro', 236),
#   ('claudio', 235),
#   ('franco', 234),
#   ('detalhes', 234),
#   ('sitio', 234),
#   ('onibus', 234),
#   ('criticas', 233),
#   ('bancada', 233),
#   ('ataques', 233),
#   ('vale', 233),
#   ('referencia', 232),
#   ('carreira', 232),
#   ('direcao', 232),
#   ('conversas', 232),
#   ('moreira', 232),
#   ('deixa', 231),
#   ('teixeira', 231),
#   ('comunicacao', 231),
#   ('minimo', 230),
#   ('querem', 230),
#   ('aurelio', 230),
#   ('tucano', 230),
#   ('alto', 230),
#   ('orgaos', 230),
#   ('padilha', 230),
#   ('ambiente', 229),
#   ('vieira', 229),
#   ('apreensao', 229),
#   ('bahia', 228),
#   ('entender', 228),
#   ('gravacao', 228),
#   ('veio', 228),
#   ('martins', 227),
#   ('mundial', 227),
#   ('provisoria', 227),
#   ('producao', 227),
#   ('conteudo', 226),
#   ('unidades', 226),
#   ('disseram', 225),
#   ('marido', 225),
#   ('diretamente', 225),
#   ('jornalista', 225),
#   ('cadeia', 224),
#   ('escolas', 224),
#   ('preve', 224),
#   ('moradores', 224),
#   ('proxima', 224),
#   ('registro', 224),
#   ('material', 224),
#   ('divulgou', 224),
#   ('musica', 224),
#   ('conhecido', 223),
#   ('andrade', 223),
#   ('media', 222),
#   ('colocar', 222),
#   ('loures', 222),
#   ('manutencao', 222),
#   ('audiencia', 222),
#   ('viagem', 221),
#   ('ambos', 221),
#   ('realidade', 221),
#   ('leo', 221),
#   ('indicios', 221),
#   ('dialogo', 221),
#   ('cidadao', 220),
#   ('santa', 220),
#   ('misseis', 220),
#   ('residencia', 219),
#   ('barroso', 219),
#   ('vaccari', 219),
#   ('manifestacao', 218),
#   ('doenca', 218),
#   ('cara', 218),
#   ('legislacao', 218),
#   ('preocupacao', 218),
#   ...],
#  1: [('presidente', 2059),
#   ('lula', 2047),
#   ('dilma', 1370),
#   ('disse', 1246),
#   ('brasil', 916),
#   ('temer', 863),
#   ('federal', 851),
#   ('governo', 773),
#   ('pais', 746),
#   ('ministro', 737),
#   ('sobre', 652),
#   ('jato', 628),
#   ('lava', 624),
#   ('anos', 564),
#   ('moro', 562),
#   ('ainda', 561),
#   ('contra', 550),
#   ('acordo', 534),
#   ('hoje', 508),
#   ('sergio', 504),
#   ('deputado', 501),
#   ('pode', 489),
#   ('milhoes', 482),
#   ('durante', 468),
#   ('apos', 440),
#   ('diz', 437),
#   ('dinheiro', 437),
#   ('dia', 435),
#   ('juiz', 433),
#   ('petista', 416),
#   ('senador', 413),
#   ('policia', 412),
#   ('michel', 398),
#   ('stf', 395),
#   ('caso', 376),
#   ('justica', 374),
#   ('paulo', 373),
#   ('video', 373),
#   ('impeachment', 372),
#   ('pessoas', 369),
#   ('operacao', 367),
#   ('estado', 346),
#   ('mil', 341),
#   ('republica', 341),
#   ('todos', 338),
#   ('bolsonaro', 337),
#   ('publico', 336),
#   ('tudo', 330),
#   ('porque', 328),
#   ('fazer', 317),
#   ('casa', 308),
#   ('cunha', 308),
#   ('afirmou', 307),
#   ('delacao', 300),
#   ('agora', 298),
#   ('rousseff', 297),
#   ('politicos', 297),
#   ('senado', 297),
#   ('corrupcao', 296),
#   ('processo', 291),
#   ('prisao', 290),
#   ('camara', 286),
#   ('odebrecht', 284),
#   ('segundo', 282),
#   ('politica', 279),
#   ('parte', 278),
#   ('informou', 276),
#   ('norte', 276),
#   ('eduardo', 275),
#   ('pmdb', 274),
#   ('fez', 273),
#   ('ministerio', 267),
#   ('outros', 267),
#   ('mundo', 266),
#   ('petrobras', 262),
#   ('aecio', 257),
#   ('todo', 256),
#   ('silva', 253),
#   ('vez', 252),
#   ('dois', 251),
#   ('ano', 250),
#   ('grupo', 248),
#   ('sendo', 247),
#   ('jose', 246),
#   ('qualquer', 246),
#   ('dias', 245),
#   ('filho', 245),
#   ('onde', 243),
#   ('jornal', 243),
#   ('preso', 243),
#   ('alem', 240),
#   ('partido', 236),
#   ('globo', 233),
#   ('jornalista', 232),
#   ('lei', 232),
#   ('eua', 231),
#   ('momento', 229),
#   ('informacoes', 226),
#   ('povo', 224),
#   ('bem', 224),
#   ('podera', 224),
#   ('apenas', 224),
#   ('brasilia', 223),
#   ('defesa', 223),
#   ('sociais', 222),
#   ('vida', 221),
#   ('nome', 220),
#   ('assim', 214),
#   ('poder', 212),
#   ('politico', 211),
#   ('empresa', 210),
#   ('campanha', 210),
#   ('feira', 207),
#   ('fato', 205),
#   ('presidencia', 204),
#   ('advogado', 203),
#   ('redes', 203),
#   ('decisao', 202),
#   ('maior', 202),
#   ('coreia', 202),
#   ('gente', 201),
#   ('grande', 200),
#   ('aqui', 200),
#   ('cargo', 199),
#   ('quer', 197),
#   ('nada', 197),
#   ('familia', 197),
#   ('renan', 196),
#   ('abaixo', 194),
#   ('nacional', 191),
#   ('deputados', 191),
#   ('brasileiro', 189),
#   ('supremo', 186),
#   ('faz', 186),
#   ('pedido', 185),
#   ('ontem', 185),
#   ('psdb', 184),
#   ('rio', 183),
#   ('entrevista', 182),
#   ('joao', 179),
#   ('mendes', 178),
#   ('desde', 178),
#   ('alguns', 178),
#   ('veja', 176),
#   ('sido', 176),
#   ('menos', 175),
#   ('novo', 174),
#   ('conta', 174),
#   ('seguranca', 173),
#   ('brasileiros', 173),
#   ('situacao', 172),
#   ('gilmar', 171),
#   ('leia', 171),
#   ('luiz', 169),
#   ('congresso', 167),
#   ('antes', 164),
#   ('eleicoes', 164),
#   ('outro', 163),
#   ('dentro', 162),
#   ('direito', 162),
#   ('tribunal', 162),
#   ('crime', 162),
#   ('ninguem', 162),
#   ('entao', 162),
#   ('dizer', 161),
#   ('militar', 161),
#   ('vamos', 161),
#   ('atraves', 160),
#   ('fim', 160),
#   ('propina', 160),
#   ('exercito', 158),
#   ('pouco', 157),
#   ('investigacoes', 156),
#   ('forca', 156),
#   ('informacao', 156),
#   ('brasileira', 156),
#   ('porem', 155),
#   ('curitiba', 155),
#   ('local', 151),
#   ('revista', 151),
#   ('geral', 151),
#   ('sabe', 151),
#   ('janot', 150),
#   ('semana', 150),
#   ('nota', 150),
#   ('ultima', 150),
#   ('tempo', 149),
#   ('chegou', 148),
#   ('tres', 147),
#   ('deu', 147),
#   ('planalto', 147),
#   ('delcidio', 147),
#   ('neves', 146),
#   ('homem', 146),
#   ('folha', 146),
#   ('pediu', 145),
#   ('trump', 145),
#   ('ultimo', 145),
#   ('havia', 144),
#   ('projeto', 142),
#   ('instituto', 142),
#   ('apoio', 141),
#   ('primeiro', 141),
#   ('meses', 140),
#   ('depoimento', 140),
#   ('primeira', 140),
#   ('ira', 139),
#   ('dar', 138),
#   ('epoca', 138),
#   ('sul', 138),
#   ('coisa', 136),
#   ('acao', 135),
#   ('deve', 135),
#   ('recebeu', 135),
#   ('mandato', 135),
#   ('inacio', 135),
#   ('programa', 135),
#   ('feito', 134),
#   ('trabalho', 134),
#   ('rodrigo', 134),
#   ('meio', 134),
#   ('toda', 134),
#   ('machado', 133),
#   ('senadores', 133),
#   ('estar', 133),
#   ('cidade', 132),
#   ('sempre', 132),
#   ('pessoa', 132),
#   ('nunca', 132),
#   ('empresario', 131),
#   ('civil', 131),
#   ('foro', 131),
#   ('marcelo', 131),
#   ('crimes', 131),
#   ('conversa', 131),
#   ('materia', 130),
#   ('site', 130),
#   ('denuncia', 130),
#   ('guerra', 130),
#   ('juca', 129),
#   ('cerca', 128),
#   ('ver', 128),
#   ('reais', 128),
#   ('cada', 127),
#   ('jair', 127),
#   ('historia', 127),
#   ('publica', 127),
#   ('votos', 127),
#   ('imprensa', 127),
#   ('nova', 126),
#   ('joesley', 126),
#   ('mostra', 126),
#   ('lider', 125),
#   ('declarou', 125),
#   ('rede', 125),
#   ('cadeia', 124),
#   ('premiada', 124),
#   ('ministros', 124),
#   ('mulher', 123),
#   ('valor', 122),
#   ('parlamentar', 122),
#   ('quase', 122),
#   ('kim', 122),
#   ('sim', 121),
#   ('segunda', 120),
#   ('fernando', 120),
#   ('poderia', 119),
#   ('esquema', 119),
#   ('forma', 118),
#   ('pgr', 118),
#   ('oficial', 118),
#   ('vou', 117),
#   ('cara', 117),
#   ('publicos', 117),
#   ('bilhoes', 117),
#   ('relacao', 116),
#   ('vem', 115),
#   ('todas', 115),
#   ('saude', 115),
#   ('golpe', 115),
#   ('publicou', 115),
#   ('pois', 114),
#   ('falar', 114),
#   ('podem', 114),
#   ('algo', 113),
#   ('tipo', 113),
#   ('general', 113),
#   ('advogados', 112),
#   ('diario', 112),
#   ('lado', 111),
#   ('possivel', 111),
#   ('somente', 110),
#   ('duas', 110),
#   ('populacao', 110),
#   ('equipe', 110),
#   ('condenado', 108),
#   ('confira', 108),
#   ('esposa', 108),
#   ('feita', 107),
#   ('candidato', 107),
#   ('proximo', 107),
#   ('chefe', 107),
#   ('sistema', 106),
#   ('sitio', 106),
#   ('nesta', 105),
#   ('morte', 105),
#   ('aconteceu', 105),
#   ('proprio', 105),
#   ('carlos', 105),
#   ('crise', 104),
#   ('diretor', 104),
#   ('militares', 104),
#   ('palacio', 104),
#   ('enquanto', 104),
#   ('questao', 104),
#   ('atual', 103),
#   ('decidiu', 103),
#   ('petistas', 103),
#   ('janeiro', 103),
#   ('outra', 103),
#   ('dessa', 103),
#   ('casos', 103),
#   ('movimento', 102),
#   ('alguem', 102),
#   ('calheiros', 101),
#   ('sob', 101),
#   ('desse', 100),
#   ('discurso', 100),
#   ('tarde', 99),
#   ('noite', 99),
#   ('quanto', 99),
#   ('investigacao', 99),
#   ('manha', 99),
#   ('numero', 99),
#   ('partir', 98),
#   ('outras', 98),
#   ('tal', 98),
#   ('senadora', 97),
#   ('eleitoral', 97),
#   ('tentar', 97),
#   ('recursos', 97),
#   ('afirma', 97),
#   ('estaria', 97),
#   ('quatro', 97),
#   ('fala', 97),
#   ('oas', 97),
#   ('ataque', 97),
#   ('doria', 96),
#   ('vezes', 96),
#   ('estados', 96),
#   ('parlamentares', 96),
#   ('favor', 96),
#   ('senhor', 96),
#   ('esquerda', 96),
#   ('empresas', 96),
#   ('diante', 96),
#   ('conseguiu', 95),
#   ('ficou', 95),
#   ('precisa', 95),
#   ('final', 95),
#   ('claro', 94),
#   ('jbs', 94),
#   ('cidadao', 94),
#   ('receber', 93),
#   ('facebook', 93),
#   ('neste', 93),
#   ('bom', 92),
#   ('governador', 92),
#   ('melhor', 92),
#   ('mes', 92),
#   ('caixa', 92),
#   ('mpf', 91),
#   ('propinas', 91),
#   ('horas', 91),
#   ('nenhum', 91),
#   ('vice', 91),
#   ('via', 91),
#   ('reportagem', 91),
#   ('pede', 91),
#   ('acabou', 90),
#   ('cervero', 90),
#   ('varios', 90),
#   ('marido', 90),
#   ('imagem', 89),
#   ('pai', 89),
#   ('algum', 89),
#   ('apresentador', 89),
#   ('alvo', 89),
#   ('tentou', 89),
#   ('texto', 89),
#   ('prefeito', 88),
#   ('antonio', 88),
#   ('passou', 88),
#   ('comecou', 88),
#   ('frente', 88),
#   ('apartamento', 88),
#   ('ator', 88),
#   ('tao', 87),
#   ('vao', 87),
#   ('palocci', 87),
#   ('procurador', 87),
#   ('provas', 87),
#   ('corte', 87),
#   ('palavras', 87),
#   ('algumas', 87),
#   ('ameaca', 87),
#   ('teori', 87),
#   ('pedir', 86),
#   ('dizendo', 86),
#   ('gleisi', 86),
#   ('ricardo', 86),
#   ('hora', 86),
#   ('presidenta', 86),
#   ('desta', 85),
#   ('amigo', 85),
#   ('capital', 85),
#   ('aviao', 85),
#   ('ato', 85),
#   ('silvio', 84),
#   ('problema', 84),
#   ('social', 84),
#   ('documentos', 84),
#   ('lavagem', 84),
#   ('grandes', 84),
#   ('claudio', 84),
#   ('proposta', 83),
#   ('ordem', 83),
#   ('tanto', 83),
#   ('lugar', 83),
#   ('total', 83),
#   ('presidencial', 83),
#   ('pena', 83),
#   ('contas', 83),
#   ('deveria', 82),
#   ('deixou', 82),
#   ('deste', 82),
#   ('reforma', 82),
#   ('risco', 82),
#   ('tse', 82),
#   ('china', 82),
#   ('dono', 81),
#   ('reuniao', 81),
#   ('acusado', 81),
#   ('forcas', 81),
#   ('acoes', 81),
#   ('plenario', 81),
#   ('privilegiado', 80),
#   ('batista', 80),
#   ('deus', 80),
#   ('luis', 80),
#   ('marco', 79),
#   ('objetivo', 79),
#   ('fazendo', 79),
#   ('cinco', 79),
#   ('alerta', 79),
#   ('empreiteira', 78),
#   ('criminosa', 78),
#   ('democracia', 78),
#   ('jovem', 78),
#   ('lista', 78),
#   ('passar', 78),
#   ('banco', 78),
#   ('amigos', 78),
#   ('falta', 78),
#   ('direitos', 77),
#   ('medo', 77),
#   ('posse', 77),
#   ('triplex', 77),
#   ('responsavel', 77),
#   ('tarefa', 77),
#   ('midia', 77),
#   ('americano', 77),
#   ('evitar', 76),
#   ('base', 76),
#   ('delacoes', 76),
#   ('voto', 76),
#   ('defender', 76),
#   ('hospital', 76),
#   ('assessor', 76),
#   ('trabalhadores', 76),
#   ('santana', 76),
#   ('nenhuma', 75),
#   ('volta', 75),
#   ('roberto', 75),
#   ('presos', 75),
#   ('organizacao', 75),
#   ('assunto', 75),
#   ('votacao', 75),
#   ('comando', 75),
#   ('nuclear', 75),
#   ('constituicao', 74),
#   ('inicio', 74),
#   ('passa', 74),
#   ('junto', 74),
#   ('mesma', 73),
#   ('vivo', 73),
#   ('sessao', 73),
#   ('chamou', 73),
#   ('acima', 73),
#   ('funcionarios', 73),
#   ('muita', 72),
#   ('verdade', 72),
#   ('logo', 72),
#   ('confirmou', 72),
#   ('milhao', 72),
#   ('marisa', 72),
#   ('mensagem', 72),
#   ('virus', 72),
#   ('ministra', 71),
#   ('podemos', 71),
#   ('assessoria', 71),
#   ('seguinte', 71),
#   ('colocar', 70),
#   ('santos', 70),
#   ('recebido', 70),
#   ('sociedade', 70),
#   ('penal', 70),
#   ('resposta', 70),
#   ('relator', 70),
#   ('carro', 70),
#   ('poderao', 70),
#   ('noticia', 70),
#   ('antagonista', 70),
#   ('parece', 69),
#   ('busca', 69),
#   ('coisas', 69),
#   ('possa', 69),
#   ('comissao', 69),
#   ('tirar', 69),
#   ('nesse', 69),
#   ('mae', 69),
#   ('henrique', 69),
#   ('policiais', 69),
#   ('desses', 69),
#   ('valores', 69),
#   ('amaral', 69),
#   ('publicada', 69),
#   ('reporter', 69),
#   ('misseis', 69),
#   ('portal', 69),
#   ('cargos', 68),
#   ('internacional', 68),
#   ('julgamento', 68),
#   ('caiu', 68),
#   ('proxima', 68),
#   ('zavascki', 68),
#   ('noticias', 68),
#   ('maiores', 67),
#   ('autoridades', 67),
#   ('exemplo', 67),
#   ('nacao', 67),
#   ('vitima', 67),
#   ('ruas', 67),
#   ('acha', 67),
#   ('minas', 67),
#   ('pessoal', 66),
#   ('maria', 66),
#   ('ultimos', 66),
#   ('regime', 66),
#   ('encontro', 66),
#   ('pesquisa', 66),
#   ('chamado', 66),
#   ('conhecido', 66),
#   ('medico', 66),
#   ('porta', 66),
#   ('colunista', 66),
#   ('acho', 65),
#   ('passado', 65),
#   ('salario', 65),
#   ('citado', 65),
#   ('manter', 65),
#   ('respeito', 65),
#   ('deixar', 65),
#   ('mal', 65),
#   ('intencao', 65),
#   ('internet', 65),
#   ('ciro', 65),
#   ('disso', 65),
#   ('quero', 65),
#   ('parana', 65),
#   ('processos', 65),
#   ('principal', 65),
#   ('paises', 65),
#   ('judiciario', 64),
#   ('sexta', 64),
#   ('delator', 64),
#   ('sabia', 64),
#   ('problemas', 64),
#   ('ocorreu', 64),
#   ('economica', 64),
#   ('terra', 64),
#   ('dona', 64),
#   ('secretaria', 63),
#   ('compra', 63),
#   ('friboi', 63),
#   ('medidas', 63),
#   ('futuro', 63),
#   ('atibaia', 63),
#   ('unidos', 63),
#   ('agua', 63),
#   ('contou', 62),
#   ('mst', 62),
#   ('atras', 62),
#   ('conselho', 62),
#   ('twitter', 62),
#   ('alguma', 62),
#   ('area', 62),
#   ('pagar', 62),
#   ('filhos', 62),
#   ('fogo', 62),
#   ('propria', 62),
#   ('trata', 62),
#   ('pagamento', 62),
#   ('motivo', 61),
#   ('ficar', 61),
#   ('seis', 61),
#   ('fica', 61),
#   ('ajuda', 61),
#   ('aparece', 61),
#   ('leo', 61),
#   ('agencia', 61),
#   ('fonte', 61),
#   ('zika', 61),
#   ('liberdade', 60),
#   ('chama', 60),
#   ('usar', 60),
#   ('afastamento', 60),
#   ('campanhas', 60),
#   ('saber', 60),
#   ('cantor', 60),
#   ('vale', 60),
#   ('ameacas', 60),
#   ('sentenca', 60),
#   ('novas', 60),
#   ('cultura', 60),
#   ('gastos', 60),
#   ('nucleares', 60),
#   ('executivo', 59),
#   ('maneira', 59),
#   ('mim', 59),
#   ('disseram', 59),
#   ('voz', 59),
#   ('possui', 59),
#   ('comunicacao', 59),
#   ('varias', 59),
#   ('maos', 58),
#   ('periodo', 58),
#   ('integrantes', 58),
#   ('possibilidade', 58),
#   ('muitos', 58),
#   ('divulgada', 58),
#   ('causa', 58),
#   ('acidente', 58),
#   ('alexandre', 58),
#   ('armas', 58),
#   ('filha', 58),
#   ('aeroporto', 58),
#   ('pior', 57),
#   ('alegou', 57),
#   ('inquerito', 57),
#   ('eleicao', 57),
#   ('novamente', 57),
#   ('carta', 57),
#   ('regiao', 57),
#   ('gomes', 57),
#   ('mostrou', 57),
#   ('manifestantes', 57),
#   ('tiririca', 57),
#   ('popular', 57),
#   ('revelou', 57),
#   ('escreveu', 57),
#   ('corpo', 57),
#   ('nomes', 56),
#   ('querem', 56),
#   ('relatou', 56),
#   ('quarta', 56),
#   ('cabeca', 56),
#   ('procuradoria', 56),
#   ('costa', 56),
#   ('instancia', 56),
#   ('servicos', 56),
#   ('divulgou', 56),
#   ('assista', 56),
#   ('ideia', 56),
#   ('sair', 56),
#   ('diversos', 56),
#   ('recado', 56),
#   ('acusacoes', 56),
#   ('documento', 56),
#   ('uso', 56),
#   ('pinheiro', 56),
#   ('lindbergh', 56),
#   ('medida', 56),
#   ('queria', 56),
#   ('afastada', 56),
#   ('atitude', 55),
#   ('respondeu', 55),
#   ('pressao', 55),
#   ('proximos', 55),
#   ('vara', 55),
#   ('devem', 55),
#   ('fachin', 55),
#   ('romero', 55),
#   ('conforme', 55),
#   ('principais', 55),
#   ('partidos', 55),
#   ('unico', 55),
#   ('chegar', 55),
#   ('ambos', 55),
#   ('obras', 55),
#   ('corruptos', 55),
#   ('mundial', 55),
#   ('oposicao', 55),
#   ('moura', 55),
#   ('feitas', 55),
#   ('levar', 54),
#   ('maioria', 54),
#   ('tomar', 54),
#   ('comunista', 54),
#   ('exercicio', 54),
#   ('centro', 54),
#   ('imagens', 54),
#   ('geddel', 54),
#   ('uniao', 54),
#   ('bumlai', 54),
#   ('jong', 54),
#   ('boa', 53),
#   ('acabar', 53),
#   ('imediatamente', 53),
#   ('tomou', 53),
#   ('etc', 53),
#   ('inclusive', 53),
#   ('acontecer', 53),
#   ('cancer', 53),
#   ('continua', 53),
#   ('combate', 53),
#   ('dirceu', 53),
#   ('federais', 53),
#   ('dados', 53),
#   ('data', 53),
#   ('maranhao', 53),
#   ('troca', 52),
#   ('entrou', 52),
#   ('audio', 52),
#   ('opiniao', 52),
#   ('corrupto', 52),
#   ('educacao', 52),
#   ('tucano', 52),
#   ('servico', 52),
#   ('chega', 52),
#   ('declaracao', 52),
#   ('casal', 52),
#   ('amanha', 51),
#   ('tentativa', 51),
#   ('dolares', 51),
#   ('tenta', 51),
#   ('eleito', 51),
#   ('superior', 51),
#   ('simples', 51),
#   ('sei', 51),
#   ('francisco', 51),
#   ('responsabilidade', 51),
#   ('procuradores', 51),
#   ('vergonha', 51),
#   ('carvalho', 51),
#   ('caiado', 51),
#   ('demissao', 51),
#   ('lucia', 51),
#   ('gravacao', 51),
#   ('nessa', 51),
#   ('incluindo', 51),
#   ('ataques', 51),
#   ('provavelmente', 50),
#   ('fase', 50),
#   ('edson', 50),
#   ('pretende', 50),
#   ('existe', 50),
#   ('artigo', 50),
#   ('perder', 50),
#   ('acesso', 50),
#   ('investigado', 50),
#   ('chapa', 50),
#   ('voltar', 50),
#   ('perdeu', 50),
#   ('postagem', 50),
#   ('jornalistas', 50),
#   ('comentou', 50),
#   ('onu', 50),
#   ('atriz', 50),
#   ('abreu', 49),
#   ('agentes', 49),
#   ('enfim', 49),
#   ('suposto', 49),
#   ('jamais', 49),
#   ('domingo', 49),
#   ('estatal', 49),
#   ('contratos', 49),
#   ('instituicoes', 49),
#   ('apesar', 49),
#   ('realmente', 49),
#   ('santo', 49),
#   ('mensagens', 49),
#   ('publicacao', 49),
#   ('investigadores', 49),
#   ('pagamentos', 49),
#   ('usado', 49),
#   ('juizes', 49),
#   ('nomeacao', 49),
#   ('candidatura', 48),
#   ('entrar', 48),
#   ('dez', 48),
#   ('venezuela', 48),
#   ('levou', 48),
#   ('iria', 48),
#   ('devido', 48),
#   ('guaruja', 48),
#   ('referindo', 48),
#   ('alta', 48),
#   ('executivos', 48),
#   ('quis', 48),
#   ('ladrao', 48),
#   ('doenca', 48),
#   ('serie', 47),
#   ('economia', 47),
#   ('estadao', 47),
#   ('usou', 47),
#   ('denuncias', 47),
#   ('ponto', 47),
#   ('mudar', 47),
#   ('luta', 47),
#   ('quinta', 47),
#   ('atencao', 47),
#   ('condicoes', 47),
#   ('grave', 47),
#   ('urgente', 47),
#   ('envolvendo', 47),
#   ('leticia', 47),
#   ('especial', 47),
#   ('imovel', 47),
#   ('donald', 47),
#   ('afastado', 47),
#   ('inqueritos', 47),
#   ('exterior', 47),
#   ('monica', 47),
#   ('controle', 47),
#   ('carmen', 47),
#   ('voltou', 47),
#   ('usando', 47),
#   ('predio', 46),
#   ('lideres', 46),
#   ('aliados', 46),
#   ('escandalo', 46),
#   ('santa', 46),
#   ('cassacao', 46),
#   ('reu', 46),
#   ('depoimentos', 46),
#   ('preciso', 46),
#   ('wyllys', 46),
#   ('publicado', 46),
#   ('americanos', 46),
#   ('boca', 46),
#   ('importante', 46),
#   ('mulheres', 46),
#   ('russia', 46),
#   ('cardozo', 46),
#   ('sede', 45),
#   ('certo', 45),
#   ('dizem', 45),
#   ('falou', 45),
#   ('condenacao', 45),
#   ('madrugada', 45),
#   ('real', 45),
#   ('movimentos', 45),
#   ('papel', 45),
#   ('aponta', 45),
#   ('alto', 45),
#   ('gabinete', 45),
#   ('fhc', 45),
#   ('pedidos', 45),
#   ('especie', 45),
#   ('renuncia', 45),
#   ('policial', 45),
#   ('contrato', 45),
#   ('operacoes', 45),
#   ('autoridade', 44),
#   ('turma', 44),
#   ('considerado', 44),
#   ('longo', 44),
#   ('mudanca', 44),
#   ('arma', 44),
#   ('marqueteiro', 44),
#   ('fazenda', 44),
#   ('livre', 44),
#   ('unica', 44),
#   ('news', 44),
#   ('investigar', 44),
#   ('trecho', 44),
#   ('divulgado', 44),
#   ('aumento', 44),
#   ('ditador', 44),
#   ('voo', 44),
#   ('razao', 43),
#   ('outubro', 43),
#   ('etica', 43),
#   ('ajudar', 43),
#   ('entregar', 43),
#   ('gestao', 43),
#   ('psc', 43),
#   ('cenario', 43),
#   ('crianca', 43),
#   ('perto', 43),
#   ('defende', 43),
#   ('jean', 43),
#   ('andrade', 43),
#   ('armadas', 43),
#   ('secretario', 43),
#   ('servidores', 43),
#   ('saida', 42),
#   ('obstrucao', 42),
#   ('tornou', 42),
#   ('passiva', 42),
#   ('sarney', 42),
#   ('nestor', 42),
#   ('parar', 42),
#   ('plano', 42),
#   ('declaracoes', 42),
#   ('criancas', 42),
#   ('patricia', 42),
#   ('lima', 42),
#   ('maio', 42),
#   ('maia', 42),
#   ('doacoes', 42),
#   ('magistrado', 42),
#   ('deixa', 42),
#   ('resolver', 42),
#   ('interino', 42),
#   ('audiencia', 42),
#   ('destacou', 42),
#   ('sofreu', 42),
#   ('avioes', 42),
#   ('continuou', 42),
#   ('mega', 42),
#   ('cut', 42),
#   ('atacar', 42),
#   ('excelencia', 42),
#   ('ana', 42),
#   ('estrategia', 41),
#   ('novembro', 41),
#   ('vive', 41),
#   ('senhora', 41),
#   ('prazo', 41),
#   ('acusacao', 41),
#   ('suposta', 41),
#   ('trabalhar', 41),
#   ('interesses', 41),
#   ('sabado', 41),
#   ('paulista', 41),
#   ('dezembro', 41),
#   ('abertura', 41),
#   ('criticas', 41),
#   ('quebra', 41),
#   ('homens', 41),
#   ('hotel', 41),
#   ('novos', 41),
#   ('barbosa', 41),
#   ('leis', 41),
#   ('rouanet', 41),
#   ('linha', 41),
#   ('canal', 41),
#   ('bernardo', 41),
#   ('olimpica', 41),
#   ('katia', 40),
#   ('orgao', 40),
#   ('deputada', 40),
#   ('embora', 40),
#   ('uol', 40),
#   ('impostos', 40),
#   ('prender', 40),
#   ('mao', 40),
#   ('pastor', 40),
#   ('emissora', 40),
#   ('dificil', 40),
#   ('quais', 40),
#   ('investigados', 40),
#   ('fazem', 40),
#   ('viu', 40),
#   ('minutos', 40),
#   ('whatsapp', 40),
#   ('manda', 40),
#   ('cupula', 39),
#   ('continuar', 39),
#   ('dialogo', 39),
#   ('virou', 39),
#   ('evento', 39),
#   ('fizeram', 39),
#   ('presidio', 39),
#   ('cpi', 39),
#   ('destruir', 39),
#   ('hoffmann', 39),
#   ('aeronave', 39),
#   ...]}

# %%
fig, ax = plt.subplots(nrows=2, figsize=(15, 14))

n_most_common = 10

ax[0].bar([plv[0] for plv in all_cnt[0][:n_most_common]], [plv[1] for plv in all_cnt[0][:n_most_common]])
ax[0].set_title('Palavras mais comuns em textos de notícias verdadeiras', fontdict={'size': 16})
ax[0].set_ylim(0, 10000)

ax[1].bar([plv[0] for plv in all_cnt[1][:n_most_common]], [plv[1] for plv in all_cnt[1][:n_most_common]])
ax[1].set_title('Palavras mais comuns em textos de notícias falsas', fontdict={'size': 16})
ax[1].set_ylim(0, 2500)

plt.subplots_adjust(hspace=0.25)

for i in range(2):
    for tick in ax[i].get_xticklabels():
        tick.set_rotation(0)
    padd = [plv[1] for plv in all_cnt[i][:n_most_common]][0] * 0.01
    for j in range(n_most_common):
        ax[i].text(j, all_cnt[i][j][1] + padd, all_cnt[i][j][1], fontsize=14, horizontalalignment="center")

# %%
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer(language='portuguese')

def clean_text(text):
    # Making sure we're dealing with strings and lowering the characters
    text = str(text).lower()
    
    # Stemming tokens
    text = " ".join([stemmer.stem(wrd) for wrd in text.split()])
    
    # Stripping accents
    text = unidecode(text)
    
    # Removing characters that aren't alphanumeric
    text = re.sub(r'[^a-zA-Z0-9 ]', ' ', text)
    
    # Removing tokens that intercalate between letters and digits
    text = re.sub(r'\w*([a-zA-Z][0-9]|[0-9][a-zA-Z])\w*', ' ', text)
    
    # Removing digits
    text = re.sub(r'\d', ' ', text)
    
    # Removing tokens with letters that appear more than twice in a row
    text = re.sub(r'\w*([a-zA-Z])\1{2,}\w*', ' ', text)
    
    # Removing extra spaces
    text = re.sub('\s+', ' ', text)
    
    # Removing words with length equal or lower than 2 or are in STOPWORDS
    return ' '.join([token for token in text.split() if len(token) > 2 and token not in STOPWORDS])

# %%
df['TEXT_CLEAN'] = df['TEXT'].apply(clean_text)
df['TEXT_LEN_CHAR'] = df['TEXT_CLEAN'].apply(str.split).apply(len)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.set_ylim(-100, 4000)
# ax.set_title("Distribuição dos documentos com relação à quantidade de tokens", fontdict={'size': 16})
ax = sns.boxplot(x='FAKE', y='TEXT_LEN_CHAR', data=df)
ax.set_ylabel("Quantidade de tokens")
ax.set_xlabel("Tipo de notícia")
ax.set_xticklabels(["Verdadeira", "Falsa"])
# Out:
# [Text(0, 0, 'Verdadeira'), Text(0, 0, 'Falsa')]

# %%
df_trunc['TEXT_CLEAN'] = df_trunc['TEXT'].apply(clean_text)
df_trunc['TEXT_LEN_CHAR'] = df_trunc['TEXT_CLEAN'].apply(str.split).apply(len)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.set_ylim(-50, 1300)
# ax.set_title("Distribuição dos documentos com relação à quantidade de tokens", fontdict={'size': 16})
ax = sns.boxplot(x='FAKE', y='TEXT_LEN_CHAR', data=df_trunc)
ax.set_ylabel("Quantidade de tokens")
ax.set_xlabel("Tipo de notícia")
ax.set_xticklabels(["Verdadeira", "Falsa"])
# Out:
# [Text(0, 0, 'Verdadeira'), Text(0, 0, 'Falsa')]

# %%
df_trunc['SIMPLE_CLEAN_TEXT'] = df_trunc['TEXT'].apply(simple_clean_text)

# %%
all_cnt = {}
for key in tqdm_notebook(CLASS_DICT):
    cnt = Counter()
    for text in tqdm_notebook(df_trunc[df_trunc['FAKE'] == key]['SIMPLE_CLEAN_TEXT']):
        cnt += Counter(str(text).split())

    all_cnt[key] = cnt.most_common()
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2089), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2089), HTML(value='')))

# %%
fig, ax = plt.subplots(nrows=2, figsize=(15, 14))

n_most_common = 10

ax[0].bar([plv[0] for plv in all_cnt[0][:n_most_common]], [plv[1] for plv in all_cnt[0][:n_most_common]])
ax[0].set_title('Palavras mais comuns em textos de notícias verdadeiras', fontdict={'size': 16})
ax[0].set_ylim(0, 2500)

ax[1].bar([plv[0] for plv in all_cnt[1][:n_most_common]], [plv[1] for plv in all_cnt[1][:n_most_common]])
ax[1].set_title('Palavras mais comuns em textos de notícias falsas', fontdict={'size': 16})
ax[1].set_ylim(0, 2500)

plt.subplots_adjust(hspace=0.25)

for i in range(2):
    for tick in ax[i].get_xticklabels():
        tick.set_rotation(0)
    padd = [plv[1] for plv in all_cnt[i][:n_most_common]][0] * 0.01
    for j in range(n_most_common):
        ax[i].text(j, all_cnt[i][j][1] + padd, all_cnt[i][j][1], fontsize=14, horizontalalignment="center")

# %%
all_cnt = {}
for key in tqdm_notebook(CLASS_DICT):
    cnt = Counter()
    for text in tqdm_notebook(df_calc[df_calc['FAKE'] == key]['SIMPLE_CLEAN_TEXT']):
        cnt += Counter(str(text).split())

    all_cnt[key] = cnt.most_common()
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=615), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=615), HTML(value='')))

# %%
fig, ax = plt.subplots(nrows=2, figsize=(15, 14))

n_most_common = 10

ax[0].bar([plv[0] for plv in all_cnt[0][:n_most_common]], [plv[1] for plv in all_cnt[0][:n_most_common]])
ax[0].set_title('Palavras mais comuns em textos de notícias verdadeiras', fontdict={'size': 16})
ax[0].set_ylim(0, 700)

ax[1].bar([plv[0] for plv in all_cnt[1][:n_most_common]], [plv[1] for plv in all_cnt[1][:n_most_common]])
ax[1].set_title('Palavras mais comuns em textos de notícias falsas', fontdict={'size': 16})
ax[1].set_ylim(0, 700)

plt.subplots_adjust(hspace=0.25)

for i in range(2):
    for tick in ax[i].get_xticklabels():
        tick.set_rotation(0)
        tick.set_fontsize(14)
    padd = [plv[1] for plv in all_cnt[i][:n_most_common]][0] * 0.01
    for j in range(n_most_common):
        ax[i].text(j, all_cnt[i][j][1] + padd, all_cnt[i][j][1], fontsize=14, horizontalalignment="center")

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.set_ylim(-500, 5000)
# ax.set_title("Distribuição dos documentos com relação à quantidade de tokens", fontdict={'size': 16})
ax = sns.boxplot(x='FAKE', y='TEXT_LEN_CHAR', data=df_calc)
ax.set_ylabel("Quantidade de tokens")
ax.set_xlabel("Tipo de notícia")
ax.set_xticklabels(["Verdadeira", "Falsa"])
# Out:
# [Text(0, 0, 'Verdadeira'), Text(0, 0, 'Falsa')]

# %%
# vect = TfidfVectorizer(ngram_range=(1, 2), min_df=5, max_df=0.9)
# features = vect.fit_transform(df_calc['TEXT_CLEAN'])
# from sklearn.feature_selection import chi2
# chi2_res = chi2(features, df_calc['FAKE'])
# vect.vocabulary_
# chi2_res[0]
# chi2_dict = {}

# for i, term in enumerate(vect.vocabulary_):
#     chi2_dict[term] = chi2_res[0][i]

# chi2_dict
# from heapq import nlargest 
# largest = nlargest(10, chi2_dict, key = chi2_dict.get) 
# largest

# %%
from imblearn.under_sampling import RandomUnderSampler

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier

from sklearn.calibration import CalibratedClassifierCV

from sklearn.pipeline import Pipeline

# %%
df_calc
# Out:
#             DATE                                               TEXT  \
# 0     10/12/2018  BOLSONARO Passou o Coaf Pro Moro , serão demit...
# 1     08/12/2018  Te segura aí. Trump tem 267 Bilhões pra Negoci...
# 2     09/12/2018  6 anos vendendo Avon. Chupa Natura!! Lula diz ...
# 3     12/12/2018   “Arma com número de série raspada, filiado ao...
# 4     13/12/2018   Gilmar mendes fica de costas propositadamente...
# 5     13/12/2018  *INDULTO DISFARÇADO PARA SOLTAR LULA, O MAIOR ...
# 6     21/12/2018  INSS cancela benefício de 400 mil pessoas, ido...
# 7     20/12/2018  Ministrão Marco Aurélio e satanás Fidel dono d...
# 8     16/12/2018  Aí está a resposta do porque que 200 “médicos”...
# 9     19/12/2018  O que estava sendo implantado no Brasil é o qu...
# 10    20/12/2018  BRASIL O PARAÍSO PARA OS TERRORISTAS. Aos desa...
# 11    22/12/2018  “JUSTIFICANDO O FIM DA APOSENTADORIA. “Não é j...
# 12    22/12/2018  Pessoal, estou aqui no estado do Tocantins, as...
# 13    21/11/2018  Cotrim Bolsonaro: POR ESSA O GOVERNO, NÃO ESPE...
# 14    23/12/2018  “João de Deus: Tem vinte anos de Filiação ao P...
# 15    24/12/2018  Renan Calheiros é condenado à perda do mandato...
# 16    22/11/2018   Descobriu-se que há 1 Trilhão e meio de Euros...
# 17    27/11/2018  CHINA DIZ QUE AS ÁGUAS BRASILEIRAS AGORA SÃO C...
# 18    23/11/2018  ESTAS FORAM AS CENSURAS DO JORNALISTA PEDRO BI...
# 19    20/11/2018   BOLSONARO MOSTRANDO COMO SE COMBATE A CORRUPÇ...
# 20    24/11/2018  AFINAL, AONDE ESTAVAM VCS ???????????  R E S I...
# 21    25/11/2018  PELO QUE ENTENDI, BOLSONARO CORREU RISCO DE NO...
# 22    02/12/2018  Bolsonaro acaba de ser agredido numa cafeteria...
# 23    30/11/2018  O povo do Rio de janeiro deve dar uma chance a...
# 24    01/12/2018  “Não destinaremos recursos financeiros para o ...
# 25    01/12/2018  Tem esquerdista reclamando que Bolsonaro prest...
# 26    29/11/2018  “Bolsonaro quer que Luciano Huck devolva o din...
# 27    08/12/2018  Militares treinam performance para o dia do po...
# 28    02/12/2018  Pessoal, leia isso: conheço uma pessoa na secr...
# 29    03/12/2018  “TRIPLO A” – O que é? Por que Bolsonaro foi co...
# ...          ...                                                ...
# 1200  08/01/2017  Quatro detentos foram mortos na madrugada dest...
# 1201  18/07/2016  Trata-se, porém, de espaços emblemáticos para ...
# 1202  08/06/2016  A opinião é da socióloga Fátima Pacheco Jordão...
# 1203  07/01/2017  Na semana em que o Brasil registrou duas das m...
# 1204  07/04/2018  “Lula preso amanhã.” A internet, definitivamen...
# 1205  19/09/2017  O presidente dos EUA,  Donald Trump , fez seu ...
# 1206  16/11/2016  Não era a despedida da Europa que Obama espera...
# 1207  04/07/2017  A legislação brasileira permite que qualquer p...
# 1208  09/12/2016  Nas redes sociais a imagem viralizou, e deu mu...
# 1209  30/08/2016  Dilma Rousseff  se dirigiu pela primeira vez, ...
# 1210  09/04/2017  A  greve geral contra a gestão de Mauricio Mac...
# 1211  13/04/2016  A falta de convicção do PP como partido da bas...
# 1212  22/07/2016  Por isso, quem estiver na cidade deve aproveit...
# 1213  31/10/2016  “O Rafael voltou, o Rafael voltou...”, cantava...
# 1214  10/01/2018  O delegado da PF responsável pelo caso, Rubens...
# 1215  03/10/2016  O presidente Juan Manuel Santos aceitou a derr...
# 1216  14/12/2018  O Senado dos EUA se divorciou na quinta-feira ...
# 1217  23/08/2018  Uma primeira leitura das notas técnicas revela...
# 1218  18/03/2018  Na última quinta-feira, 15, embaixo do vão do ...
# 1219  03/03/2016  Não sabemos se dois deputados ou deputadas já ...
# 1220  13/07/2016  Inicialmente o  PSOL  (cuja bancada tem seis d...
# 1221  07/08/2018  O EL PAÍS Brasil inicia nesta segunda-feira su...
# 1222  29/12/2017  O Governo brasileiro publicou nesta sexta-feir...
# 1223  09/09/2016  O ato teve concentração no Largo da Batata, me...
# 1224  26/06/2017  A euforia se instalou nas principais  empresas...
# 1225  05/01/2016  O texto é uma crítica inequívoca à tentativa d...
# 1226  19/04/2017  O  FMI registra a recuperação da economia mund...
# 1227  12/02/2017  A vitória de  Pablo Iglesias  no congresso do ...
# 1228  07/12/2016  O Senado da  Itália  aprovou a lei orçamentári...
# 1229  10/01/2018  Fire and Fury: Inside the Trump White House  (...
#
#                                                   TITLE  FAKE      SOURCE  \
# 0     \n   \t\t\tMoro vai demitir 180 petistas que g...     1  boatos.org
# 1     \n   \t\t\tTrump quer investir R$ 1 trilhão no...     1  boatos.org
# 2     \n   \t\t\tLula disse que dona Marisa ganhou R...     1  boatos.org
# 3     \n   \t\t\tAtirador de Campinas, Euler Fernand...     1  boatos.org
# 4     \n   \t\t\tGilmar Mendes vira de costas na hor...     1  boatos.org
# 5     \n   \t\t\tIndulto de Natal de Temer foi edita...     1  boatos.org
# 6     \n   \t\t\tIdosa chora ao tentar sacar BPC-Loa...     1  boatos.org
# 7     \n   \t\t\tMinistro Marco Aurélio Mello aparec...     1  boatos.org
# 8     \n   \t\t\tPrimeiros 200 médicos cubanos que f...     1  boatos.org
# 9     \n   \t\t\tProjeto Aster, de Dilma e Putin, tr...     1  boatos.org
# 10    \n   \t\t\tCesare Battisti recebia pensão de R...     1  boatos.org
# 11    \n   \t\t\tPaulo Guedes diz que não é justo qu...     1  boatos.org
# 12    \n   \t\t\tFazenda Nossa Senhora Aparecida em ...     1  boatos.org
# 13    \n   \t\t\tCotrim Bolsonaro entrega PEC de ref...     1  boatos.org
# 14    \n   \t\t\tJoão de Deus é filiado ao PT há 20 ...     1  boatos.org
# 15    \n   \t\t\tRenan Calheiros é condenado à perda...     1  boatos.org
# 16    \n   \t\t\tLula tem 1,5 trilhão de euros em co...     1  boatos.org
# 17    \n   \t\t\tChina diz que águas brasileiras são...     1  boatos.org
# 18    \n   \t\t\tPedro Bial diz que redes sociais sã...     1  boatos.org
# 19    \n   \t\t\tGustavo Perrella é nomeado como min...     1  boatos.org
# 20    \n   \t\t\tWilliam Waack endossa texto que cri...     1  boatos.org
# 21    \n   \t\t\tGrupo terrorista planejava jogar bo...     1  boatos.org
# 22    \n   \t\t\tBolsonaro acaba de ser agredido com...     1  boatos.org
# 23    \n   \t\t\tBolsonaro publicou tuíte de apoio a...     1  boatos.org
# 24    \n   \t\t\tPaulo Guedes diz que não dará dinhe...     1  boatos.org
# 25    \n   \t\t\tLula ficou de joelhos para Hugo Chá...     1  boatos.org
# 26    \n   \t\t\tBolsonaro manda Luciano Huck devolv...     1  boatos.org
# 27    \n   \t\t\tVídeo de ensaio da posse de Bolsona...     1  boatos.org
# 28    \n   \t\t\tCurso obrigatório para professores ...     1  boatos.org
# 29    \n   \t\t\tTriplo A está na pauta do Acordo de...     1  boatos.org
# ...                                                 ...   ...         ...
# 1200  Cadeia que “isolava” presos do PCC registra qu...     0     El País
# 1201  Muçulmanos conquistam ruas e praças emblemátic...     0     El País
# 1202  “Políticos jogam xadrez, enquanto o povo joga ...     0     El País
# 1203  “Tinha era que matar mais”, as declarações de ...     0     El País
# 1204                          Lula preso, memes à solta     0     El País
# 1205  Na ONU, Donald Trump ameaça “destruir totalmen...     0     El País
# 1206  Obama: “É preciso estar alerta para o aumento ...     0     El País
# 1207  A luta pelo funk no Senado: a história mais br...     0     El País
# 1208  Foto de Moro e Aécio rindo juntos eletriza as ...     0     El País
# 1209           As frases dos senadores a Dilma Rousseff     0     El País
# 1210                                 Macri, sob pressão     0     El País
# 1211  PP desembarca do Governo e enfraquece ainda ma...     0     El País
# 1212  As fotografias raras de Robert Capa na Guerra ...     0     El País
# 1213  Rafael Greca é eleito e volta à Prefeitura de ...     0     El País
# 1214  Um ano após morte de Teori Zavascki, relatório...     0     El País
# 1215  Santos: “Não me renderei, continuarei buscando...     0     El País
# 1216  Senado desafia Trump e condena herdeiro saudit...     0     El País
# 1217  Governo May prepara britânicos para um Brexit ...     0     El País
# 1218           Marielle e Monica, por todas as famílias     0     El País
# 1219  O polêmico beijo de dois deputados no Congress...     0     El País
# 1220  Erundina: “Enquanto a esquerda não se unir, a ...     0     El País
# 1221  EL PAÍS estreia novas seções fixas para cobert...     0     El País
# 1222  Temer reativa regras para fiscalizar trabalho ...     0     El País
# 1223  Manifestantes vão à casa de Temer em São Paulo...     0     El País
# 1224  Clima de “euforia” nas principais empresas alemãs     0     El País
# 1225  Brasil à Venezuela: “Não há lugar para soluçõe...     0     El País
# 1226                         Recuperação com obstáculos     0     El País
# 1227                          O Podemos se entrincheira     0     El País
# 1228  Senado italiano aprova orçamento, e Renzi prep...     0     El País
# 1229                                 A Casa Branca caiu     0     El País
#
#                                              TEXT_CLEAN  \
# 0     bolsonar pass coaf pro mor demit petist salari...
# 1     segur trump bilho pra negoc govern bolsonar im...
# 2     anos vend avon chup natura lul diz milho inven...
# 3     arm numer seri raspada fili atir indiscrimin l...
# 4     gilm mend fic cost proposit plen execu hin nac...
# 5     indult disfarc par solt lula maior ladra histo...
# 6     inss cancel benefici mil pessoas idos chor fil...
# 7     ministra marc aureli satanas fidel don cubanos...
# 8     respost porqu medicos sair dia par outro brasi...
# 9     estav send implant brasil comec ser implant ve...
# 10    brasil parais par terroristas desavis cesar ba...
# 11    justific fim aposentadoria just idos gast jove...
# 12    pessoal aqu estad tocantins margens fazend mui...
# 13    cotrim bolsonaro governo esperava projet emend...
# 14    joa deus vint anos filiaca explic silenci peti...
# 15    renan calheir conden perd mandat pel var feder...
# 16    descobriu trilha mei euros pertencent noss pai...
# 17    chin diz agu brasileir agor chines quas afund ...
# 18    censur jornal pedr bial facebook red soc perig...
# 19    bolsonar mostr combat corrupcao brasil acim tu...
# 20    afinal aond estav vcs text assin pseudonim bia...
# 21    pel entendi bolsonar corr risc nov atent cheg ...
# 22    bolsonar acab ser agred cafet rio segur estav ...
# 23    pov rio janeir dev dar chanc peza govern par d...
# 24    destin recurs financeir par carnaval par gay m...
# 25    esquerd reclam bolsonar prest continent par as...
# 26    bolsonar quer lucian huck devolv dinheir receb...
# 27    milit trein performanc par dia poss bolsonaro ...
# 28    pessoal lei conhec pesso secret educ dias tev ...
# 29    tripl bolsonar contra seman noss presidente el...
# ...                                                 ...
# 1200  quatr detent mort madrug dest doming rebelia p...
# 1201  trata porem espac emblemat par esquerd setor l...
# 1202  opinia sociolog fatim pachec jordao par sobr m...
# 1203  seman brasil registr duas maior chacin cad his...
# 1204  lul pres amanha internet definitivamente sab l...
# 1205  president eua donald trump fez primeir discurs...
# 1206  desped europ obam esperava lad primeiro minist...
# 1207  legisl brasileir permit qualqu propost consig ...
# 1208  red soc imag viralizou deu munica par aquel cr...
# 1209  dilm rousseff dirig pel primeir vez nest segun...
# 1210  grev geral contr gesta maurici macr frent arge...
# 1211  falt convicca part bas govern hav fic clar com...
# 1212  estiv cidad dev aproveitar negativos form tal ...
# 1213  rafael voltou rafael voltou cant apoiador pref...
# 1214  deleg respons pel caso rubens maleiner encontr...
# 1215  president juan manuel sant aceit derrot sim pl...
# 1216  sen eua divorc quinta feir estrateg donald tru...
# 1217  primeir leitur not tecnic revel problem soluco...
# 1218  ultim quinta feira embaix masp enquant milh pe...
# 1219  sab dois deput deput hav beij boc dependent co...
# 1220  inicial psol cuj banc seis deputados esper pod...
# 1221  pais brasil inic nest segunda feir cobertur es...
# 1222  govern brasileir public nest sexta feir nov po...
# 1223  ato tev concentr larg batata mesm local onde d...
# 1224  eufor instal princip empres alemas dev aument ...
# 1225  text critic inequivoc tentat chavism impugnar ...
# 1226  fmi registr recuper econom mundial faz grand c...
# 1227  vitor pabl igles congress pod encerr nest sab ...
# 1228  sen ital aprov lei orcamentar vot favor contr ...
# 1229  fir and fury insid the trump whit hous fog fur...
#
#                                             TITLE_CLEAN  TEXT_LEN_CHAR  \
# 0               mor vai demit petist ganh mil coaf boat            242
# 1     trump quer invest trilha brasil caus bolsonar ...            190
# 2          lul diss don maris ganh milho vend avon boat            225
# 3           atir campinas eul fern grandolpho fili boat            134
# 4     gilm mend vir cost hor hin nacional mostr vid ...            330
# 5                indult natal edit par tir lul cad boat            581
# 6     idos chor tent sac bpc cancel pel inss mostr f...            838
# 7     ministr marc aureli mell aparec fot fidel cast...            523
# 8            primeir medic cuban embor polic cuban boat            105
# 9     projet aster dilm putin trar exercit russ ufa ...            354
# 10            cesar battist receb pensa mil brasil boat            192
# 11      paul gued diz just idos gast jovens produz boat            226
# 12    fazend noss senhor aparec barroland president ...            763
# 13    cotrim bolsonar entreg pec reform congress mil...           1059
# 14                 joa deus fili anos mil mes part boat            165
# 15                renan calheir conden perd mandat boat            586
# 16                   lul trilha eur cont banc suic boat           1054
# 17    chin diz agu brasileir chines apos acord dilm ...            556
# 18    pedr bial diz red soc perig porqu pod direit boat            190
# 19      gustav perrell nom ministr esport bolsonar boat            275
# 20    will waack endoss text critic resistencia cont...            430
# 21    grup terror planej jog bomb bolsonaro mostr vi...            532
# 22    bolsonar acab ser agred tap cafet rio janeir boat            436
# 23             bolsonar public tuit apoi peza aeci boat            138
# 24    paul gued diz dar dinheir par carnaval par gay...            227
# 25    lul fic joelh par hug chavez evo morales mostr...            397
# 26    bolsonar mand lucian huck devolv milho lei rou...            778
# 27    vid ensai poss bolsonar mostr sold faz bandeir...            121
# 28    curs obrigatori par professor ensin atrapalh g...            554
# 29             tripl paut acord par cop ser brasil boat            756
# ...                                                 ...            ...
# 1200     cad isolava pres pcc registr quatr mort manaus           1437
# 1201      muculman conquist ruas prac emblemat par laic           1412
# 1202              polit jog xadrez enquant pov jog dama           1490
# 1203                        tinh mat declar seman pavor           1371
# 1204                                 lul preso mem solt           1343
# 1205      onu donald trump ameac destru total cor norte           1397
# 1206  obama precis estar alert par aument nacional e...           1395
# 1207  lut pel funk senado histor brasileir nunc contada           1420
# 1208  fot mor aeci rind junt eletriz red plen caos pais           1338
# 1209                         fras senador dilm rousseff           1459
# 1210                                   macri sob pressa           1452
# 1211           desembarc govern enfraquec aind dilm cam           1408
# 1212  fotograf rar robert cap guerr civil espanhol paul           1383
# 1213  rafael grec eleit volt prefeitur curitib apos ...           1378
# 1214  ano apos mort teor zavascki relatori parcial d...           1431
# 1215                   santos renderei continu busc paz           1371
# 1216  sen desaf trump conden herdeir saudit mort jornal           1428
# 1217          govern may prep britan par brexit drastic           1487
# 1218                           mariell monica tod famil           1424
# 1219            polem beij dois deput congress espanhol           1389
# 1220  erundina enquant esquerd unir direit ser inven...           1450
# 1221     pais estre nov seco fix par cobertur eleitoral           1476
# 1222  reativ regr par fiscaliz trabalh escravo falt ...           1480
# 1223                manifest cas paul terceir ato seman           1401
# 1224                 clim euforia princip empres alemas           1425
# 1225  brasil venezuela lug par soluco institucionali...           1587
# 1226                                   recuper obstacul           1507
# 1227                                    pod entrincheir           1463
# 1228       sen italian aprov orcamento renz prep renunc           1475
# 1229                                     cas branc caiu           1433
#
#       TEXT_LEN_TOKEN  TITLE_LEN_CHAR  TITLE_LEN_TOKEN MONTH_YEAR  \
# 0                 38              39                8    12/2018
# 1                 31              50                8    12/2018
# 2                 41              44                9    12/2018
# 3                 20              43                7    12/2018
# 4                 50              50               10    12/2018
# 5                 96              38                8    12/2018
# 6                130              53               11    12/2018
# 7                 80              52                9    12/2018
# 8                 18              42                7    12/2018
# 9                 59              57               10    12/2018
# 10                31              41                7    12/2018
# 11                31              47                9    12/2018
# 12               128              54                8    12/2018
# 13               160              63                9    11/2018
# 14                28              36                8    12/2018
# 15                87              37                6    12/2018
# 16               175              34                7    11/2018
# 17                91              50                9    11/2018
# 18                30              49               10    11/2018
# 19                46              47                7    11/2018
# 20                73              61                9    11/2018
# 21                80              52                9    11/2018
# 22                71              49                9    12/2018
# 23                23              40                7    11/2018
# 24                33              57               11    12/2018
# 25                60              55               11    12/2018
# 26               118              61               10    11/2018
# 27                18              58               10    12/2018
# 28                87              65                9    12/2018
# 29               113              40                8    12/2018
# ...              ...             ...              ...        ...
# 1200             216              46                8    01/2017
# 1201             216              45                7    07/2016
# 1202             216              37                7    06/2016
# 1203             216              27                5    01/2017
# 1204             216              18                4    04/2018
# 1205             216              45                8    09/2017
# 1206             216              51                8    11/2016
# 1207             216              49                8    07/2017
# 1208             217              49               10    12/2016
# 1209             217              26                4    08/2016
# 1210             217              16                3    04/2017
# 1211             217              40                6    04/2016
# 1212             217              49                8    07/2016
# 1213             217              50                8    10/2016
# 1214             217              60                9    01/2018
# 1215             217              32                5    10/2016
# 1216             217              49                8    12/2018
# 1217             218              41                7    08/2018
# 1218             218              24                4    03/2018
# 1219             218              39                6    03/2016
# 1220             218              51                7    07/2016
# 1221             218              46                8    08/2018
# 1222             218              58                9    12/2017
# 1223             219              35                6    09/2016
# 1224             219              34                5    06/2017
# 1225             219              50                6    01/2016
# 1226             219              16                2    04/2017
# 1227             220              15                2    02/2017
# 1228             220              44                7    12/2016
# 1229             220              14                3    01/2018
#
#                                       SIMPLE_CLEAN_TEXT
# 0     bolsonaro passou coaf pro moro demitidos petis...
# 1     segura trump bilhoes negociar governo bolsonar...
# 2     anos vendendo avon chupa natura lula diz milho...
# 3     arma numero serie raspada filiado atirando ind...
# 4     gilmar mendes fica costas propositadamente ple...
# 5     indulto disfarcado soltar lula maior ladrao hi...
# 6     inss cancela beneficio mil pessoas idosa chora...
# 7     ministrao marco aurelio satanas fidel dono cub...
# 8     resposta porque medicos sairam dia outro brasi...
# 9     sendo implantado brasil comecou implantado ven...
# 10    brasil paraiso terroristas desavisados cesare ...
# 11    justificando fim aposentadoria justo idosos ga...
# 12    pessoal aqui estado tocantins margens fazenda ...
# 13    cotrim bolsonaro governo esperava projeto emen...
# 14    joao deus vinte anos filiacao explicado silenc...
# 15    renan calheiros condenado perda mandato vara f...
# 16    descobriu trilhao meio euros pertencentes pais...
# 17    china diz aguas brasileiras agora chinesas qua...
# 18    censuras jornalista pedro bial facebook redes ...
# 19    bolsonaro mostrando combate corrupcao brasil a...
# 20    afinal aonde vcs texto assinado pseudonimo bia...
# 21    entendi bolsonaro correu risco novo atentado c...
# 22    bolsonaro acaba agredido cafeteria rio seguran...
# 23    povo rio janeiro deve dar chance pezao governa...
# 24    destinaremos recursos financeiros carnaval par...
# 25    esquerdista reclamando bolsonaro prestou conti...
# 26    bolsonaro quer luciano huck devolva dinheiro r...
# 27    militares treinam performance dia posse bolson...
# 28    pessoal leia conheco pessoa secretaria educaca...
# 29    triplo bolsonaro contra semana presidente elei...
# ...                                                 ...
# 1200  quatro detentos mortos madrugada deste domingo...
# 1201  trata porem espacos emblematicos esquerda seto...
# 1202  opiniao sociologa fatima pacheco jordao sobre ...
# 1203  semana brasil registrou duas maiores chacinas ...
# 1204  lula preso amanha internet definitivamente sab...
# 1205  presidente eua donald trump fez primeiro discu...
# 1206  despedida europa obama esperava lado primeiro ...
# 1207  legislacao brasileira permite qualquer propost...
# 1208  redes sociais imagem viralizou deu municao cri...
# 1209  dilma rousseff dirigiu primeira vez nesta segu...
# 1210  greve geral contra gestao mauricio macri frent...
# 1211  falta conviccao partido base governo havia fic...
# 1212  cidade deve aproveitar negativos formam tal va...
# 1213  rafael voltou rafael voltou cantavam apoiadore...
# 1214  delegado responsavel caso rubens maleiner enco...
# 1215  presidente juan manuel santos aceitou derrota ...
# 1216  senado eua divorciou quinta feira estrategia d...
# 1217  primeira leitura notas tecnicas revela problem...
# 1218  ultima quinta feira embaixo vao masp enquanto ...
# 1219  sabemos dois deputados deputadas haviam beijad...
# 1220  inicialmente psol cuja bancada seis deputados ...
# 1221  pais brasil inicia nesta segunda feira cobertu...
# 1222  governo brasileiro publicou nesta sexta feira ...
# 1223  ato concentracao largo batata local onde domin...
# 1224  euforia instalou principais empresas alemas de...
# 1225  texto critica inequivoca tentativa chavismo im...
# 1226  fmi registra recuperacao economia mundial faz ...
# 1227  vitoria pablo iglesias congresso podemos encer...
# 1228  senado italia aprovou lei orcamentaria votos f...
# 1229  fire and fury inside the trump white house fog...
#
# [1230 rows x 13 columns]

# %%
pipe = Pipeline(
    [('vect', TfidfVectorizer(ngram_range=(1, 2), min_df=5, max_df=0.9)),
     ('clf', CalibratedClassifierCV(LinearSVC()))]
)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_calc['TEXT_CLEAN'], df_calc['FAKE'])

# %%
pipe.fit(X_train, y_train)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Pipeline(memory=None,
#          steps=[('vect',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=0.9, max_features=None,
#                                  min_df=5, ngram_range=(1, 2), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, use_idf=True,
#                                  vocabulary=None)),
#                 ('clf',
#                  CalibratedClassifierCV(base_estimator=LinearSVC(C=1.0,
#                                                                  class_weight=None,
#                                                                  dual=True,
#                                                                  fit_intercept=True,
#                                                                  intercept_scaling=1,
#                                                                  loss='squared_hinge',
#                                                                  max_iter=1000,
#                                                                  multi_class='ovr',
#                                                                  penalty='l2',
#                                                                  random_state=None,
#                                                                  tol=0.0001,
#                                                                  verbose=0),
#                                         cv='warn', method='sigmoid'))],
#          verbose=False)

# %%
y_pred = pipe.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94       162
#            1       0.92      0.96      0.94       146
#
#     accuracy                           0.94       308
#    macro avg       0.94      0.94      0.94       308
# weighted avg       0.94      0.94      0.94       308

# %%
y_pred = pipe.predict(df['TEXT_CLEAN'])

# %%
print(classification_report(df['FAKE'], y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      6088
#            1       0.75      0.99      0.85       615
#
#     accuracy                           0.97      6703
#    macro avg       0.87      0.98      0.92      6703
# weighted avg       0.98      0.97      0.97      6703

# %%
print(confusion_matrix(df['FAKE'], y_pred))
# Out:
# [[5881  207]
#  [   6  609]]

# %%
data = {'TEXT': [], 'FAKE': []}

for i, item in enumerate(tqdm_notebook(sorted(glob('../data/processed/corpus_usp/size_normalized_texts/fake/*'), key=lambda x: int(re.findall('\d+', x)[0])))):
    
    if '../data/processed/corpus_usp/full_texts/fake-meta-information\\{}-meta.txt'.format(i + 1) not in glob('../data/processed/corpus_usp/full_texts/fake-meta-information/*'):
        continue
    
    with open('../data/processed/corpus_usp/full_texts/fake-meta-information/{}-meta.txt'.format(i + 1), 'r', encoding="utf8") as f:
        if f.read().split('\n')[2] != 'politica':
            continue

    with open(item, 'r', encoding="utf8") as f:
        data['TEXT'].append(f.read())
        data['FAKE'].append(1)
# Out:
# HBox(children=(IntProgress(value=0, max=3600), HTML(value='')))

# %%
for i, item in enumerate(tqdm_notebook(sorted(glob('../data/processed/corpus_usp/size_normalized_texts/true/*'), key=lambda x: int(re.findall('\d+', x)[0])))):
    
    if '../data/processed/corpus_usp/full_texts/true-meta-information\\{}-meta.txt'.format(i + 1) not in glob('../data/processed/corpus_usp/full_texts/true-meta-information/*'):
        continue
    
    with open('../data/processed/corpus_usp/full_texts/true-meta-information/{}-meta.txt'.format(i + 1), 'r', encoding="utf8") as f:
        if f.read().split('\n')[2] != 'politica':
            continue

    with open(item, 'r', encoding="utf8") as f:
        data['TEXT'].append(f.read())
        data['FAKE'].append(0)
# Out:
# HBox(children=(IntProgress(value=0, max=3600), HTML(value='')))

# %%
df = pd.DataFrame(data)

# %%
with open('data/df_usp_clean.pkl', 'wb') as f:
    pkl.
# Out:
#                                                    TEXT  FAKE  \
# 0     Kátia Abreu diz que vai colocar sua expulsão e...     1
# 1     Alckmin diz que por ele PSDB “desembarca”, mas...     1
# 2     Cara de pau não tem limites: Zé Celso aciona M...     1
# 3     Temer resolve o problema de Luislinda: “liberd...     1
# 4     Moro está certo ao não se arrepender de divulg...     1
# 5     Hoje completou um ano da morte de um dos psico...     1
# 6     Palocci vai contar que Lula pagou propina a ex...     1
# 7     Dr. Ray peita Bolsonaro, chama-o de “conservad...     1
# 8     Garotinho ganha prêmio após teatro sobre “surr...     1
# 9     Dilma finge solidariedade a Katia Abreu mas nã...     1
# 10    Gilmar Mendes age como masoquista ao permitir ...     1
# 11    Raquel Dodge faz o que Janot não fazia: pediu ...     1
# 12    Garotinho se supera no teatro ao chutar parede...     1
# 13    Kátia Abreu conseguiu a proeza de ter uma biog...     1
# 14    Joesley chorou ao entrar na cela e está sem co...     1
# 15    O partido mais corrupto do Brasil não é o PT. ...     1
# 16    Malafaia chama eleitores de Bolsonaro de gays ...     1
# 17    Bolsonaro vai militarizar todas as escolas do ...     1
# 18    Maria do Rosário pode tirar Bolsonaro da dispu...     1
# 19    ‘O próximo presidente será de centro-direita’,...     1
# 20    Marido de Dilma acaba de morrer. Será que mata...     1
# 21    Sobrinho atira no tio após galinhas comerem se...     1
# 22    Temer está articulando a candidatura de Dória ...     1
# 23    Deputada Maria do Rosário é intimada pelo STF ...     1
# 24    Ciro Gomes ataca Bolsonaro, Dória, Dilma e Lul...     1
# 25    João Dória está deixando o PSDB, saiba qual se...     1
# 26    Movimento “Ovos na Cara” é a versão atualizada...     1
# 27    “Deus mandou votar a favor de Temer”, disseram...     1
# 28    Deputada chamada de gostosa no plenário vai pr...     1
# 29    Temer vai punir Sergio Reis e Tiririca por tra...     1
# ...                                                 ...   ...
# 4148  Segunda-feira, 18 de dezembro de 2017. Boa noi...     0
# 4149  Zara Larsson junta dance pop e feminismo: Qual...     0
# 4150  FGTS: Temer anuncia liberação para saque de co...     0
# 4151  Justiça condena advogado a mais de 60 anos de ...     0
# 4152  Em propaganda partidária veiculada anteontem n...     0
# 4153  Quinta-feira, 9 de novembro. Bom dia! Aqui est...     0
# 4154  Não vai parar, diz delegado em BO de junho de ...     0
# 4155  Gerações têm visões distintas de Fidel. Pai, f...     0
# 4156  Líderes dos caminhoneiros grevistas vão a Bras...     0
# 4157  O avanço de Kim. Por um grande paradoxo, sançõ...     0
# 4158  Na contramão do setor, construtora de Ribeirão...     0
# 4159  Peritos afirmam que partes importantes da grav...     0
# 4160  Foi para se livrar das pressões de parlamentar...     0
# 4161  Gosto quando dizem que sou caso de marketing: ...     0
# 4162  Aposentado mineiro baleado em protesto contra ...     0
# 4163  Entenda a crise política no Paraguai após apro...     0
# 4164  Não dá para culpar militares se intervenção no...     0
# 4165  Em SP, Obama diz que Coreia do Norte é perigo ...     0
# 4166  Como celulares roubados no carnaval são desblo...     0
# 4167  O duplamente covarde atentado terrorista do Es...     0
# 4168  Governo corta R$ 42 bi em gastos e eleva impos...     0
# 4169  Hamas convoca nova intifada após anúncio de Tr...     0
# 4170  PF vê indícios de organização criminosa em inv...     0
# 4171  A defesa de Aécio Neves exigiu que o STF afast...     0
# 4172  Ficou longe das notícias no fim de ano? Veja o...     0
# 4173  A nova denúncia contra o ex-presidente Luiz In...     0
# 4174  Como a Bahia virou uma potência mundial do mar...     0
# 4175  Alvo da Lava Jato, Bendine tinha passagem comp...     0
# 4176  Chefs convidados do Encontro Mundial das Cidad...     0
# 4177  As lições de educação moral e cívica, que o ba...     0
#
#                                              CLEAN_TEXT
# 0     kat abreu diz vai coloc expulsa moldura par re...
# 1     alckmin diz psdb desembarca explic utiliz apar...
# 2     car pau limites cels acion contr silvi santos ...
# 3     resolv problem luislinda liberdade aind tardia...
# 4     mor cert arrepend divulg audi lul dilma vir he...
# 5     hoj complet ano mort psicopat repuls atual fid...
# 6     palocc vai cont lul pag propin president peru ...
# 7     ray peit bolsonaro chama conserv fake entrev d...
# 8     garotinh ganh premi apos teatr sobr surr cadei...
# 9     dilm fing solidariedad kat abreu conv par pres...
# 10    gilm mend age masoqu permit mill fiqu silenci ...
# 11    raquel dodg faz janot fazia ped prisa senador ...
# 12    garotinh sup teatr chut pared fing lesion cade...
# 13    kat abreu consegu proez ter biograf manch peti...
# 14    joesley chor entrar cel tom banho delator joes...
# 15    part corrupt brasil vej part denunc pel pgr co...
# 16    malafa cham eleitor bolsonar gays enrustidos p...
# 17    bolsonar vai militariz tod escol brasil anos b...
# 18    mar rosari pod tir bolsonar disput eleitoral n...
# 19    proxim president ser centro direita diz cienti...
# 20    mar dilm acab morrer ser mataram dilm desesper...
# 21    sobrinh atir tio apos galinh pes maconha cuida...
# 22    articul candidatur dor par president pmdb pres...
# 23    deput mar rosari intim pel stf process bolsona...
# 24    cir gom atac bolsonaro doria dilm lula cir gom...
# 25    joa dor deix psdb saib ser nov partido joa dor...
# 26    moviment cara versa atualiz moviment car pinta...
# 27    deus mand vot favor temer diss deput evangelic...
# 28    deput cham gostos plenari vai process deput ta...
# 29    vai pun sergi reis tirir traicao sergi reis ti...
# ...                                                 ...
# 4148  segunda feira dezembr boa noite aqu princip no...
# 4149  zar larsson junt danc pop feminismo necess fic...
# 4150  fgts anunc liber par saqu cont inativas cont i...
# 4151  justic conden advog anos prisa fraud milhoes s...
# 4152  propagand partidar veicul anteont televisao ra...
# 4153  quinta feira novembro bom dia aqu princip noti...
# 4154  vai parar diz deleg junh hom ejacul mulh onibu...
# 4155  geraco viso distint fidel pai filh net enxerg ...
# 4156  lid caminhoneir grevist brasil par inic dialog...
# 4157  avanc kim grand paradoxo sanco eficaz contr re...
# 4158  contrama setor construtor rib pret rev process...
# 4159  perit afirm part import gravaca joesley editad...
# 4160  par livr presso parlament gast ano eleitoral g...
# 4161  gost quand diz cas marketing minut presenc ani...
# 4162  aposent mineir bal protest contr sai uti carl ...
# 4163  entend cris polit paragua apos aprov reeleica ...
# 4164  par culp milit intervenca rio der errado diz m...
# 4165  obam diz cor nort perig real defend uso diplom...
# 4166  celul roub carnaval desbloqu desov feir rolo f...
# 4167  dupl covard atent terror estad islam ramblas b...
# 4168  govern cort gast elev impost sobr folh pagamen...
# 4169  ham convoc nov intif apos anunci trump sobr je...
# 4170  indici organiz crimin investig sobr pmdb camar...
# 4171  defes aeci nev exig stf afast edson fachin rel...
# 4172  fic long notic fim ano vej acontec brasil mund...
# 4173  nov denunc contr president luiz inaci lul silv...
# 4174  bah vir potenc mundial marketing politico refe...
# 4175  alvo lav jato bendin tinh passag compr par por...
# 4176  chefs convid encontr mundial cidad criativ fic...
# 4177  lico educ moral civica bamb abat joesley batis...
#
# [4178 rows x 3 columns]

# %%
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from unidecode import unidecode

STOPWORDS = set(unidecode(sw) for sw in stopwords.words('portuguese'))

# %%
stemmer = SnowballStemmer(language='portuguese')

def clean_text(text):
    # Making sure we're dealing with strings and lowering the characters
    text = str(text).lower()
    
    # Stemming tokens
    text = " ".join([stemmer.stem(wrd) for wrd in text.split()])
    
    # Stripping accents
    text = unidecode(text)
    
    # Removing characters that aren't alphanumeric
    text = re.sub(r'[^a-zA-Z0-9 ]', ' ', text)
    
    # Removing tokens that intercalate between letters and digits
    text = re.sub(r'\w*([a-zA-Z][0-9]|[0-9][a-zA-Z])\w*', ' ', text)
    
    # Removing digits
    text = re.sub(r'\d', ' ', text)
    
    # Removing tokens with letters that appear more than twice in a row
    text = re.sub(r'\w*([a-zA-Z])\1{2,}\w*', ' ', text)
    
    # Removing extra spaces
    text = re.sub('\s+', ' ', text)
    
    # Removing words with length equal or lower than 2 or are in STOPWORDS
    return ' '.join([token for token in text.split() if len(token) > 2 and token not in STOPWORDS])

# %%
for i, row in tqdm_notebook(df.iterrows(), total=len(df)):
    df.loc[i, 'CLEAN_TEXT'] = clean_text(row['TEXT'])
# Out:
# HBox(children=(IntProgress(value=0, max=4178), HTML(value='')))

# %%
y_pred = pipe.predict(df['CLEAN_TEXT'])

# %%
print(classification_report(df['FAKE'], y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.65      0.71      2089
#            1       0.70      0.82      0.75      2089
#
#     accuracy                           0.73      4178
#    macro avg       0.74      0.73      0.73      4178
# weighted avg       0.74      0.73      0.73      4178

# %%
print(confusion_matrix(df['FAKE'], y_pred))
# Out:
# [[1358  731]
#  [ 384 1705]]

# %%
y_pred_proba = pipe.predict_proba(df['CLEAN_TEXT'])

# %%
y_test_wproba = []
y_pred_wproba = []
threshold = 0.99

for i, item in enumerate(y_pred):
    if y_pred_proba[i].max() > threshold:
        y_test_wproba.append(df['FAKE'][i])
        y_pred_wproba.append(y_pred[i])

# %%
print(classification_report(y_test_wproba, y_pred_wproba))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97        74
#            1       0.98      0.99      0.99       171
#
#     accuracy                           0.98       245
#    macro avg       0.98      0.97      0.98       245
# weighted avg       0.98      0.98      0.98       245

# %%
len(y_pred_wproba) / len(y_pred)
# Out:
# 0.058640497845859264

# %%
# fig, ax = plt.subplots(2, 1, figsize=(10, 20))
# fig.subplots_adjust(top=1.4)
# for i, cls in enumerate(CLASS_DICT):
# #     n_bins = 2 * len(set(df[df['FAKE'] == cls]['TEXT_LEN_TOKEN'].apply(lambda x: round(x / 100) * 100)))
# #     n_bins = 50
# #     x_min = math.floor(min(df[df['FAKE'] == cls]['TEXT_LEN_TOKEN']) / 100) * 100
# #     x_max = math.ceil(max(df[df['FAKE'] == cls]['TEXT_LEN_TOKEN']) / 100) * 100
#     x_min = 0
#     x_max = 500
# #     x_step = int(math.pow(10, math.ceil(math.log(math.floor((x_max - x_min) / 100), 10))))
#     print(x_step)
# #     ax[i].set(xlim=(x_min, x_max))
# #     ax[i].hist(df[df['FAKE'] == cls]['TEXT_LEN_TOKEN'], bins=n_bins, align='mid')
#     ax[i].hist(df[df['FAKE'] == cls]['TEXT_LEN_TOKEN'], align='mid')
# #     ax[i].set_xticklabels(range(x_min, x_max, x_step), rotation=90)
    
#     ax[i].set_title('Tamanho do Corpus - {}'.format(cls))
#     ax[i].set_xlabel('Número de tokens (por documento)');
#     ax[i].set_ylabel('Número total de documentos');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-dc543f72c1ff> in <module>
#       9     x_max = 500
#      10 #     x_step = int(math.pow(10, math.ceil(math.log(math.floor((x_max - x_min) / 100), 10))))
# ---> 11     print(x_step)
#      12 #     ax[i].set(xlim=(x_min, x_max))
#      13 #     ax[i].hist(df[df['FAKE'] == cls]['TEXT_LEN_TOKEN'], bins=n_bins, align='mid')
#
# NameError: name 'x_step' is not defined
