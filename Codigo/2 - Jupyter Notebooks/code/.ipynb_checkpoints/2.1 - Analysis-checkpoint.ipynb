# %% [markdown]
# # Analysis of the primary dataset

# %%
import pickle as pkl
import seaborn as sns
import matplotlib.pyplot as plt
import re
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import math

from tqdm import tqdm_notebook
from collections import Counter
from glob import glob
from unidecode import unidecode
from nltk.corpus import stopwords
from datetime import datetime

import utils

# %matplotlib inline

sns.set(style="darkgrid")

# %%
PATH = '../'

PROCESSED_DATA_PATH = os.path.join(PATH, 'data/processed/')

DF_FAKE_PATH = os.path.join(PROCESSED_DATA_PATH, 'df_fake_clean.pkl')
DF_LEGIT_PATH = os.path.join(PROCESSED_DATA_PATH, 'df_legit_clean.pkl')

STOPWORDS = utils.get_stopwords()

CLASS_DICT = {
    0: 'Notícias verdadeiras',
    1: 'Notícias falsas'
}

# %%
df_fake = pkl.load(open(DF_FAKE_PATH, 'rb'))

df_legit = pkl.load(open(DF_LEGIT_PATH, 'rb'))

df = pd.concat((df_fake, df_legit), axis=0)

# %%
df
# Out:
#              DATE                                               TEXT  \
# 0      20/09/2019  “bolsonaro demite presidente da caixa e exige ...
# 1      25/09/2019  Todo mundo tinha certeza, inclusive quem era o...
# 2      06/10/2019  700 empresas do Japão querem investir no Brasi...
# 3      07/10/2019   Torre Eiffel vermelha em homenagem ao mais no...
# 4      08/10/2019  Atenção! O STF proibiu a circulação do livro d...
# 5      12/10/2019  Este homem enganou milhões de brasileiros. Sér...
# 6      14/10/2019  “A HORA QUE A MÃO DE DEUS PESAR Dizem que essa...
# 7      14/10/2019  *EX-SENADOR PELO PT, LINDENBERG FARIAS, É FLAG...
# 8      15/10/2019  “Bom mesmo era o Sarney, que fazia o discurso ...
# 9      03/10/2019  “Eu tô do lado do capitão cueca, que foi pego ...
# 10     15/10/2019  LULA VAI SER PAI!! NOVO MOTIVO PODE FAZER LULA...
# 11     05/10/2019  Dilminha é gente como a gente!!! Dilma pede a ...
# 12     16/10/2019  Vice diretora de coordenação Regional do PT de...
# 13     15/10/2019  “Um paciente com câncer custa muito caro para ...
# 14     19/09/2019  Mensagem no WhatsApp: A CASA CAIU!!! FRAUDE NA...
# 15     29/08/2019  URGENTE: Nosso Valente Ministro Ricardo Salles...
# 16     04/10/2019  A chapa tá esquentando para o STF, intervenção...
# 17     22/09/2019  Novidade da pior espécie. O STF liberou um “ga...
# 18     26/08/2019  COMO PARTE DA AMAZÔNIA FOI VENDIDA PARA OUTROS...
# 19     31/08/2019  *URGENTE!!!*  Decisão do TSE determinou a reti...
# 20     07/10/2019  Lula está com depressão e tem crises de choro ...
# 21     29/08/2019  Lista de assinaturas no documento encaminhado ...
# 22     03/09/2019  ALGUÉM PODE ME DIZER AE ISSO É REAL M… infanti...
# 23     05/09/2019  DA SÉRIE CURIOSIDADES CURIOSAS: O que está por...
# 24     06/09/2019  Escutem o que Alfredo Léo um dos maiores anali...
# 25     27/08/2019  “A AMAZÔNIA É DO BRASIL! O vice-presidente Mou...
# 26     30/08/2019  Bolsonaro culpa Marcelo D2 por fumaça na Amazô...
# 27     27/08/2019  Nossa senhora, merece ser morto esse b****** ?...
# 28     30/08/2019  É claro como água mas nem todos entendem. A de...
# 29     13/09/2019  “FAZENDA GRENDENE (do Lula Safado) Comprada do...
# ...           ...                                                ...
# 15675  31/05/2019   A Mesa Diretora do Senado, comandada por Rena...
# 15676  31/05/2019   O plenário do Supremo Tribunal Federal (STF) ...
# 15677  31/05/2019   A presidente do Supremo Tribunal Federal (STF...
# 15678  31/05/2019   O presidente do Senado, Renan Calheiros (PMDB...
# 15679  31/05/2019   A Câmara dos Deputados aprovou nesta terça-fe...
# 15680  31/05/2019   O ministro Marco Aurélio Mello tratou com iro...
# 15681  31/05/2019   O procurador-geral da República, Rodrigo Jano...
# 15682  31/05/2019   Depois de se recusar, na noite de segunda-fei...
# 15683  31/05/2019   O ministro Marco Aurélio Mello, do Supremo Tr...
# 15684  31/05/2019   A presidente do Supremo Tribunal Federal (STF...
# 15685  31/05/2019   A força-tarefa formada por procuradores da Op...
# 15686  31/05/2019   Formado em direito pela Universidade Federal ...
# 15687  31/05/2019   O presidente da Câmara dos Deputados, Rodrigo...
# 15688  31/05/2019   Confira abaixo como foi a repercussão polític...
# 15689  31/05/2019   Além de processar e punir os corruptos, os pr...
# 15690  31/05/2019   O ministro do Supremo Tribunal Federal (STF) ...
# 15691  31/05/2019   As manifestações a favor da Operação Lava Jat...
# 15692  31/05/2019   Após o Supremo Tribunal Federal (STF)  tornar...
# 15693  31/05/2019   O senador Roberto Requião (PMDB-PR), relator ...
# 15694  31/05/2019   O presidente da Câmara, Rodrigo Maia (DEM-RJ)...
# 15695  31/05/2019   O presidente Michel Temer lamentou neste domi...
# 15696  31/05/2019   O presidente do Senado, Renan Calheiros (PMDB...
# 15697  31/05/2019   A assessoria do presidente da Câmara, Rodrigo...
# 15698  31/05/2019   Um grupo de senadores apresentou nesta quinta...
# 15699  31/05/2019   O presidente nacional da Ordem dos Advogados ...
# 15700  31/05/2019   O presidente do Senado, Renan Calheiros (PMDB...
# 15701  31/05/2019   O governador de Santa Catarina, Raimundo Colo...
# 15702  31/05/2019   O presidente do Senado, Renan Calheiros (PMDB...
# 15703  31/05/2019   O ministro Luiz Edson Fachin, do Supremo Trib...
# 15704  31/05/2019   O governo federal publicou nesta quarta-feira...
#
#                                                    TITLE  FAKE      SOURCE  \
# 0      \n   \t\t\tBolsonaro demite presidente da Caix...     1  boatos.org
# 1      \n   \t\t\tMarcos Valério grava áudio falando ...     1  boatos.org
# 2      \n   \t\t\t700 empresas querem investir no Bra...     1  boatos.org
# 3      \n   \t\t\tTorre Eiffel ficou vermelha em home...     1  boatos.org
# 4      \n   \t\t\tSTF proíbe venda de livro escrito p...     1  boatos.org
# 5      \n   \t\t\tCapa da Veja diz que Sérgio Moro en...     1  boatos.org
# 6      \n   \t\t\tLoja de Luciano Huck lança camiseta...     1  boatos.org
# 7      \n   \t\t\tLindbergh Farias é flagrado compran...     1  boatos.org
# 8      \n   \t\t\tJosé Sarney fez discurso na ONU fal...     1  boatos.org
# 9      \n   \t\t\tDeputado José Guimarães já foi pres...     1  boatos.org
# 10     \n   \t\t\tLula vai ser pai: Rosângela Silva, ...     1  boatos.org
# 11     \n   \t\t\tDilma pede a Michelle Bolsonaro pot...     1  boatos.org
# 12     \n   \t\t\tVice-diretora do PT de Porto Alegre...     1  boatos.org
# 13     \n   \t\t\tBolsonaro diz que paciente com cânc...     1  boatos.org
# 14     \n   \t\t\tAssessor do PT que ganhou na Mega-S...     1  boatos.org
# 15     \n   \t\t\tRicardo Salles foi envenenado, víti...     1  boatos.org
# 16     \n   \t\t\tFilho de Janot que mora em Portugal...     1  boatos.org
# 17     \n   \t\t\tLula tem um gabinete dentro da PF e...     1  boatos.org
# 18     \n   \t\t\tAmazônia já foi vendida pelo Brasil...     1  boatos.org
# 19     \n   \t\t\tTSE acaba de censurar comentário de...     1  boatos.org
# 20     \n   \t\t\tLula está com depressão e tem crise...     1  boatos.org
# 21     \n   \t\t\tPT e PSOL assinaram documento que p...     1  boatos.org
# 22     \n   \t\t\tPrefeitura de Fortaleza cria cartil...     1  boatos.org
# 23     \n   \t\t\tRaoni Metukire mora na França, é do...     1  boatos.org
# 24     \n   \t\t\tAlfredo Léo, diretor da XP, falou, ...     1  boatos.org
# 25     \n   \t\t\tMourão vai à Amazônia (área militar...     1  boatos.org
# 26     \n   \t\t\tBolsonaro culpa Marcelo D2 por incê...     1  boatos.org
# 27     \n   \t\t\tPrefeito de Parauapebas (PA) é flag...     1  boatos.org
# 28     \n   \t\t\tFunai suspende venda de terra indíg...     1  boatos.org
# 29     \n   \t\t\tFazenda Grendene foi comprada por L...     1  boatos.org
# ...                                                  ...   ...         ...
# 15675  Senado pede ao STF que anule ação sobre réus n...     0          G1
# 15676  STF começa a julgar afastamento de Renan da pr...     0          G1
# 15677  Cármen diz que pautará caso de Renan com urgên...     0          G1
# 15678  Após ser afastado do comando do Senado, Renan ...     0          G1
# 15679  Câmara aprova projeto que cria novo Estatuto d...     0          G1
# 15680  Marco Aurélio chama de 'grotesca' recusa de Re...     0          G1
# 15681  MP manifesta 'preocupação' com projeto do abus...     0          G1
# 15682  Antes de afastamento, Renan cancela sessão do ...     0          G1
# 15683  Marco Aurélio Mello decide levar ao plenário d...     0          G1
# 15684  Cármen Lúcia se reúne com presidentes de tribu...     0          G1
# 15685  Força-tarefa da Operação Lava Jato ganha Prêmi...     0          G1
# 15686  Relembre a trajetória política de Renan Calheiros     0          G1
# 15687  Maia: Congresso não precisa se reunir em janei...     0          G1
# 15688  Saiba como o meio político reagiu ao afastamen...     0          G1
# 15689  Juiz deve estimular 'virtude cívica' além de p...     0          G1
# 15690  Ministro do STF afasta Renan Calheiros da pres...     0          G1
# 15691  Manifestações a favor da Lava Jato reúnem milh...     0          G1
# 15692  Senadores citam 'constrangimento' por Renan te...     0          G1
# 15693  Abuso de autoridade: Requião diz que sugestão ...     0          G1
# 15694  ‘Nada foi feito de forma velada’, diz Maia sob...     0          G1
# 15695  Ferreira Gullar deixa um vazio imenso na liter...     0          G1
# 15696  Renan Calheiros diz que manifestações são legí...     0          G1
# 15697  Presidência da Câmara diz que recebe manifesta...     0          G1
# 15698  Senadores apresentam versão alternativa de pro...     0          G1
# 15699  OAB pede afastamento imediato de Renan da pres...     0          G1
# 15700  Após virar réu, Renan diz que provará inocênci...     0          G1
# 15701  Governador de SC anuncia que Temer irá a Chape...     0          G1
# 15702  Alvo de 12 inquéritos, Renan diz que considera...     0          G1
# 15703  Relator vota para tornar Renan réu por desvio ...     0          G1
# 15704  Feriados 2017: veja a lista de pontos facultat...     0          G1
#
#                                               TEXT_CLEAN  \
# 0      bolsonar demit president caix exig result prox...
# 1      tod mund tinh certeza inclusiv mandante revel ...
# 2      empres japa quer invest brasil expect govern b...
# 3      torr eiffel vermelh homenag nov cidada honorar...
# 4      atencao stf proib circul livr janot revel info...
# 5      hom engan milho brasileiros sergi mor explic p...
# 6      hor deus pes diz loj lucian huck cavallera rep...
# 7      sen pel lindenberg farias flagr compr drog mor...
# 8      bom mesm sarney faz discurs onu ingles gent pa...
# 9      lad capita cueca peg dinheir cueca aqu guimara...
# 10     lul vai ser pai nov motiv pod faz lul aceit se...
# 11     dilminh gent gente dilm ped michell bolsonar p...
# 12     vic diretor coorden regional port alegre mar j...
# 13     pacient canc cust muit car par estado vam cort...
# 14     mensag whatsapp cas caiu fraud mega sen assess...
# 15     urgente noss valent ministr ricard salles viti...
# 16     chap esquent par stf intervenca milit constitu...
# 17     novidad pior especie stf liber gabinet dentr p...
# 18     part amazon vend par outr pais alemanha russia...
# 19     urgente decisa tse determin retir comentari ar...
# 20     lul depressa cris chor inform dad pel agent po...
# 21     list assinatur document encaminh macron par me...
# 22     alguem pod diz real infantil par acalm crianc ...
# 23     seri curios curiosas tras caciqu anos cham rao...
# 24     escut alfred leo maior anal mercado diretor fa...
# 25     amazon brasil vice president moura entra cen m...
# 26     bolsonar culp marcel fumac amazon acu pel falt...
# 27     noss senhora merec ser mort agressor prefeit p...
# 28     clar agu tod entendem demarc terr indigen serv...
# 29     fazend grenden lul safado compr moac vista por...
# ...                                                  ...
# 15675  mes diretor senado comand renan calheir pmdb i...
# 15676  plenari suprem tribunal federal stf inic volt ...
# 15677  president suprem tribunal federal stf carmen l...
# 15678  president senado renan calheir pmdb decid nest...
# 15679  cam deput aprov nest terca feir projet institu...
# 15680  ministr marc aureli mell trat iron nest quarta...
# 15681  procurador geral republica rodrig janot procur...
# 15682  depo recusar noit segunda feir receb notific a...
# 15683  ministr marc aureli mello suprem tribunal fede...
# 15684  president suprem tribunal federal stf ministr ...
# 15685  forca taref form procur oper lav jato parana g...
# 15686  form direit pel univers federal alago ufal ren...
# 15687  president cam deputados rodrig maia avali nest...
# 15688  conf abaix repercussa polit depo ministr supre...
# 15689  alem process pun corruptos procur juiz dev con...
# 15690  ministr suprem tribunal federal stf marc aurel...
# 15691  manifest favor oper lav jat contr corrupca nes...
# 15692  apos suprem tribunal federal stf torn reu pres...
# 15693  senador robert requia pmdb relator defensor pr...
# 15694  president camara rodrig mai dem divulg not nes...
# 15695  president michel lament nest doming mensag pub...
# 15696  president senado renan calheir pmdb divulg not...
# 15697  assessor president camara rodrig mai dem divul...
# 15698  grup senador apresent nest quinta feir propost...
# 15699  president nacional ordem advog brasil oab clau...
# 15700  president senado renan calheir pmdb divulg not...
# 15701  govern sant catarina raimund colombo anunc ent...
# 15702  president senado renan calheir pmdb afirm nest...
# 15703  ministr luiz edson fachin suprem tribunal fede...
# 15704  govern federal public nest quarta feir port di...
#
#                                              TITLE_CLEAN  TEXT_LEN_CHAR  \
# 0      bolsonar demit president caix apos assessor ga...            256
# 1      marc valeri grav audi fal cas cels daniel edua...            134
# 2           empres quer invest brasil caus bolsonar boat            354
# 3         torr eiffel fic vermelh homenag lul ontem boat            425
# 4           stf proib vend livr escrit rodrig janot boat            265
# 5       cap vej diz sergi mor engan milho brasileir boat            209
# 6      loj lucian huck lanc camiset satiriz bolsonar ...            148
# 7      lindbergh far flagr compr drog morr vidigal ja...            102
# 8      jos sarney fez discurs onu fal ingles fort sot...             82
# 9               deput jos guimara pres dinheir cuec boat            376
# 10     lul vai ser pai rosangel silva namor president...            178
# 11     dilm ped michell bolsonar pot tupperwar palaci...            236
# 12     vice diretor port alegre mar jaqueline flagr r...            161
# 13     bolsonar diz pacient canc cust car entrev folh...             99
# 14     assessor ganh mega sen compr carr lux antes re...            785
# 15     ricard sall envenenado vitim ecoterror sofr in...            375
# 16     filh janot mor portugal grav vid ameac gilm me...            144
# 17            lul gabinet dentr curitib par despach boat            278
# 18     amazon vend pel brasil par outr pais alemanha ...           1569
# 19     tse acab censur comentari arnald jabor sobr lu...           1001
# 20              lul depressa cris chor prisao revel boat            135
# 21     psol assin document ped internacionaliz amazon...            351
# 22     prefeitur fortal cri cartilh incent sexualiz i...            377
# 23     raon metukir mor franca don ong par vend alde ...           1029
# 24     alfred leo diretor falou video sobr bolsonar p...            108
# 25     moura vai amazon militar par projet control co...            849
# 26        bolsonar culp marcel incendi fumac amazon boat            212
# 27                    prefeit parauapeb flagr agred boat            405
# 28     funa suspend vend terr indigen par estrangeir ...            549
# 29            fazend grenden compr lul lulinh milho boat            406
# ...                                                  ...            ...
# 15675  sen ped stf anul aca sobr reus linh sucessor p...           1404
# 15676           stf comec julg afast renan president sen           1896
# 15677   carmen diz paut cas renan urgencia relator liber           1065
# 15678  apos ser afast senado renan cancel confraterni...           1171
# 15679           cam aprov projet cri nov estatut migraca           1142
# 15680  marc aureli cham grotesca recus renan cumpr or...           2086
# 15681             manifest preocupacao projet abus autor           1462
# 15682      antes afastamento renan cancel sessa congress            911
# 15683  marc aureli mell decid lev plenari stf limin a...           2267
# 15684            carmen luc reun president tribun estadu            829
# 15685        forca taref oper lav jat ganh premi innovar           3727
# 15686               relembr trajetor polit renan calheir           1929
# 15687  maia congress precis reun janeir apenas prevident           1798
# 15688            saib mei polit reag afast renan calheir           3590
# 15689  juiz dev estimul virtud civica alem pun corrup...           1688
# 15690      ministr stf afast renan calheir president sen           5302
# 15691  manifest favor lav jat reun milh pesso nest do...           8935
# 15692  senador cit constrangimento renan ter vir reu stf           1933
# 15693  abus autoridade requia diz sugesta mor generic...           4086
# 15694  nad feit form velada diz mai sobr pacot antico...           2915
# 15695        ferreir gull deix vazi imens literatura diz            511
# 15696                 renan calheir diz manifest legitim           1703
# 15697   president cam diz receb manifest atenca respeito           1418
# 15698  senador apresent versa altern projet sobr abus...           2068
# 15699          oab ped afast imediat renan president sen           3370
# 15700   apos vir reu renan diz prov inocent long process           2177
# 15701                  govern anunc ira chapec nest sext            965
# 15702   alvo inqueritos renan diz consid lav jat sagrada           1391
# 15703  relator vot par torn renan reu desvi dinheir p...           2915
# 15704              feri vej list pont facult feri nacion            733
#
#        TEXT_LEN_TOKEN  TITLE_LEN_CHAR  TITLE_LEN_TOKEN MONTH_YEAR
# 0                  39              62               10    09/2019
# 1                  22              65               12    09/2019
# 2                  52              44                7    10/2019
# 3                  69              46                8    10/2019
# 4                  42              44                8    10/2019
# 5                  31              48                9    10/2019
# 6                  31              58                9    10/2019
# 7                  17              56                9    10/2019
# 8                  15              54               10    10/2019
# 9                  60              40                7    10/2019
# 10                 35              57               10    10/2019
# 11                 35              57                9    10/2019
# 12                 25              60               10    10/2019
# 13                 18              51                9    10/2019
# 14                128              62               11    09/2019
# 15                 53              55                8    08/2019
# 16                 23              53               10    10/2019
# 17                 42              42                7    09/2019
# 18                228              66               12    08/2019
# 19                153              71               12    08/2019
# 20                 21              40                7    10/2019
# 21                 55              58                8    08/2019
# 22                 58              64                9    09/2019
# 23                155              56               11    09/2019
# 24                 17              58               10    09/2019
# 25                139              71               11    08/2019
# 26                 33              46                7    08/2019
# 27                 61              34                5    08/2019
# 28                 87              64               10    08/2019
# 29                 63              42                7    09/2019
# ...               ...             ...              ...        ...
# 15675             220              54               10    05/2019
# 15676             289              40                7    05/2019
# 15677             164              48                8    05/2019
# 15678             180              55                8    05/2019
# 15679             174              40                7    05/2019
# 15680             302              58                9    05/2019
# 15681             196              38                5    05/2019
# 15682             130              45                6    05/2019
# 15683             355              56               10    05/2019
# 15684             117              39                6    05/2019
# 15685             528              43                8    05/2019
# 15686             301              36                5    05/2019
# 15687             263              49                7    05/2019
# 15688             541              39                7    05/2019
# 15689             244              70               11    05/2019
# 15690             813              45                7    05/2019
# 15691            1349              50                9    05/2019
# 15692             299              49                8    05/2019
# 15693             608              60                9    05/2019
# 15694             429              52                9    05/2019
# 15695              76              43                7    05/2019
# 15696             252              34                5    05/2019
# 15697             209              48                7    05/2019
# 15698             307              52                8    05/2019
# 15699             490              41                7    05/2019
# 15700             323              48                9    05/2019
# 15701             143              33                6    05/2019
# 15702             207              48                8    05/2019
# 15703             442              51                9    05/2019
# 15704             105              37                7    05/2019
#
# [16599 rows x 12 columns]

# %%
def simple_clean_text(text):
    # Making sure we're dealing with strings and lowering the characters
    text = str(text).lower()
    
    # Stripping accents
    text = unidecode(text)
    
    # Removing characters that aren't alphanumeric
    text = re.sub(r'[^a-zA-Z ]', ' ', text)
    
    # Removing extra spaces
    text = re.sub('\s+', ' ', text)
    
    # Removing words with length equal or lower than 2 or are in STOPWORDS
    return [token for token in text.split()]

# %%
texts = df['TEXT'].apply(simple_clean_text)

# %%
cnt = Counter()
for text in tqdm_notebook(texts):
    cnt += Counter(text)
# Out:
# HBox(children=(IntProgress(value=0, max=16599), HTML(value='')))

# %% [markdown]
# ## Most common words

# %%
mc = cnt.most_common(25)

x = [c[0] for c in mc]
y = [c[1] for c in mc]

fig, ax = plt.subplots(figsize=(12, 6))
plt.bar(x, y)
plt.xticks(rotation=45, fontsize=16);
plt.yticks(fontsize=16)
# Out:
# (array([     0., 100000., 200000., 300000., 400000., 500000., 600000.]),
#  <a list of 7 Text yticklabel objects>)

# %% [markdown]
# ## Percentage of each source in the corpus

# %%
# Contagem para cada fonte
x = ['G1', 'El País', 'boatos.org']
y = [len(df[df['SOURCE'] == x[0]]),
     len(df[df['SOURCE'] == x[1]]),
     len(df[df['SOURCE'] == x[2]])]
total = np.array(y).sum()

fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.barplot(x, y)
ax.set_ylim(0, 13000)
ax.text(0, y[0] + 50, '{} ({}%)'.format(y[0], round(y[0] / total * 100, 1)), fontsize=14, horizontalalignment="center")
ax.text(1, y[1] + 50, '{} ({}%)'.format(y[1], round(y[1] / total * 100, 1)), fontsize=14, horizontalalignment="center")
ax.text(2, y[2] + 50, '{} ({}%)'.format(y[2], round(y[2] / total * 100, 1)), fontsize=14, horizontalalignment="center")
# ax.set_title("Quantidade de dados de cada fonte", fontsize=16)
# Out:
# Text(2, 944, '894 (5.4%)')

# %% [markdown]
# ## Fake news x legit news comparison

# %%
x = ['Notícias verdadeiras', 'Notícias falsas']
y = [len(df[df['FAKE'] == 0]),
     len(df[df['FAKE'] == 1])]
total = np.array(y).sum()

fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.barplot(x, y)
ax.set_ylim(0, 18000)
ax.text(0, y[0] + 50, '{} ({}%)'.format(y[0], round(y[0] / total * 100, 1)), fontsize=14, horizontalalignment="center")
ax.text(1, y[1] + 50, '{} ({}%)'.format(y[1], round(y[1] / total * 100, 1)), fontsize=14, horizontalalignment="center")
# ax.set_title("Quantidade de dados de cada classe", fontsize=16)
# Out:
# Text(1, 944, '894 (5.4%)')

# %% [markdown]
# ## Analyzing time range in fake news

# %%
start_date = datetime.strptime('01/2016', '%m/%Y')
end_date = datetime.strptime('01/2019', '%m/%Y')

# %%
df[(df['FAKE'] == 1) & (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) < start_date)].shape
# Out:
# (20, 12)

# %%
df[(df['FAKE'] == 1) & (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) > end_date)].shape
# Out:
# (232, 12)

# %%
date_fake = Counter(sorted(df[(df['FAKE'] == 1) &
                              (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) >= start_date) &
                              (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) < end_date)]['MONTH_YEAR'], key=lambda x: datetime.strptime(x, '%m/%Y')))

date_true = Counter(sorted(df[(df['FAKE'] == 0) &
                              (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) >= start_date) &
                              (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) < end_date)]['MONTH_YEAR'], key=lambda x: datetime.strptime(x, '%m/%Y')))

# %%
all_dates = sorted(set(date_fake.keys()).union(set(date_true.keys())), key=lambda x: datetime.strptime(x, '%m/%Y'))

# %%
date_fake_final = {}
date_true_final = {}
for date in all_dates:
    if date not in date_fake:
        date_fake_final[date] = 0
    else:
        date_fake_final[date] = date_fake[date]
        
    
    if date not in date_true:
        date_true_final[date] = 0
    else:
        date_true_final[date] = date_true[date]

# %%
df_date = pd.DataFrame({
    'date': list(date_fake_final.keys()) + list(date_true_final.keys()),
    'count': list(date_fake_final.values()) + list(date_true_final.values()),
    'Tipo de Notícia': len(date_fake_final) * ['Notícias falsas'] + len(date_true_final) * ['Notícias verdadeiras']
})

# %%
df_date
# Out:
#        date  count       Tipo de Notícia
# 0   01/2016      1       Notícias falsas
# 1   02/2016      2       Notícias falsas
# 2   03/2016     34       Notícias falsas
# 3   04/2016     24       Notícias falsas
# 4   05/2016     19       Notícias falsas
# 5   06/2016     13       Notícias falsas
# 6   07/2016      9       Notícias falsas
# 7   08/2016      5       Notícias falsas
# 8   09/2016     19       Notícias falsas
# 9   10/2016     12       Notícias falsas
# 10  11/2016     10       Notícias falsas
# 11  12/2016      6       Notícias falsas
# 12  01/2017     16       Notícias falsas
# 13  02/2017     11       Notícias falsas
# 14  03/2017     11       Notícias falsas
# 15  04/2017     16       Notícias falsas
# 16  05/2017     26       Notícias falsas
# 17  06/2017     14       Notícias falsas
# 18  07/2017     12       Notícias falsas
# 19  08/2017     20       Notícias falsas
# 20  09/2017      5       Notícias falsas
# 21  10/2017      0       Notícias falsas
# 22  11/2017      3       Notícias falsas
# 23  12/2017      2       Notícias falsas
# 24  01/2018      4       Notícias falsas
# 25  02/2018      5       Notícias falsas
# 26  03/2018     14       Notícias falsas
# 27  04/2018     28       Notícias falsas
# 28  05/2018     33       Notícias falsas
# 29  06/2018     14       Notícias falsas
# ..      ...    ...                   ...
# 42  07/2016    190  Notícias verdadeiras
# 43  08/2016    155  Notícias verdadeiras
# 44  09/2016    229  Notícias verdadeiras
# 45  10/2016    222  Notícias verdadeiras
# 46  11/2016    238  Notícias verdadeiras
# 47  12/2016    177  Notícias verdadeiras
# 48  01/2017    169  Notícias verdadeiras
# 49  02/2017    143  Notícias verdadeiras
# 50  03/2017    164  Notícias verdadeiras
# 51  04/2017    205  Notícias verdadeiras
# 52  05/2017    229  Notícias verdadeiras
# 53  06/2017    176  Notícias verdadeiras
# 54  07/2017    155  Notícias verdadeiras
# 55  08/2017    133  Notícias verdadeiras
# 56  09/2017    156  Notícias verdadeiras
# 57  10/2017    206  Notícias verdadeiras
# 58  11/2017    136  Notícias verdadeiras
# 59  12/2017    138  Notícias verdadeiras
# 60  01/2018    124  Notícias verdadeiras
# 61  02/2018    112  Notícias verdadeiras
# 62  03/2018    158  Notícias verdadeiras
# 63  04/2018    149  Notícias verdadeiras
# 64  05/2018    132  Notícias verdadeiras
# 65  06/2018    103  Notícias verdadeiras
# 66  07/2018    121  Notícias verdadeiras
# 67  08/2018    162  Notícias verdadeiras
# 68  09/2018    157  Notícias verdadeiras
# 69  10/2018    250  Notícias verdadeiras
# 70  11/2018    156  Notícias verdadeiras
# 71  12/2018    124  Notícias verdadeiras
#
# [72 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.lineplot(x='date', y='count', hue='Tipo de Notícia', data=df_date, sort=False)

plt.legend(fontsize='x-large')
ax.set_xlabel('Mês e ano', fontsize=24)
ax.set_ylabel('Quantidade de notícias', fontsize=24)

for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    tick.set_fontsize(20)
    tick.set_ha('right')
    

    
for tick in ax.get_yticklabels():
    tick.set_fontsize(20)

# %%
df = df[(df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) >= start_date) &
        (df['MONTH_YEAR'].apply(lambda x: datetime.strptime(x, '%m/%Y')) < end_date)].reset_index(drop=True)

# %%
x = ['Notícias verdadeiras', 'Notícias falsas']
y = [len(df[df['FAKE'] == 0]),
     len(df[df['FAKE'] == 1])]

total = np.array(y).sum()

fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.barplot(x, y)
ax.set_ylim(0, 18000)
ax.text(0, y[0] + 50, '{} ({}%)'.format(y[0], round(y[0] / total * 100, 1)), fontsize=14, horizontalalignment="center")
ax.text(1, y[1] + 50, '{} ({}%)'.format(y[1], round(y[1] / total * 100, 1)), fontsize=14, horizontalalignment="center")
# ax.set_title("Quantidade de dados de cada classe", fontsize=16)
# Out:
# Text(1, 665, '615 (9.2%)')

# %% [markdown]
# ## Analyzing word count

# %%
def simple_clean_text(text):
    # Making sure we're dealing with strings and lowering the characters
    text = str(text).lower()
    
    # Stripping accents
    text = unidecode(text)
    
    # Removing characters that aren't alphanumeric
    text = re.sub(r'[^a-zA-Z0-9 ]', ' ', text)
    
    # Removing tokens that intercalate between letters and digits
    text = re.sub(r'\w*([a-zA-Z][0-9]|[0-9][a-zA-Z])\w*', ' ', text)
    
    # Removing digits
    text = re.sub(r'\d', ' ', text)
    
    # Removing tokens with letters that appear more than twice in a row
    text = re.sub(r'\w*([a-zA-Z])\1{2,}\w*', ' ', text)
    
    # Removing extra spaces
    text = re.sub('\s+', ' ', text)
    
    # Removing words with length equal or lower than 2 or are in STOPWORDS
    return ' '.join([token for token in text.split() if len(token) > 2 and token not in STOPWORDS])

# %%
df['SIMPLE_CLEAN_TEXT'] = df['TEXT'].apply(simple_clean_text)

# %%
all_cnt = {}
for key in tqdm_notebook(CLASS_DICT):
    cnt = Counter()
    for text in tqdm_notebook(df[df['FAKE'] == key]['SIMPLE_CLEAN_TEXT']):
        cnt += Counter(str(text).split())

    all_cnt[key] = cnt.most_common()
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6088), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=615), HTML(value='')))

# %%
all_cnt
# Out:
# {0: [('presidente', 14240),
#   ('governo', 11832),
#   ('pais', 11078),
#   ('anos', 10438),
#   ('sobre', 9590),
#   ('contra', 8366),
#   ('ainda', 7888),
#   ('politica', 7602),
#   ('brasil', 7371),
#   ('segundo', 7055),
#   ('trump', 6561),
#   ('partido', 6512),
#   ('pode', 6361),
#   ('feira', 6130),
#   ('pessoas', 5945),
#   ('disse', 5837),
#   ('estado', 5762),
#   ('porque', 5730),
#   ('agora', 5612),
#   ('dois', 5525),
#   ('ano', 5507),
#   ('lula', 5473),
#   ('todos', 5090),
#   ('temer', 5030),
#   ('caso', 4955),
#   ('parte', 4751),
#   ('dia', 4681),
#   ('desde', 4637),
#   ('diz', 4573),
#   ('eleicoes', 4512),
#   ('durante', 4493),
#   ('campanha', 4417),
#   ('vez', 4413),
#   ('primeiro', 4359),
#   ('poder', 4257),
#   ('bolsonaro', 4239),
#   ('federal', 4214),
#   ('onde', 4204),
#   ('outros', 4157),
#   ('fazer', 4107),
#   ('politico', 4095),
#   ('ministro', 4069),
#   ('nacional', 4056),
#   ('processo', 3999),
#   ('antes', 3997),
#   ('menos', 3987),
#   ('grande', 3952),
#   ('candidato', 3927),
#   ('hoje', 3881),
#   ('apenas', 3849),
#   ('nesta', 3754),
#   ('acordo', 3710),
#   ('maior', 3702),
#   ('momento', 3689),
#   ('assim', 3683),
#   ('alem', 3671),
#   ('outro', 3638),
#   ('estados', 3587),
#   ('mundo', 3578),
#   ('paulo', 3563),
#   ('tempo', 3523),
#   ('milhoes', 3512),
#   ('casa', 3506),
#   ('primeira', 3478),
#   ('afirmou', 3460),
#   ('justica', 3430),
#   ('apos', 3417),
#   ('dias', 3368),
#   ('tres', 3329),
#   ('corrupcao', 3264),
#   ('dilma', 3251),
#   ('alguns', 3212),
#   ('tudo', 3194),
#   ('eleitoral', 3118),
#   ('novo', 3024),
#   ('publico', 3019),
#   ('havia', 3006),
#   ('qualquer', 2986),
#   ('reais', 2928),
#   ('lei', 2890),
#   ('politicos', 2881),
#   ('crise', 2876),
#   ('bem', 2873),
#   ('enquanto', 2859),
#   ('forma', 2859),
#   ('camara', 2850),
#   ('entao', 2844),
#   ('nova', 2844),
#   ('duas', 2806),
#   ('vida', 2784),
#   ('sido', 2777),
#   ('norte', 2770),
#   ('sempre', 2742),
#   ('grupo', 2734),
#   ('votos', 2732),
#   ('todo', 2728),
#   ('decisao', 2725),
#   ('seguranca', 2709),
#   ('segunda', 2705),
#   ('meio', 2679),
#   ('cada', 2661),
#   ('apoio', 2585),
#   ('relacao', 2583),
#   ('semana', 2582),
#   ('jato', 2556),
#   ('neste', 2555),
#   ('lava', 2539),
#   ('quase', 2527),
#   ('deve', 2524),
#   ('conta', 2519),
#   ('passado', 2517),
#   ('unidos', 2498),
#   ('paises', 2485),
#   ('esquerda', 2485),
#   ('policia', 2466),
#   ('congresso', 2463),
#   ('tribunal', 2444),
#   ('pouco', 2435),
#   ('meses', 2430),
#   ('impeachment', 2409),
#   ('publica', 2391),
#   ('sendo', 2391),
#   ('deputados', 2391),
#   ('ministerio', 2372),
#   ('rio', 2367),
#   ('historia', 2361),
#   ('fez', 2360),
#   ('partidos', 2336),
#   ('maioria', 2331),
#   ('oposicao', 2322),
#   ('muitos', 2309),
#   ('outras', 2308),
#   ('apesar', 2307),
#   ('lado', 2304),
#   ('exemplo', 2290),
#   ('possivel', 2280),
#   ('prisao', 2279),
#   ('social', 2263),
#   ('democracia', 2258),
#   ('presidencia', 2255),
#   ('sociedade', 2251),
#   ('trabalho', 2249),
#   ('afirma', 2243),
#   ('sociais', 2238),
#   ('sistema', 2238),
#   ('outra', 2232),
#   ('direitos', 2229),
#   ('fato', 2218),
#   ('voto', 2217),
#   ('eleicao', 2216),
#   ('todas', 2213),
#   ('dinheiro', 2209),
#   ('geral', 2200),
#   ('fim', 2198),
#   ('deputado', 2185),
#   ('cidade', 2175),
#   ('operacao', 2171),
#   ('direita', 2163),
#   ('nunca', 2155),
#   ('algo', 2130),
#   ('disso', 2128),
#   ('nada', 2127),
#   ('rousseff', 2126),
#   ('frente', 2113),
#   ('militar', 2112),
#   ('final', 2089),
#   ('populacao', 2075),
#   ('situacao', 2071),
#   ('mulheres', 2058),
#   ('quatro', 2053),
#   ('ultimos', 2044),
#   ('tao', 2006),
#   ('republica', 1994),
#   ('nome', 1993),
#   ('guerra', 1979),
#   ('supremo', 1977),
#   ('lider', 1975),
#   ('defesa', 1971),
#   ('projeto', 1967),
#   ('economia', 1962),
#   ('gente', 1955),
#   ('direito', 1944),
#   ('brasileira', 1924),
#   ('centro', 1912),
#   ('embora', 1907),
#   ('eua', 1906),
#   ('proprio', 1905),
#   ('melhor', 1893),
#   ('discurso', 1892),
#   ('forca', 1888),
#   ('empresa', 1863),
#   ('poderia', 1862),
#   ('chegou', 1848),
#   ('vezes', 1845),
#   ('saude', 1830),
#   ('politicas', 1821),
#   ('dizer', 1814),
#   ('podem', 1811),
#   ('faz', 1800),
#   ('presidenta', 1788),
#   ('sob', 1780),
#   ('senado', 1776),
#   ('tanto', 1764),
#   ('dentro', 1760),
#   ('sim', 1758),
#   ('diante', 1756),
#   ('vem', 1740),
#   ('atual', 1740),
#   ('estar', 1739),
#   ('pmdb', 1738),
#   ('candidatos', 1735),
#   ('reforma', 1732),
#   ('questao', 1724),
#   ('movimento', 1721),
#   ('psdb', 1720),
#   ('cargo', 1717),
#   ('desta', 1715),
#   ('empresas', 1705),
#   ('quarta', 1686),
#   ('programa', 1679),
#   ('aqui', 1673),
#   ('nenhum', 1671),
#   ('familia', 1668),
#   ('janeiro', 1667),
#   ('quais', 1666),
#   ('dar', 1663),
#   ('eleitores', 1647),
#   ('brasileiro', 1644),
#   ('uniao', 1642),
#   ('importante', 1637),
#   ('parece', 1637),
#   ('economica', 1632),
#   ('grandes', 1620),
#   ('imprensa', 1617),
#   ('clinton', 1616),
#   ('inicio', 1604),
#   ('mandato', 1603),
#   ('cerca', 1599),
#   ('dados', 1596),
#   ('ninguem', 1592),
#   ('violencia', 1591),
#   ('lugar', 1588),
#   ('preciso', 1586),
#   ('entanto', 1577),
#   ('numero', 1565),
#   ('ultima', 1565),
#   ('futuro', 1565),
#   ('constituicao', 1562),
#   ('quanto', 1558),
#   ('terca', 1553),
#   ('deste', 1544),
#   ('domingo', 1544),
#   ('senador', 1542),
#   ('toda', 1542),
#   ('problema', 1539),
#   ('algumas', 1538),
#   ('ver', 1537),
#   ('partir', 1537),
#   ('cinco', 1534),
#   ('vice', 1525),
#   ('mesma', 1521),
#   ('mulher', 1511),
#   ('internacional', 1508),
#   ('turno', 1507),
#   ('pesquisas', 1506),
#   ('quer', 1505),
#   ('regiao', 1498),
#   ('crime', 1493),
#   ('michel', 1493),
#   ('venezuela', 1493),
#   ('espanha', 1484),
#   ('dessa', 1483),
#   ('ponto', 1483),
#   ('nesse', 1483),
#   ('vitoria', 1482),
#   ('quinta', 1482),
#   ('votacao', 1480),
#   ('juiz', 1470),
#   ('investigacao', 1468),
#   ('rede', 1468),
#   ('claro', 1465),
#   ('principal', 1458),
#   ('verdade', 1451),
#   ('educacao', 1449),
#   ('obama', 1448),
#   ('ultimo', 1446),
#   ('debate', 1434),
#   ('desse', 1427),
#   ('explica', 1423),
#   ('feito', 1422),
#   ('horas', 1416),
#   ('forcas', 1412),
#   ('base', 1405),
#   ('marco', 1399),
#   ('regime', 1394),
#   ('brasileiros', 1393),
#   ('povo', 1393),
#   ('chefe', 1383),
#   ('donald', 1382),
#   ('entrevista', 1373),
#   ('sexta', 1371),
#   ('varios', 1366),
#   ('mudanca', 1364),
#   ('europa', 1363),
#   ('coisa', 1362),
#   ('principais', 1359),
#   ('contas', 1359),
#   ('redes', 1357),
#   ('bilhoes', 1351),
#   ('branca', 1346),
#   ('pedido', 1344),
#   ('acao', 1342),
#   ('precisa', 1340),
#   ('casos', 1336),
#   ('problemas', 1336),
#   ('recursos', 1332),
#   ('favor', 1331),
#   ('pesquisa', 1326),
#   ('maneira', 1321),
#   ('jornal', 1314),
#   ('muitas', 1310),
#   ('filho', 1309),
#   ('resultado', 1304),
#   ('grupos', 1292),
#   ('medidas', 1292),
#   ('existe', 1290),
#   ('silva', 1289),
#   ('cunha', 1286),
#   ('civil', 1285),
#   ('republicano', 1285),
#   ('mercado', 1284),
#   ('odebrecht', 1284),
#   ('dolares', 1276),
#   ('governador', 1271),
#   ('conseguiu', 1271),
#   ('coisas', 1268),
#   ('publicos', 1266),
#   ('proposta', 1264),
#   ('democrata', 1263),
#   ('capital', 1261),
#   ('epoca', 1260),
#   ('medida', 1260),
#   ('ruas', 1259),
#   ('gestao', 1252),
#   ('noite', 1251),
#   ('homem', 1250),
#   ('falta', 1247),
#   ('america', 1244),
#   ('comissao', 1244),
#   ('maduro', 1243),
#   ('haddad', 1234),
#   ('mes', 1233),
#   ('stf', 1233),
#   ('vao', 1230),
#   ('possibilidade', 1229),
#   ('dificil', 1225),
#   ('sul', 1220),
#   ('crimes', 1219),
#   ('comecou', 1215),
#   ('eleito', 1214),
#   ('membros', 1213),
#   ('causa', 1209),
#   ('deu', 1201),
#   ('paz', 1190),
#   ('ideia', 1187),
#   ('golpe', 1186),
#   ('moro', 1185),
#   ('pessoa', 1184),
#   ('hora', 1184),
#   ('popular', 1184),
#   ('papel', 1182),
#   ('saida', 1180),
#   ('fernando', 1178),
#   ('presidencial', 1178),
#   ('falar', 1176),
#   ('tipo', 1175),
#   ('propria', 1171),
#   ('argentina', 1171),
#   ('candidatura', 1166),
#   ('ficou', 1160),
#   ('nenhuma', 1160),
#   ('morte', 1158),
#   ('ministros', 1158),
#   ('prefeito', 1155),
#   ('vamos', 1155),
#   ('humanos', 1154),
#   ('ordem', 1150),
#   ('forte', 1144),
#   ('jose', 1143),
#   ('plano', 1143),
#   ('ditadura', 1142),
#   ('seis', 1139),
#   ('militares', 1135),
#   ('acho', 1134),
#   ('alguem', 1132),
#   ('inclusive', 1129),
#   ('periodo', 1121),
#   ('exercito', 1120),
#   ('longo', 1116),
#   ('cidadaos', 1116),
#   ('chegar', 1114),
#   ('sabe', 1110),
#   ('risco', 1109),
#   ('organizacao', 1104),
#   ('proximo', 1103),
#   ('boa', 1102),
#   ('contrario', 1099),
#   ('parlamento', 1097),
#   ('executivo', 1096),
#   ('deveria', 1092),
#   ('deixou', 1090),
#   ('talvez', 1089),
#   ('universidade', 1088),
#   ('europeia', 1076),
#   ('acoes', 1074),
#   ('tentar', 1073),
#   ('varias', 1070),
#   ('controle', 1070),
#   ('votar', 1068),
#   ('conselho', 1064),
#   ('lideres', 1061),
#   ('resposta', 1059),
#   ('objetivo', 1058),
#   ('preso', 1056),
#   ('crescimento', 1054),
#   ('semanas', 1053),
#   ('caminho', 1053),
#   ('eduardo', 1050),
#   ('trabalhadores', 1048),
#   ('relacoes', 1044),
#   ('continua', 1042),
#   ('jovens', 1040),
#   ('opiniao', 1040),
#   ('parlamentares', 1040),
#   ('unido', 1037),
#   ('acabou', 1036),
#   ('informacoes', 1035),
#   ('publicas', 1035),
#   ('evitar', 1035),
#   ('liberdade', 1032),
#   ('policiais', 1025),
#   ('deixar', 1024),
#   ('pontos', 1023),
#   ('reino', 1021),
#   ('pai', 1020),
#   ('economico', 1019),
#   ('parlamentar', 1015),
#   ('reuniao', 1013),
#   ('petista', 1012),
#   ('podemos', 1012),
#   ('manter', 1009),
#   ('valor', 1000),
#   ('novas', 999),
#   ('cenario', 999),
#   ('passou', 996),
#   ('diretor', 994),
#   ('instituicoes', 988),
#   ('outubro', 986),
#   ('referendo', 986),
#   ('trata', 985),
#   ('corte', 985),
#   ('area', 982),
#   ('volta', 981),
#   ('equipe', 981),
#   ('bom', 981),
#   ('franca', 981),
#   ('disputa', 980),
#   ('atras', 978),
#   ('americano', 977),
#   ('imagem', 973),
#   ('unico', 969),
#   ('medo', 969),
#   ('respeito', 967),
#   ('responsavel', 966),
#   ('alckmin', 964),
#   ('pediu', 963),
#   ('autoridades', 962),
#   ('facebook', 961),
#   ('governos', 959),
#   ('setor', 955),
#   ('novos', 955),
#   ('nota', 953),
#   ('local', 953),
#   ('classe', 949),
#   ('algum', 947),
#   ('brasilia', 946),
#   ('washington', 945),
#   ('filhos', 941),
#   ('assembleia', 940),
#   ('tarde', 937),
#   ('ato', 937),
#   ('alguma', 935),
#   ('diferentes', 934),
#   ('texto', 932),
#   ('queda', 927),
#   ('armas', 926),
#   ('palavras', 926),
#   ('oficial', 925),
#   ('investigacoes', 924),
#   ('mensagem', 924),
#   ('denuncia', 924),
#   ('vista', 923),
#   ('professor', 923),
#   ('unica', 918),
#   ('fala', 918),
#   ('aumento', 916),
#   ('secretario', 916),
#   ('responsabilidade', 916),
#   ('banco', 909),
#   ('comunicacao', 905),
#   ('rua', 902),
#   ('julgamento', 898),
#   ('setembro', 895),
#   ('dezembro', 893),
#   ('russia', 891),
#   ('maio', 891),
#   ('pois', 889),
#   ('campo', 889),
#   ('realidade', 886),
#   ('acesso', 885),
#   ('abril', 885),
#   ('ultimas', 883),
#   ('petrobras', 882),
#   ('total', 881),
#   ('sentido', 878),
#   ('demais', 871),
#   ('mundial', 869),
#   ('luta', 869),
#   ('homens', 868),
#   ('aconteceu', 868),
#   ('tornou', 866),
#   ('funcionarios', 865),
#   ('prazo', 864),
#   ('saber', 862),
#   ('sergio', 861),
#   ('passada', 861),
#   ('jair', 860),
#   ('luiz', 860),
#   ('comunidade', 860),
#   ('porta', 859),
#   ('posicao', 857),
#   ('novembro', 857),
#   ('maos', 857),
#   ('poucos', 855),
#   ('valores', 855),
#   ('democratas', 855),
#   ('central', 854),
#   ('twitter', 854),
#   ('mexico', 853),
#   ('participacao', 852),
#   ('servicos', 852),
#   ('estrategia', 851),
#   ('ficar', 851),
#   ('recebeu', 851),
#   ('ambos', 851),
#   ('muita', 850),
#   ('macri', 847),
#   ('capacidade', 843),
#   ('maiores', 843),
#   ('livro', 842),
#   ('voz', 839),
#   ('informacao', 838),
#   ('livre', 836),
#   ('latina', 836),
#   ('relatorio', 836),
#   ('condicoes', 835),
#   ('americanos', 835),
#   ('acredita', 834),
#   ('mal', 833),
#   ('conseguir', 833),
#   ('mudar', 832),
#   ('devem', 830),
#   ('los', 828),
#   ('eleitorais', 828),
#   ('porem', 826),
#   ('junho', 824),
#   ('espaco', 823),
#   ('especialmente', 822),
#   ('sair', 822),
#   ('comum', 821),
#   ('real', 821),
#   ('querem', 821),
#   ('nessa', 821),
#   ('busca', 817),
#   ('criticas', 816),
#   ('extrema', 815),
#   ('protestos', 814),
#   ('senadores', 813),
#   ('instituto', 813),
#   ('junto', 813),
#   ('feita', 812),
#   ('anunciou', 812),
#   ('serie', 809),
#   ('alemanha', 809),
#   ('levar', 806),
#   ('media', 806),
#   ('decidiu', 806),
#   ('mudancas', 806),
#   ('decadas', 806),
#   ('escola', 805),
#   ('agosto', 801),
#   ('delacao', 801),
#   ('jogo', 799),
#   ('pena', 799),
#   ('procurador', 799),
#   ('pergunta', 798),
#   ('colombia', 795),
#   ('constitucional', 795),
#   ('proximos', 793),
#   ('fiscal', 789),
#   ('manha', 787),
#   ('assunto', 786),
#   ('secretaria', 785),
#   ('americana', 784),
#   ('defender', 783),
#   ('passar', 783),
#   ('modelo', 782),
#   ('continuar', 782),
#   ('oito', 780),
#   ('sete', 779),
#   ('cidades', 779),
#   ('uso', 779),
#   ('sabado', 778),
#   ('joao', 777),
#   ('linha', 777),
#   ('especial', 777),
#   ('movimentos', 775),
#   ('ataque', 773),
#   ('ganhar', 771),
#   ('voltar', 770),
#   ('republicanos', 770),
#   ('brexit', 769),
#   ('reformas', 769),
#   ('presenca', 768),
#   ('mostra', 768),
#   ('mao', 768),
#   ('alta', 764),
#   ('presidenciais', 760),
#   ('tema', 760),
#   ('principalmente', 760),
#   ('fazendo', 759),
#   ('jovem', 758),
#   ('desses', 757),
#   ('general', 756),
#   ('jornalista', 756),
#   ('dizem', 756),
#   ('alto', 753),
#   ('the', 752),
#   ('senhor', 749),
#   ('representantes', 749),
#   ('interesses', 747),
#   ('fundo', 743),
#   ('resultados', 742),
#   ('presos', 742),
#   ('confianca', 740),
#   ('processos', 740),
#   ('policial', 739),
#   ('significa', 739),
#   ('carlos', 738),
#   ('pior', 738),
#   ('artigo', 737),
#   ('pobres', 735),
#   ('empresario', 734),
#   ('necessario', 734),
#   ('cultura', 733),
#   ('macron', 733),
#   ('levou', 732),
#   ('modo', 732),
#   ('gastos', 728),
#   ('ali', 727),
#   ('dialogo', 725),
#   ('milhares', 725),
#   ('aliados', 724),
#   ('renda', 722),
#   ('tentativa', 722),
#   ('diferente', 722),
#   ('decisoes', 721),
#   ('atencao', 720),
#   ('manifestantes', 718),
#   ('santos', 717),
#   ('portanto', 717),
#   ('certo', 715),
#   ('seculo', 715),
#   ('terra', 714),
#   ('advogado', 713),
#   ('judiciario', 713),
#   ('manifestacoes', 713),
#   ('administracao', 713),
#   ('hillary', 711),
#   ('catalunha', 711),
#   ('urnas', 710),
#   ('logo', 709),
#   ('desenvolvimento', 708),
#   ('criancas', 708),
#   ('agenda', 708),
#   ('encontro', 707),
#   ('chamado', 705),
#   ('entrar', 705),
#   ('ameaca', 704),
#   ('acabar', 703),
#   ('ira', 703),
#   ('possa', 700),
#   ('eleitorado', 699),
#   ('dez', 698),
#   ('somente', 696),
#   ('vitimas', 696),
#   ('espanhol', 696),
#   ('importantes', 695),
#   ('intervencao', 695),
#   ('ocorreu', 695),
#   ('representa', 695),
#   ('construcao', 694),
#   ('declarou', 694),
#   ('indigenas', 694),
#   ('acontece', 692),
#   ('fica', 690),
#   ('pratica', 686),
#   ('recente', 686),
#   ('superior', 685),
#   ('questoes', 685),
#   ('julho', 684),
#   ('razao', 683),
#   ('sobretudo', 683),
#   ('propostas', 683),
#   ('siria', 682),
#   ('ministra', 681),
#   ('obras', 680),
#   ('alvo', 678),
#   ('menor', 677),
#   ('setores', 677),
#   ('pessoal', 675),
#   ('agencia', 675),
#   ('palacio', 673),
#   ('garantir', 670),
#   ('doria', 670),
#   ('china', 669),
#   ('aprovacao', 669),
#   ('espera', 668),
#   ('democratica', 668),
#   ('defende', 667),
#   ('lista', 667),
#   ('especie', 663),
#   ('colocar', 663),
#   ('jornalistas', 661),
#   ('posse', 657),
#   ('noticias', 657),
#   ('aecio', 656),
#   ('duvida', 656),
#   ('conflito', 654),
#   ('previdencia', 654),
#   ('candidata', 653),
#   ('longe', 650),
#   ('sucesso', 650),
#   ('areas', 650),
#   ('planalto', 647),
#   ('dado', 647),
#   ('trabalhar', 645),
#   ('acusacoes', 645),
#   ('ajuda', 644),
#   ('vou', 643),
#   ('familias', 643),
#   ('apresentar', 642),
#   ('capaz', 642),
#   ('entender', 641),
#   ('henrique', 641),
#   ('ataques', 640),
#   ('legislativo', 640),
#   ('ganhou', 640),
#   ('fizeram', 640),
#   ('plenario', 640),
#   ('pagar', 639),
#   ('perdeu', 638),
#   ('proxima', 636),
#   ('nomes', 635),
#   ('independencia', 634),
#   ('declaracoes', 633),
#   ('pressao', 632),
#   ('declaracao', 632),
#   ('interesse', 629),
#   ('atualmente', 628),
#   ('existem', 628),
#   ('podera', 628),
#   ('bastante', 628),
#   ('voltou', 626),
#   ('ambiente', 624),
#   ('televisao', 622),
#   ('tempos', 622),
#   ('primeiros', 621),
#   ('documento', 621),
#   ('esquema', 621),
#   ('metade', 620),
#   ('abertura', 619),
#   ('negociacoes', 619),
#   ('atraves', 618),
#   ('referencia', 618),
#   ('instancia', 618),
#   ('especialistas', 617),
#   ('prefeitura', 616),
#   ('pre', 616),
#   ('york', 616),
#   ('conhecido', 615),
#   ('criar', 613),
#   ('enorme', 612),
#   ('projetos', 612),
#   ('escolas', 612),
#   ('carta', 611),
#   ('reportagem', 610),
#   ('documentos', 610),
#   ('manifestacao', 609),
#   ('necessidade', 609),
#   ('europeu', 608),
#   ('participar', 606),
#   ('mae', 605),
#   ('tornar', 605),
#   ('internacionais', 603),
#   ('inteligencia', 601),
#   ('agentes', 601),
#   ('fazem', 601),
#   ('vontade', 601),
#   ('judicial', 601),
#   ('dessas', 599),
#   ('sede', 599),
#   ('regras', 599),
#   ('acredito', 599),
#   ('considera', 596),
#   ('fatos', 594),
#   ('receber', 594),
#   ('rodrigo', 594),
#   ('dizendo', 592),
#   ('empresarios', 592),
#   ('escandalo', 592),
#   ('solucao', 591),
#   ('intencao', 591),
#   ('conservador', 590),
#   ('vive', 590),
#   ('via', 590),
#   ('servico', 589),
#   ('unidade', 589),
#   ('nivel', 589),
#   ('mesa', 588),
#   ('juizes', 587),
#   ('serem', 587),
#   ('socialista', 586),
#   ('pretende', 585),
#   ('tomar', 585),
#   ('viu', 583),
#   ('entretanto', 582),
#   ('fevereiro', 581),
#   ('formacao', 580),
#   ('comando', 579),
#   ('palavra', 579),
#   ('condenado', 579),
#   ('exterior', 578),
#   ('cargos', 576),
#   ('terceiro', 575),
#   ('grave', 575),
#   ('deixa', 574),
#   ('inacio', 574),
#   ('condenacao', 574),
#   ('acusacao', 573),
#   ('territorio', 573),
#   ('escreveu', 572),
#   ('ciro', 572),
#   ('mim', 571),
#   ('acordos', 571),
#   ('protesto', 570),
#   ('idade', 570),
#   ('internet', 569),
#   ('tarefa', 569),
#   ('assumir', 568),
#   ('sei', 567),
#   ('meios', 567),
#   ('acima', 566),
#   ('leis', 566),
#   ('psl', 565),
#   ('acusado', 565),
#   ('troca', 563),
#   ('antonio', 563),
#   ('anterior', 563),
#   ('conversa', 563),
#   ('figura', 563),
#   ('passa', 562),
#   ('imigrantes', 562),
#   ('data', 562),
#   ('provas', 562),
#   ('comeca', 561),
#   ('decada', 558),
#   ('medio', 558),
#   ('zona', 557),
#   ('campanhas', 557),
#   ('acontecer', 557),
#   ('farc', 556),
#   ('reducao', 553),
#   ('experiencia', 553),
#   ('direcao', 553),
#   ('legal', 553),
#   ('tal', 553),
#   ('estadual', 552),
#   ('fundamental', 550),
#   ('seguinte', 548),
#   ('investimentos', 548),
#   ('mensagens', 548),
#   ('israel', 548),
#   ('acaba', 547),
#   ('filha', 547),
#   ('origem', 545),
#   ('pagamento', 545),
#   ('passo', 545),
#   ('derrota', 545),
#   ('cara', 544),
#   ('minimo', 544),
#   ('janot', 544),
#   ('orcamento', 543),
#   ('coalizao', 543),
#   ('perder', 541),
#   ('combate', 540),
#   ('atuacao', 540),
#   ('comercio', 540),
#   ('sessao', 538),
#   ('incluindo', 537),
#   ('atos', 537),
#   ('presidentes', 536),
#   ('caixa', 536),
#   ('enfrentar', 536),
#   ('tentou', 535),
#   ('gabinete', 534),
#   ('analise', 534),
#   ('efeito', 533),
#   ('deus', 533),
#   ('medicos', 533),
#   ('influencia', 532),
#   ('democratico', 532),
#   ('visao', 532),
#   ('esperanca', 532),
#   ('folha', 531),
#   ('visto', 530),
#   ('mostrou', 530),
#   ('facil', 529),
#   ('orgao', 528),
#   ('conforme', 528),
#   ('evento', 528),
#   ('quero', 528),
#   ('video', 526),
#   ('diferenca', 526),
#   ('feitas', 526),
#   ('lideranca', 526),
#   ('milhao', 525),
#   ('marina', 525),
#   ('putin', 525),
#   ('clara', 524),
#   ('criacao', 524),
#   ('ideias', 524),
#   ('critica', 522),
#   ('funcao', 522),
#   ('termos', 521),
#   ('torno', 521),
#   ('desafio', 520),
#   ('may', 520),
#   ('legislacao', 519),
#   ('rejeicao', 519),
#   ('chega', 518),
#   ('nove', 517),
#   ('cuja', 515),
#   ('comunicado', 515),
#   ('dezenas', 514),
#   ('historico', 514),
#   ('refugiados', 514),
#   ('onu', 514),
#   ('diretamente', 512),
#   ('emprego', 512),
#   ('rajoy', 512),
#   ('planos', 510),
#   ('trabalhista', 510),
#   ('poderiam', 509),
#   ('odio', 509),
#   ('advogados', 507),
#   ('mortos', 507),
#   ('pedir', 507),
#   ('ensino', 507),
#   ('proximas', 506),
#   ('negociacao', 505),
#   ('prova', 505),
#   ('gracas', 504),
#   ('departamento', 504),
#   ('comeco', 504),
#   ('suficiente', 504),
#   ('dizia', 504),
#   ('mantem', 503),
#   ('tucano', 503),
#   ('preocupacao', 502),
#   ('reduzir', 502),
#   ('fogo', 502),
#   ('coletiva', 502),
#   ('responsaveis', 501),
#   ('institucional', 501),
#   ('tirar', 501),
#   ('psol', 500),
#   ('perfil', 498),
#   ('visita', 498),
#   ('maria', 497),
#   ...],
#  1: [('lula', 386),
#   ('bolsonaro', 382),
#   ('brasil', 355),
#   ('presidente', 339),
#   ('dilma', 220),
#   ('todos', 188),
#   ('pais', 173),
#   ('contra', 167),
#   ('temer', 152),
#   ('agora', 150),
#   ('federal', 150),
#   ('governo', 149),
#   ('dia', 139),
#   ('povo', 136),
#   ('anos', 131),
#   ('sobre', 130),
#   ('porque', 127),
#   ('tudo', 127),
#   ('hoje', 123),
#   ('moro', 122),
#   ('dinheiro', 119),
#   ('milhoes', 116),
#   ('globo', 113),
#   ('pode', 110),
#   ('todo', 108),
#   ('ainda', 106),
#   ('vamos', 105),
#   ('fazer', 96),
#   ('pessoas', 93),
#   ('paulo', 91),
#   ('segundo', 89),
#   ('onde', 88),
#   ('mundo', 87),
#   ('video', 85),
#   ('sergio', 85),
#   ('policia', 85),
#   ('aqui', 84),
#   ('haddad', 82),
#   ('deputado', 79),
#   ('diz', 78),
#   ('ministro', 78),
#   ('candidato', 77),
#   ('educacao', 75),
#   ('dias', 74),
#   ('assim', 74),
#   ('brasileiro', 73),
#   ('nacional', 70),
#   ('bem', 70),
#   ('brasilia', 69),
#   ('disse', 69),
#   ('sendo', 68),
#   ('estado', 68),
#   ('vao', 67),
#   ('juiz', 66),
#   ('votos', 66),
#   ('maior', 65),
#   ('gente', 65),
#   ('apenas', 65),
#   ('rio', 65),
#   ('feira', 65),
#   ('deputados', 65),
#   ('mil', 64),
#   ('caso', 64),
#   ('esquerda', 64),
#   ('nome', 64),
#   ('familia', 64),
#   ('voto', 64),
#   ('sociais', 63),
#   ('silva', 63),
#   ('grande', 62),
#   ('vez', 62),
#   ('casa', 62),
#   ('nunca', 61),
#   ('brasileiros', 60),
#   ('apos', 60),
#   ('jair', 60),
#   ('campanha', 60),
#   ('jato', 60),
#   ('antes', 59),
#   ('stf', 59),
#   ('outros', 59),
#   ('entao', 59),
#   ('poder', 59),
#   ('lei', 58),
#   ('votar', 58),
#   ('eleicoes', 58),
#   ('fim', 57),
#   ('qualquer', 57),
#   ('lava', 57),
#   ('politica', 57),
#   ('pois', 55),
#   ('michel', 55),
#   ('impeachment', 54),
#   ('corrupcao', 54),
#   ('nada', 54),
#   ('durante', 54),
#   ('janeiro', 54),
#   ('vou', 53),
#   ('semana', 52),
#   ('publico', 52),
#   ('deus', 52),
#   ('veja', 51),
#   ('primeira', 51),
#   ('redes', 51),
#   ('sabe', 51),
#   ('desde', 50),
#   ('menos', 50),
#   ('vida', 50),
#   ('preso', 50),
#   ('noticia', 50),
#   ('toda', 50),
#   ('congresso', 49),
#   ('politicos', 49),
#   ('filho', 49),
#   ('conta', 48),
#   ('parte', 48),
#   ('todas', 48),
#   ('audio', 47),
#   ('lista', 47),
#   ('golpe', 47),
#   ('rousseff', 47),
#   ('grupo', 46),
#   ('reais', 45),
#   ('justica', 45),
#   ('verdade', 45),
#   ('tribunal', 45),
#   ('militar', 45),
#   ('urgente', 45),
#   ('urnas', 45),
#   ('ano', 44),
#   ('brasileira', 44),
#   ('tres', 44),
#   ('cara', 44),
#   ('fez', 44),
#   ('presidencia', 44),
#   ('prisao', 44),
#   ('coisa', 44),
#   ('amigos', 44),
#   ('republica', 44),
#   ('quer', 43),
#   ('atencao', 43),
#   ('dois', 43),
#   ('inacio', 43),
#   ('dar', 43),
#   ('eleicao', 43),
#   ('exercito', 43),
#   ('partido', 43),
#   ('morte', 43),
#   ('favor', 42),
#   ('camara', 42),
#   ('rede', 42),
#   ('acordo', 42),
#   ('politico', 41),
#   ('pessoal', 41),
#   ('faz', 41),
#   ('cada', 41),
#   ('luiz', 41),
#   ('ninguem', 41),
#   ('ver', 41),
#   ('salario', 41),
#   ('foto', 40),
#   ('tempo', 40),
#   ('saude', 40),
#   ('chegou', 40),
#   ('volta', 39),
#   ('meio', 39),
#   ('pai', 39),
#   ('sociedade', 39),
#   ('deve', 38),
#   ('projeto', 38),
#   ('olha', 38),
#   ('acabou', 38),
#   ('petista', 38),
#   ('populacao', 38),
#   ('horas', 38),
#   ('fala', 37),
#   ('tse', 37),
#   ('momento', 37),
#   ('ontem', 37),
#   ('nesta', 37),
#   ('outro', 37),
#   ('novo', 37),
#   ('jornal', 37),
#   ('jose', 37),
#   ('historia', 36),
#   ('informacao', 36),
#   ('total', 36),
#   ('tao', 36),
#   ('operacao', 36),
#   ('dessa', 36),
#   ('primeiro', 36),
#   ('turno', 36),
#   ('melhor', 36),
#   ('reuniao', 36),
#   ('fato', 35),
#   ('mulher', 35),
#   ('senador', 35),
#   ('possivel', 35),
#   ('sim', 35),
#   ('atentado', 35),
#   ('alem', 35),
#   ('noite', 35),
#   ('nova', 34),
#   ('acabar', 34),
#   ('informacoes', 34),
#   ('direito', 34),
#   ('ministerio', 34),
#   ('general', 34),
#   ('valor', 34),
#   ('desta', 34),
#   ('hospital', 34),
#   ('noticias', 34),
#   ('deste', 33),
#   ('deixar', 33),
#   ('pouco', 32),
#   ('enquanto', 32),
#   ('democracia', 32),
#   ('maximo', 32),
#   ('site', 32),
#   ('midia', 32),
#   ('psdb', 32),
#   ('mensagem', 31),
#   ('sido', 31),
#   ('venezuela', 31),
#   ('desse', 31),
#   ('imprensa', 31),
#   ('outra', 31),
#   ('grupos', 31),
#   ('bom', 31),
#   ('crime', 31),
#   ('alguns', 31),
#   ('internet', 31),
#   ('pro', 30),
#   ('salarios', 30),
#   ('processo', 30),
#   ('faca', 30),
#   ('alguem', 30),
#   ('junto', 30),
#   ('joao', 30),
#   ('entrevista', 30),
#   ('dizendo', 30),
#   ('dentro', 30),
#   ('sistema', 30),
#   ('empresa', 30),
#   ('ficar', 30),
#   ('nego', 30),
#   ('segunda', 29),
#   ('medicos', 29),
#   ('pessoa', 29),
#   ('banco', 29),
#   ('dizer', 29),
#   ('estados', 29),
#   ('nesse', 29),
#   ('filhos', 29),
#   ('eduardo', 29),
#   ('apoio', 28),
#   ('havia', 28),
#   ('somente', 28),
#   ('aecio', 28),
#   ('texto', 28),
#   ('bomba', 28),
#   ('seguranca', 28),
#   ('escolas', 28),
#   ('querem', 28),
#   ('falar', 28),
#   ('porto', 28),
#   ('repassem', 28),
#   ('sair', 28),
#   ('acho', 28),
#   ('senado', 28),
#   ('numero', 27),
#   ('fica', 27),
#   ('acaba', 27),
#   ('saber', 27),
#   ('cidade', 27),
#   ('ideia', 27),
#   ('pmdb', 27),
#   ('decisao', 27),
#   ('causa', 27),
#   ('supremo', 27),
#   ('governador', 27),
#   ('mandou', 27),
#   ('atraves', 27),
#   ('homem', 27),
#   ('falando', 27),
#   ('caminhoneiros', 27),
#   ('forma', 27),
#   ('ensino', 27),
#   ('hora', 26),
#   ('precisa', 26),
#   ('auxilio', 26),
#   ('quanto', 26),
#   ('seguinte', 26),
#   ('paises', 26),
#   ('final', 26),
#   ('podem', 26),
#   ('nenhum', 26),
#   ('bandido', 26),
#   ('quase', 25),
#   ('social', 25),
#   ('publica', 25),
#   ('duas', 25),
#   ('deu', 25),
#   ('sempre', 25),
#   ('sul', 25),
#   ('vice', 25),
#   ('safadeza', 25),
#   ('adelio', 25),
#   ('folha', 25),
#   ('petistas', 24),
#   ('local', 24),
#   ('mal', 24),
#   ('votacao', 24),
#   ('demais', 24),
#   ('aposentadoria', 24),
#   ('mandato', 24),
#   ('civil', 24),
#   ('vem', 24),
#   ('pagar', 24),
#   ('carro', 24),
#   ('militares', 24),
#   ('feito', 24),
#   ('trabalhadores', 24),
#   ('santa', 24),
#   ('sabem', 24),
#   ('maiores', 24),
#   ('abaixo', 24),
#   ('eleitoral', 24),
#   ('trabalho', 24),
#   ('compartilhem', 24),
#   ('chega', 24),
#   ('geral', 24),
#   ('disso', 24),
#   ('existe', 24),
#   ('ditadura', 24),
#   ('bilhoes', 23),
#   ('marisa', 23),
#   ('neste', 23),
#   ('fazendo', 23),
#   ('logo', 23),
#   ('imagem', 23),
#   ('comunista', 23),
#   ('recebeu', 23),
#   ('boa', 23),
#   ('reforma', 23),
#   ('proposta', 23),
#   ('repassar', 23),
#   ('direitos', 23),
#   ('internacional', 23),
#   ('parece', 23),
#   ('vitima', 23),
#   ('movimento', 23),
#   ('fernando', 23),
#   ('cuba', 23),
#   ('epoca', 23),
#   ('compartilhe', 23),
#   ('receber', 23),
#   ('estar', 23),
#   ('urna', 23),
#   ('acontecer', 23),
#   ('demissoes', 23),
#   ('podemos', 22),
#   ('constituicao', 22),
#   ('forcas', 22),
#   ('jornalista', 22),
#   ('cargo', 22),
#   ('fizeram', 22),
#   ('sexta', 22),
#   ('partir', 22),
#   ('ganhar', 22),
#   ('grave', 22),
#   ('ultima', 22),
#   ('lugar', 22),
#   ('materia', 22),
#   ('jean', 22),
#   ('amoedo', 22),
#   ('oficial', 22),
#   ('manifestacao', 22),
#   ('porem', 22),
#   ('assessoria', 22),
#   ('planalto', 22),
#   ('ministros', 21),
#   ('corte', 21),
#   ('unica', 21),
#   ('mes', 21),
#   ('proprio', 21),
#   ('chegar', 21),
#   ('amigo', 21),
#   ('plano', 21),
#   ('facebook', 21),
#   ('frente', 21),
#   ('unidos', 21),
#   ('mostra', 21),
#   ('guerra', 21),
#   ('meses', 21),
#   ('tarde', 21),
#   ('medico', 21),
#   ('dolares', 21),
#   ('tanto', 21),
#   ('filha', 21),
#   ('delacao', 21),
#   ('intervencao', 21),
#   ('teori', 21),
#   ('tentar', 20),
#   ('dona', 20),
#   ('grandes', 20),
#   ('lado', 20),
#   ('nessa', 20),
#   ('servico', 20),
#   ('ajudar', 20),
#   ('eleito', 20),
#   ('falou', 20),
#   ('absurdo', 20),
#   ('ira', 20),
#   ('publicos', 20),
#   ('feita', 20),
#   ('maria', 20),
#   ('parana', 20),
#   ('dirceu', 20),
#   ('inclusive', 20),
#   ('pesquisa', 20),
#   ('pesquisas', 20),
#   ('bandidos', 20),
#   ('corruptos', 20),
#   ('mim', 20),
#   ('defesa', 20),
#   ('nacao', 20),
#   ('vale', 20),
#   ('alegre', 20),
#   ('cunha', 20),
#   ('passou', 19),
#   ('minimo', 19),
#   ('acima', 19),
#   ('onibus', 19),
#   ('poderia', 19),
#   ('greve', 19),
#   ('lider', 19),
#   ('carta', 19),
#   ('lulinha', 19),
#   ('fraude', 19),
#   ('membros', 19),
#   ('ciro', 19),
#   ('tirar', 19),
#   ('curitiba', 19),
#   ('prefeito', 19),
#   ('jamais', 19),
#   ('jornalismo', 19),
#   ('idade', 19),
#   ('propria', 19),
#   ('tal', 19),
#   ('poupanca', 19),
#   ('nenhuma', 19),
#   ('fonte', 19),
#   ('odebrecht', 19),
#   ('deveria', 18),
#   ('vergonha', 18),
#   ('marco', 18),
#   ('sob', 18),
#   ('comando', 18),
#   ('fazenda', 18),
#   ('terra', 18),
#   ('gostaria', 18),
#   ('pec', 18),
#   ('maio', 18),
#   ('professores', 18),
#   ('criancas', 18),
#   ('estaria', 18),
#   ('revista', 18),
#   ('pobres', 18),
#   ('manha', 18),
#   ('carlos', 18),
#   ('denuncia', 18),
#   ('defender', 18),
#   ('falsas', 18),
#   ('matar', 18),
#   ('mulheres', 18),
#   ('presidenta', 18),
#   ('alckmin', 18),
#   ('ruas', 18),
#   ('diretor', 18),
#   ('afirma', 18),
#   ('jbs', 18),
#   ('ordem', 18),
#   ('agua', 18),
#   ('mec', 18),
#   ('diario', 18),
#   ('cadeia', 17),
#   ('pedir', 17),
#   ('proximo', 17),
#   ('imagens', 17),
#   ('comecou', 17),
#   ('realmente', 17),
#   ('maioria', 17),
#   ('deixou', 17),
#   ('mesma', 17),
#   ('equipe', 17),
#   ('futuro', 17),
#   ('eleitores', 17),
#   ('boulos', 17),
#   ('comunistas', 17),
#   ('luis', 17),
#   ('empresas', 17),
#   ('muitos', 17),
#   ('pior', 17),
#   ('responsavel', 17),
#   ('passar', 17),
#   ('acontecendo', 17),
#   ('pedido', 17),
#   ('exemplo', 17),
#   ('devem', 17),
#   ('aconteceu', 17),
#   ('pede', 17),
#   ('advogado', 17),
#   ('flavio', 17),
#   ('mae', 17),
#   ('situacao', 17),
#   ('discurso', 17),
#   ('armadas', 17),
#   ('leis', 17),
#   ('investigacoes', 17),
#   ('pagina', 17),
#   ('aposentados', 17),
#   ('gilmar', 16),
#   ('afirmou', 16),
#   ('repasse', 16),
#   ('sabia', 16),
#   ('dono', 16),
#   ('cultura', 16),
#   ('provas', 16),
#   ('querendo', 16),
#   ('assunto', 16),
#   ('medo', 16),
#   ('messias', 16),
#   ('publicas', 16),
#   ('propriedade', 16),
#   ('ficou', 16),
#   ('leia', 16),
#   ('comecar', 16),
#   ('boas', 16),
#   ('irao', 16),
#   ('jovem', 16),
#   ('renato', 16),
#   ('acao', 16),
#   ('previdencia', 16),
#   ('trabalhar', 16),
#   ('domingo', 16),
#   ('parar', 16),
#   ('resultado', 16),
#   ('tipo', 16),
#   ('sei', 16),
#   ('informou', 16),
#   ('problema', 16),
#   ('mentira', 16),
#   ('alguma', 16),
#   ('direita', 16),
#   ('documento', 16),
#   ('gleisi', 16),
#   ('facada', 16),
#   ('judiciario', 16),
#   ('mst', 16),
#   ('sitio', 16),
#   ('boatos', 16),
#   ('machado', 16),
#   ('trump', 15),
#   ('mendes', 15),
#   ('ladrao', 15),
#   ('caixa', 15),
#   ('fidel', 15),
#   ('castro', 15),
#   ('motivo', 15),
#   ('comunismo', 15),
#   ('resposta', 15),
#   ('pensao', 15),
#   ('certo', 15),
#   ('emenda', 15),
#   ('outras', 15),
#   ('brasileiras', 15),
#   ('odio', 15),
#   ('relacao', 15),
#   ('posse', 15),
#   ('dama', 15),
#   ('tentou', 15),
#   ('aviao', 15),
#   ('ato', 15),
#   ('teto', 15),
#   ('rodrigo', 15),
#   ('contas', 15),
#   ('principais', 15),
#   ('ministra', 15),
#   ('minas', 15),
#   ('mudar', 15),
#   ('quero', 15),
#   ('parlamentares', 15),
#   ('veio', 15),
#   ('vivo', 15),
#   ('divulgar', 15),
#   ('psol', 15),
#   ('contatos', 15),
#   ('eletronicas', 15),
#   ('politicas', 15),
#   ('crise', 15),
#   ('caminho', 15),
#   ('falsa', 15),
#   ('homens', 15),
#   ('trata', 15),
#   ('triplex', 15),
#   ('algo', 15),
#   ('forca', 15),
#   ('passado', 15),
#   ('algumas', 15),
#   ('joesley', 15),
#   ('evento', 15),
#   ('palacio', 15),
#   ('importante', 14),
#   ('los', 14),
#   ('caiu', 14),
#   ('entender', 14),
#   ('instancia', 14),
#   ('claro', 14),
#   ('militante', 14),
#   ('sessao', 14),
#   ('dessas', 14),
#   ('universidade', 14),
#   ('terrorista', 14),
#   ('etc', 14),
#   ('merece', 14),
#   ('secretaria', 14),
#   ('organizacao', 14),
#   ('reducao', 14),
#   ('villas', 14),
#   ('campo', 14),
#   ('leticia', 14),
#   ('posso', 14),
#   ('ameaca', 14),
#   ('tentativa', 14),
#   ('trabalhador', 14),
#   ('ibope', 14),
#   ('unico', 14),
#   ('nulo', 14),
#   ('saiu', 14),
#   ('morreu', 14),
#   ('certeza', 14),
#   ('principal', 14),
#   ('foro', 14),
#   ('veiculos', 14),
#   ('livro', 14),
#   ('crimes', 14),
#   ('boca', 14),
#   ('aparece', 14),
#   ('sangue', 14),
#   ('cerca', 14),
#   ('tomar', 14),
#   ('eua', 14),
#   ('fundo', 14),
#   ('imediatamente', 14),
#   ('madrugada', 14),
#   ('apartamento', 14),
#   ('freixo', 14),
#   ('senadores', 14),
#   ('petrobras', 14),
#   ('cachorro', 14),
#   ('superior', 14),
#   ('suposto', 14),
#   ('agencia', 13),
#   ('principalmente', 13),
#   ('objetivo', 13),
#   ('milhao', 13),
#   ('surpresa', 13),
#   ('verdadeiro', 13),
#   ('policiais', 13),
#   ('comissao', 13),
#   ('falta', 13),
#   ('esquema', 13),
#   ('conseguiu', 13),
#   ('autoridades', 13),
#   ('neves', 13),
#   ('federais', 13),
#   ('culpa', 13),
#   ('cabral', 13),
#   ('assessor', 13),
#   ('comandante', 13),
#   ('chico', 13),
#   ('marcelo', 13),
#   ('socialismo', 13),
#   ('recebi', 13),
#   ('vejam', 13),
#   ('minutos', 13),
#   ('cair', 13),
#   ('manda', 13),
#   ('colocar', 13),
#   ('news', 13),
#   ('honesto', 13),
#   ('pena', 13),
#   ('gerar', 13),
#   ('levar', 13),
#   ('algum', 13),
#   ('nota', 13),
#   ('abraco', 13),
#   ('regiao', 13),
#   ('sabado', 13),
#   ('inteligencia', 13),
#   ('gomes', 13),
#   ('passada', 13),
#   ('ganhou', 13),
#   ('respeito', 13),
#   ('palavras', 13),
#   ('devido', 13),
#   ('profissionais', 13),
#   ('saida', 13),
#   ('muitas', 13),
#   ('candidatos', 13),
#   ('problemas', 13),
#   ('envolvendo', 13),
#   ('cinco', 13),
#   ('amanha', 13),
#   ('conforme', 13),
#   ('coracao', 13),
#   ('jornais', 13),
#   ('drogas', 13),
#   ('quinta', 13),
#   ('alto', 13),
#   ('muita', 13),
#   ('chefe', 13),
#   ('titulo', 13),
#   ('artigo', 13),
#   ('quarta', 13),
#   ('entendeu', 13),
#   ('doria', 13),
#   ('inicio', 13),
#   ('labrador', 13),
#   ('repassando', 12),
#   ('inss', 12),
#   ('beneficios', 12),
#   ('medidas', 12),
#   ('presos', 12),
#   ('america', 12),
#   ('leiam', 12),
#   ('popular', 12),
#   ('ficha', 12),
#   ('adianta', 12),
#   ('renan', 12),
#   ('aeroporto', 12),
#   ('quebra', 12),
#   ('puder', 12),
#   ('recado', 12),
#   ('universidades', 12),
#   ('uso', 12),
#   ('gay', 12),
#   ('instituto', 12),
#   ('abrir', 12),
#   ('curso', 12),
#   ('precisamos', 12),
#   ('quiser', 12),
#   ('precisam', 12),
#   ('compartilhar', 12),
#   ('escandalo', 12),
#   ('reserva', 12),
#   ('lideres', 12),
#   ('vitoria', 12),
#   ('interesse', 12),
#   ('perfil', 12),
#   ('pedindo', 12),
#   ('vejo', 12),
#   ('outubro', 12),
#   ('camisa', 12),
#   ('dados', 12),
#   ('maneira', 12),
#   ('morrer', 12),
#   ('campos', 12),
#   ('luta', 12),
#   ('mostrar', 12),
#   ('massa', 12),
#   ('explicar', 12),
#   ('palocci', 12),
#   ('twitter', 12),
#   ('rapido', 12),
#   ('peco', 12),
#   ('geraldo', 12),
#   ('uns', 12),
#   ('possa', 12),
#   ('apesar', 12),
#   ('passa', 12),
#   ('autor', 12),
#   ('mao', 12),
#   ('especial', 12),
#   ('cidadao', 12),
#   ('troca', 12),
#   ('proximos', 12),
#   ('rua', 12),
#   ('francisco', 12),
#   ('possibilidade', 12),
#   ('rogerio', 12),
#   ('maia', 12),
#   ('moradia', 12),
#   ('proxima', 12),
#   ('propina', 12),
#   ('farsa', 12),
#   ('frota', 12),
#   ('tira', 11),
#   ('milhares', 11),
#   ('processos', 11),
#   ('renda', 11),
#   ('diversos', 11),
#   ('fatos', 11),
#   ('restaurante', 11),
#   ('gosto', 11),
#   ('parlamentar', 11),
#   ('contrario', 11),
#   ('calheiros', 11),
#   ('conseguir', 11),
#   ('suica', 11),
#   ('pegar', 11),
#   ('china', 11),
#   ('ataque', 11),
#   ('blog', 11),
#   ('funcionarios', 11),
#   ('perto', 11),
#   ('segue', 11),
#   ('pegou', 11),
#   ('amazonas', 11),
#   ('razao', 11),
#   ('divida', 11),
#   ('vezes', 11),
#   ('cabeca', 11),
#   ('simples', 11),
#   ('retirar', 11),
#   ('falso', 11),
#   ('fazendas', 11),
#   ('debate', 11),
#   ('eleitor', 11),
#   ('gastos', 11),
#   ('senadora', 11),
#   ('vazou', 11),
#   ('psl', 11),
#   ('data', 11),
#   ('real', 11),
#   ('advogados', 11),
#   ('assassinado', 11),
#   ('sede', 11),
#   ('destino', 11),
#   ('divulgada', 11),
#   ('mandado', 11),
#   ('amor', 11),
#   ('poucos', 11),
#   ('patria', 11),
#   ('liberdade', 11),
#   ('comunicacao', 11),
#   ('recebendo', 11),
#   ('maduro', 11),
#   ('maos', 11),
#   ('divulgado', 11),
#   ('setembro', 11),
#   ('devera', 11),
#   ('roberto', 11),
#   ('assista', 11),
#   ('dizem', 11),
#   ('daquele', 11),
#   ('vota', 11),
#   ('senhor', 11),
#   ('trabalha', 11),
#   ('cola', 11),
#   ('garantir', 11),
#   ('continuar', 11),
#   ('programa', 11),
#   ('encontra', 11),
#   ('resolveu', 11),
#   ('centro', 11),
#   ('papa', 11),
#   ('propaganda', 11),
#   ('suficiente', 11),
#   ('publicada', 11),
#   ('solto', 11),
#   ('varios', 11),
#   ('juizes', 11),
#   ('embora', 11),
#   ('terca', 11),
#   ('lucia', 11),
#   ('cima', 11),
#   ('pediu', 11),
#   ('declarou', 11),
#   ('coisas', 11),
#   ('fundamental', 11),
#   ('tava', 11),
#   ('tiririca', 11),
#   ('voz', 11),
#   ('antonio', 11),
#   ('org', 11),
#   ('conhecimento', 11),
#   ('cao', 11),
#   ('mundial', 10),
#   ('economia', 10),
#   ('santo', 10),
#   ('base', 10),
#   ('batista', 10),
#   ('recebe', 10),
#   ('corrupto', 10),
#   ('chama', 10),
#   ('livre', 10),
#   ('area', 10),
#   ('link', 10),
#   ('vendo', 10),
#   ('nordeste', 10),
#   ('risco', 10),
#   ('segurancas', 10),
#   ('versao', 10),
#   ('novamente', 10),
#   ('representa', 10),
#   ('jesus', 10),
#   ('deixa', 10),
#   ('referencia', 10),
#   ('criar', 10),
#   ('entrar', 10),
#   ('onu', 10),
#   ('ultimos', 10),
#   ('questao', 10),
#   ('portanto', 10),
#   ('inteiro', 10),
#   ('periodo', 10),
#   ('manuela', 10),
#   ('armas', 10),
#   ('aceitar', 10),
#   ('gerais', 10),
#   ('totalmente', 10),
#   ('juntos', 10),
#   ('praca', 10),
#   ('poderes', 10),
#   ('piada', 10),
#   ('fazem', 10),
#   ('instituicoes', 10),
#   ('estara', 10),
#   ('sabendo', 10),
#   ('usar', 10),
#   ('voltar', 10),
#   ('espalhar', 10),
#   ('assume', 10),
#   ('ferrari', 10),
#   ('quadrilha', 10),
#   ('salvar', 10),
#   ('preciso', 10),
#   ('defende', 10),
#   ('kit', 10),
#   ('esclarecer', 10),
#   ('afastamento', 10),
#   ('visto', 10),
#   ('bolsa', 10),
#   ('sentido', 10),
#   ('dado', 10),
#   ('chamar', 10),
#   ('valores', 10),
#   ('partidos', 10),
#   ('responder', 10),
#   ('numeros', 10),
#   ('agentes', 10),
#   ('acha', 10),
#   ('passageiros', 10),
#   ('marielle', 10),
#   ('wyllys', 10),
#   ('ganha', 10),
#   ('diante', 10),
#   ('amiga', 10),
#   ('coca', 10),
#   ('entregou', 10),
#   ('criminoso', 10),
#   ('vagabundo', 10),
#   ('cut', 10),
#   ('ideologia', 10),
#   ('genero', 10),
#   ('vermelho', 10),
#   ('condicoes', 10),
#   ('acreditar', 10),
#   ('ponto', 10),
#   ('escola', 10),
#   ('assessores', 10),
#   ('capital', 10),
#   ('bolivia', 10),
#   ('marinha', 10),
#   ('aeronautica', 10),
#   ('novas', 10),
#   ('carmen', 10),
#   ('palestras', 10),
#   ('iria', 10),
#   ('habeas', 10),
#   ('gravacao', 10),
#   ('alexandre', 10),
#   ('sirio', 10),
#   ('esposa', 10),
#   ('abertura', 10),
#   ('prova', 10),
#   ('medio', 10),
#   ('zavascki', 10),
#   ('acidente', 10),
#   ('obama', 10),
#   ('estimacao', 10),
#   ('fafa', 10),
#   ('animal', 10),
#   ('arma', 9),
#   ('filiado', 9),
#   ('programas', 9),
#   ('doenca', 9),
#   ('cubanos', 9),
#   ...]}

# %%
fig, ax = plt.subplots(nrows=2, figsize=(15, 14))

n_most_common = 10

ax[0].bar([plv[0] for plv in all_cnt[0][:n_most_common]], [plv[1] for plv in all_cnt[0][:n_most_common]])
ax[0].set_title('Palavras mais comuns em textos de notícias verdadeiras', fontdict={'size': 16})
ax[0].set_ylim(0, 40000)

ax[1].bar([plv[0] for plv in all_cnt[1][:n_most_common]], [plv[1] for plv in all_cnt[1][:n_most_common]])
ax[1].set_title('Palavras mais comuns em textos de notícias falsas', fontdict={'size': 16})
ax[1].set_ylim(0, 700)

plt.subplots_adjust(hspace=0.25)

for i in range(2):
    for tick in ax[i].get_xticklabels():
        tick.set_rotation(0)
    padd = [plv[1] for plv in all_cnt[i][:n_most_common]][0] * 0.01
    for j in range(n_most_common):
        ax[i].text(j, all_cnt[i][j][1] + padd, all_cnt[i][j][1], fontsize=14, horizontalalignment="center")

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.set_ylim(-500, 25000)
# ax.set_title("Distribuição dos documentos com relação à quantidade de tokens", fontdict={'size': 16})
ax = sns.boxplot(x='FAKE', y='TEXT_LEN_CHAR', data=df)
ax.set_ylabel("Quantidade de caracteres")
ax.set_xlabel("Tipo de notícia")
ax.set_xticklabels(["Verdadeira", "Falsa"])
# Out:
# [Text(0, 0, 'Verdadeira'), Text(0, 0, 'Falsa')]

# %%
df[df['FAKE'] == 1].shape
# Out:
# (615, 12)

# %%
df_calc = df[df['FAKE'] == 1].append(df[(df['FAKE'] == 0) & (df['TEXT_LEN_TOKEN'] > 20)].sort_values('TEXT_LEN_TOKEN').reset_index(drop=True)[:len(df[df['FAKE'] == 1])]).reset_index(drop=True)

# %%
df_calc
# Out:
#             DATE                                               TEXT  \
# 0     10/12/2018  BOLSONARO Passou o Coaf Pro Moro , serão demit...
# 1     08/12/2018  Te segura aí. Trump tem 267 Bilhões pra Negoci...
# 2     09/12/2018  6 anos vendendo Avon. Chupa Natura!! Lula diz ...
# 3     12/12/2018   “Arma com número de série raspada, filiado ao...
# 4     13/12/2018   Gilmar mendes fica de costas propositadamente...
# 5     13/12/2018  *INDULTO DISFARÇADO PARA SOLTAR LULA, O MAIOR ...
# 6     21/12/2018  INSS cancela benefício de 400 mil pessoas, ido...
# 7     20/12/2018  Ministrão Marco Aurélio e satanás Fidel dono d...
# 8     16/12/2018  Aí está a resposta do porque que 200 “médicos”...
# 9     19/12/2018  O que estava sendo implantado no Brasil é o qu...
# 10    20/12/2018  BRASIL O PARAÍSO PARA OS TERRORISTAS. Aos desa...
# 11    22/12/2018  “JUSTIFICANDO O FIM DA APOSENTADORIA. “Não é j...
# 12    22/12/2018  Pessoal, estou aqui no estado do Tocantins, as...
# 13    21/11/2018  Cotrim Bolsonaro: POR ESSA O GOVERNO, NÃO ESPE...
# 14    23/12/2018  “João de Deus: Tem vinte anos de Filiação ao P...
# 15    24/12/2018  Renan Calheiros é condenado à perda do mandato...
# 16    22/11/2018   Descobriu-se que há 1 Trilhão e meio de Euros...
# 17    27/11/2018  CHINA DIZ QUE AS ÁGUAS BRASILEIRAS AGORA SÃO C...
# 18    23/11/2018  ESTAS FORAM AS CENSURAS DO JORNALISTA PEDRO BI...
# 19    20/11/2018   BOLSONARO MOSTRANDO COMO SE COMBATE A CORRUPÇ...
# 20    24/11/2018  AFINAL, AONDE ESTAVAM VCS ???????????  R E S I...
# 21    25/11/2018  PELO QUE ENTENDI, BOLSONARO CORREU RISCO DE NO...
# 22    02/12/2018  Bolsonaro acaba de ser agredido numa cafeteria...
# 23    30/11/2018  O povo do Rio de janeiro deve dar uma chance a...
# 24    01/12/2018  “Não destinaremos recursos financeiros para o ...
# 25    01/12/2018  Tem esquerdista reclamando que Bolsonaro prest...
# 26    29/11/2018  “Bolsonaro quer que Luciano Huck devolva o din...
# 27    08/12/2018  Militares treinam performance para o dia do po...
# 28    02/12/2018  Pessoal, leia isso: conheço uma pessoa na secr...
# 29    03/12/2018  “TRIPLO A” – O que é? Por que Bolsonaro foi co...
# ...          ...                                                ...
# 1200  08/01/2017  Quatro detentos foram mortos na madrugada dest...
# 1201  18/07/2016  Trata-se, porém, de espaços emblemáticos para ...
# 1202  08/06/2016  A opinião é da socióloga Fátima Pacheco Jordão...
# 1203  07/01/2017  Na semana em que o Brasil registrou duas das m...
# 1204  07/04/2018  “Lula preso amanhã.” A internet, definitivamen...
# 1205  19/09/2017  O presidente dos EUA,  Donald Trump , fez seu ...
# 1206  16/11/2016  Não era a despedida da Europa que Obama espera...
# 1207  04/07/2017  A legislação brasileira permite que qualquer p...
# 1208  09/12/2016  Nas redes sociais a imagem viralizou, e deu mu...
# 1209  30/08/2016  Dilma Rousseff  se dirigiu pela primeira vez, ...
# 1210  09/04/2017  A  greve geral contra a gestão de Mauricio Mac...
# 1211  13/04/2016  A falta de convicção do PP como partido da bas...
# 1212  22/07/2016  Por isso, quem estiver na cidade deve aproveit...
# 1213  31/10/2016  “O Rafael voltou, o Rafael voltou...”, cantava...
# 1214  10/01/2018  O delegado da PF responsável pelo caso, Rubens...
# 1215  03/10/2016  O presidente Juan Manuel Santos aceitou a derr...
# 1216  14/12/2018  O Senado dos EUA se divorciou na quinta-feira ...
# 1217  23/08/2018  Uma primeira leitura das notas técnicas revela...
# 1218  18/03/2018  Na última quinta-feira, 15, embaixo do vão do ...
# 1219  03/03/2016  Não sabemos se dois deputados ou deputadas já ...
# 1220  13/07/2016  Inicialmente o  PSOL  (cuja bancada tem seis d...
# 1221  07/08/2018  O EL PAÍS Brasil inicia nesta segunda-feira su...
# 1222  29/12/2017  O Governo brasileiro publicou nesta sexta-feir...
# 1223  09/09/2016  O ato teve concentração no Largo da Batata, me...
# 1224  26/06/2017  A euforia se instalou nas principais  empresas...
# 1225  05/01/2016  O texto é uma crítica inequívoca à tentativa d...
# 1226  19/04/2017  O  FMI registra a recuperação da economia mund...
# 1227  12/02/2017  A vitória de  Pablo Iglesias  no congresso do ...
# 1228  07/12/2016  O Senado da  Itália  aprovou a lei orçamentári...
# 1229  10/01/2018  Fire and Fury: Inside the Trump White House  (...
#
#                                                   TITLE  FAKE      SOURCE  \
# 0     \n   \t\t\tMoro vai demitir 180 petistas que g...     1  boatos.org
# 1     \n   \t\t\tTrump quer investir R$ 1 trilhão no...     1  boatos.org
# 2     \n   \t\t\tLula disse que dona Marisa ganhou R...     1  boatos.org
# 3     \n   \t\t\tAtirador de Campinas, Euler Fernand...     1  boatos.org
# 4     \n   \t\t\tGilmar Mendes vira de costas na hor...     1  boatos.org
# 5     \n   \t\t\tIndulto de Natal de Temer foi edita...     1  boatos.org
# 6     \n   \t\t\tIdosa chora ao tentar sacar BPC-Loa...     1  boatos.org
# 7     \n   \t\t\tMinistro Marco Aurélio Mello aparec...     1  boatos.org
# 8     \n   \t\t\tPrimeiros 200 médicos cubanos que f...     1  boatos.org
# 9     \n   \t\t\tProjeto Aster, de Dilma e Putin, tr...     1  boatos.org
# 10    \n   \t\t\tCesare Battisti recebia pensão de R...     1  boatos.org
# 11    \n   \t\t\tPaulo Guedes diz que não é justo qu...     1  boatos.org
# 12    \n   \t\t\tFazenda Nossa Senhora Aparecida em ...     1  boatos.org
# 13    \n   \t\t\tCotrim Bolsonaro entrega PEC de ref...     1  boatos.org
# 14    \n   \t\t\tJoão de Deus é filiado ao PT há 20 ...     1  boatos.org
# 15    \n   \t\t\tRenan Calheiros é condenado à perda...     1  boatos.org
# 16    \n   \t\t\tLula tem 1,5 trilhão de euros em co...     1  boatos.org
# 17    \n   \t\t\tChina diz que águas brasileiras são...     1  boatos.org
# 18    \n   \t\t\tPedro Bial diz que redes sociais sã...     1  boatos.org
# 19    \n   \t\t\tGustavo Perrella é nomeado como min...     1  boatos.org
# 20    \n   \t\t\tWilliam Waack endossa texto que cri...     1  boatos.org
# 21    \n   \t\t\tGrupo terrorista planejava jogar bo...     1  boatos.org
# 22    \n   \t\t\tBolsonaro acaba de ser agredido com...     1  boatos.org
# 23    \n   \t\t\tBolsonaro publicou tuíte de apoio a...     1  boatos.org
# 24    \n   \t\t\tPaulo Guedes diz que não dará dinhe...     1  boatos.org
# 25    \n   \t\t\tLula ficou de joelhos para Hugo Chá...     1  boatos.org
# 26    \n   \t\t\tBolsonaro manda Luciano Huck devolv...     1  boatos.org
# 27    \n   \t\t\tVídeo de ensaio da posse de Bolsona...     1  boatos.org
# 28    \n   \t\t\tCurso obrigatório para professores ...     1  boatos.org
# 29    \n   \t\t\tTriplo A está na pauta do Acordo de...     1  boatos.org
# ...                                                 ...   ...         ...
# 1200  Cadeia que “isolava” presos do PCC registra qu...     0     El País
# 1201  Muçulmanos conquistam ruas e praças emblemátic...     0     El País
# 1202  “Políticos jogam xadrez, enquanto o povo joga ...     0     El País
# 1203  “Tinha era que matar mais”, as declarações de ...     0     El País
# 1204                          Lula preso, memes à solta     0     El País
# 1205  Na ONU, Donald Trump ameaça “destruir totalmen...     0     El País
# 1206  Obama: “É preciso estar alerta para o aumento ...     0     El País
# 1207  A luta pelo funk no Senado: a história mais br...     0     El País
# 1208  Foto de Moro e Aécio rindo juntos eletriza as ...     0     El País
# 1209           As frases dos senadores a Dilma Rousseff     0     El País
# 1210                                 Macri, sob pressão     0     El País
# 1211  PP desembarca do Governo e enfraquece ainda ma...     0     El País
# 1212  As fotografias raras de Robert Capa na Guerra ...     0     El País
# 1213  Rafael Greca é eleito e volta à Prefeitura de ...     0     El País
# 1214  Um ano após morte de Teori Zavascki, relatório...     0     El País
# 1215  Santos: “Não me renderei, continuarei buscando...     0     El País
# 1216  Senado desafia Trump e condena herdeiro saudit...     0     El País
# 1217  Governo May prepara britânicos para um Brexit ...     0     El País
# 1218           Marielle e Monica, por todas as famílias     0     El País
# 1219  O polêmico beijo de dois deputados no Congress...     0     El País
# 1220  Erundina: “Enquanto a esquerda não se unir, a ...     0     El País
# 1221  EL PAÍS estreia novas seções fixas para cobert...     0     El País
# 1222  Temer reativa regras para fiscalizar trabalho ...     0     El País
# 1223  Manifestantes vão à casa de Temer em São Paulo...     0     El País
# 1224  Clima de “euforia” nas principais empresas alemãs     0     El País
# 1225  Brasil à Venezuela: “Não há lugar para soluçõe...     0     El País
# 1226                         Recuperação com obstáculos     0     El País
# 1227                          O Podemos se entrincheira     0     El País
# 1228  Senado italiano aprova orçamento, e Renzi prep...     0     El País
# 1229                                 A Casa Branca caiu     0     El País
#
#                                              TEXT_CLEAN  \
# 0     bolsonar pass coaf pro mor demit petist salari...
# 1     segur trump bilho pra negoc govern bolsonar im...
# 2     anos vend avon chup natura lul diz milho inven...
# 3     arm numer seri raspada fili atir indiscrimin l...
# 4     gilm mend fic cost proposit plen execu hin nac...
# 5     indult disfarc par solt lula maior ladra histo...
# 6     inss cancel benefici mil pessoas idos chor fil...
# 7     ministra marc aureli satanas fidel don cubanos...
# 8     respost porqu medicos sair dia par outro brasi...
# 9     estav send implant brasil comec ser implant ve...
# 10    brasil parais par terroristas desavis cesar ba...
# 11    justific fim aposentadoria just idos gast jove...
# 12    pessoal aqu estad tocantins margens fazend mui...
# 13    cotrim bolsonaro governo esperava projet emend...
# 14    joa deus vint anos filiaca explic silenci peti...
# 15    renan calheir conden perd mandat pel var feder...
# 16    descobriu trilha mei euros pertencent noss pai...
# 17    chin diz agu brasileir agor chines quas afund ...
# 18    censur jornal pedr bial facebook red soc perig...
# 19    bolsonar mostr combat corrupcao brasil acim tu...
# 20    afinal aond estav vcs text assin pseudonim bia...
# 21    pel entendi bolsonar corr risc nov atent cheg ...
# 22    bolsonar acab ser agred cafet rio segur estav ...
# 23    pov rio janeir dev dar chanc peza govern par d...
# 24    destin recurs financeir par carnaval par gay m...
# 25    esquerd reclam bolsonar prest continent par as...
# 26    bolsonar quer lucian huck devolv dinheir receb...
# 27    milit trein performanc par dia poss bolsonaro ...
# 28    pessoal lei conhec pesso secret educ dias tev ...
# 29    tripl bolsonar contra seman noss presidente el...
# ...                                                 ...
# 1200  quatr detent mort madrug dest doming rebelia p...
# 1201  trata porem espac emblemat par esquerd setor l...
# 1202  opinia sociolog fatim pachec jordao par sobr m...
# 1203  seman brasil registr duas maior chacin cad his...
# 1204  lul pres amanha internet definitivamente sab l...
# 1205  president eua donald trump fez primeir discurs...
# 1206  desped europ obam esperava lad primeiro minist...
# 1207  legisl brasileir permit qualqu propost consig ...
# 1208  red soc imag viralizou deu munica par aquel cr...
# 1209  dilm rousseff dirig pel primeir vez nest segun...
# 1210  grev geral contr gesta maurici macr frent arge...
# 1211  falt convicca part bas govern hav fic clar com...
# 1212  estiv cidad dev aproveitar negativos form tal ...
# 1213  rafael voltou rafael voltou cant apoiador pref...
# 1214  deleg respons pel caso rubens maleiner encontr...
# 1215  president juan manuel sant aceit derrot sim pl...
# 1216  sen eua divorc quinta feir estrateg donald tru...
# 1217  primeir leitur not tecnic revel problem soluco...
# 1218  ultim quinta feira embaix masp enquant milh pe...
# 1219  sab dois deput deput hav beij boc dependent co...
# 1220  inicial psol cuj banc seis deputados esper pod...
# 1221  pais brasil inic nest segunda feir cobertur es...
# 1222  govern brasileir public nest sexta feir nov po...
# 1223  ato tev concentr larg batata mesm local onde d...
# 1224  eufor instal princip empres alemas dev aument ...
# 1225  text critic inequivoc tentat chavism impugnar ...
# 1226  fmi registr recuper econom mundial faz grand c...
# 1227  vitor pabl igles congress pod encerr nest sab ...
# 1228  sen ital aprov lei orcamentar vot favor contr ...
# 1229  fir and fury insid the trump whit hous fog fur...
#
#                                             TITLE_CLEAN  TEXT_LEN_CHAR  \
# 0               mor vai demit petist ganh mil coaf boat            242
# 1     trump quer invest trilha brasil caus bolsonar ...            190
# 2          lul diss don maris ganh milho vend avon boat            225
# 3           atir campinas eul fern grandolpho fili boat            134
# 4     gilm mend vir cost hor hin nacional mostr vid ...            330
# 5                indult natal edit par tir lul cad boat            581
# 6     idos chor tent sac bpc cancel pel inss mostr f...            838
# 7     ministr marc aureli mell aparec fot fidel cast...            523
# 8            primeir medic cuban embor polic cuban boat            105
# 9     projet aster dilm putin trar exercit russ ufa ...            354
# 10            cesar battist receb pensa mil brasil boat            192
# 11      paul gued diz just idos gast jovens produz boat            226
# 12    fazend noss senhor aparec barroland president ...            763
# 13    cotrim bolsonar entreg pec reform congress mil...           1059
# 14                 joa deus fili anos mil mes part boat            165
# 15                renan calheir conden perd mandat boat            586
# 16                   lul trilha eur cont banc suic boat           1054
# 17    chin diz agu brasileir chines apos acord dilm ...            556
# 18    pedr bial diz red soc perig porqu pod direit boat            190
# 19      gustav perrell nom ministr esport bolsonar boat            275
# 20    will waack endoss text critic resistencia cont...            430
# 21    grup terror planej jog bomb bolsonaro mostr vi...            532
# 22    bolsonar acab ser agred tap cafet rio janeir boat            436
# 23             bolsonar public tuit apoi peza aeci boat            138
# 24    paul gued diz dar dinheir par carnaval par gay...            227
# 25    lul fic joelh par hug chavez evo morales mostr...            397
# 26    bolsonar mand lucian huck devolv milho lei rou...            778
# 27    vid ensai poss bolsonar mostr sold faz bandeir...            121
# 28    curs obrigatori par professor ensin atrapalh g...            554
# 29             tripl paut acord par cop ser brasil boat            756
# ...                                                 ...            ...
# 1200     cad isolava pres pcc registr quatr mort manaus           1437
# 1201      muculman conquist ruas prac emblemat par laic           1412
# 1202              polit jog xadrez enquant pov jog dama           1490
# 1203                        tinh mat declar seman pavor           1371
# 1204                                 lul preso mem solt           1343
# 1205      onu donald trump ameac destru total cor norte           1397
# 1206  obama precis estar alert par aument nacional e...           1395
# 1207  lut pel funk senado histor brasileir nunc contada           1420
# 1208  fot mor aeci rind junt eletriz red plen caos pais           1338
# 1209                         fras senador dilm rousseff           1459
# 1210                                   macri sob pressa           1452
# 1211           desembarc govern enfraquec aind dilm cam           1408
# 1212  fotograf rar robert cap guerr civil espanhol paul           1383
# 1213  rafael grec eleit volt prefeitur curitib apos ...           1378
# 1214  ano apos mort teor zavascki relatori parcial d...           1431
# 1215                   santos renderei continu busc paz           1371
# 1216  sen desaf trump conden herdeir saudit mort jornal           1428
# 1217          govern may prep britan par brexit drastic           1487
# 1218                           mariell monica tod famil           1424
# 1219            polem beij dois deput congress espanhol           1389
# 1220  erundina enquant esquerd unir direit ser inven...           1450
# 1221     pais estre nov seco fix par cobertur eleitoral           1476
# 1222  reativ regr par fiscaliz trabalh escravo falt ...           1480
# 1223                manifest cas paul terceir ato seman           1401
# 1224                 clim euforia princip empres alemas           1425
# 1225  brasil venezuela lug par soluco institucionali...           1587
# 1226                                   recuper obstacul           1507
# 1227                                    pod entrincheir           1463
# 1228       sen italian aprov orcamento renz prep renunc           1475
# 1229                                     cas branc caiu           1433
#
#       TEXT_LEN_TOKEN  TITLE_LEN_CHAR  TITLE_LEN_TOKEN MONTH_YEAR
# 0                 38              39                8    12/2018
# 1                 31              50                8    12/2018
# 2                 41              44                9    12/2018
# 3                 20              43                7    12/2018
# 4                 50              50               10    12/2018
# 5                 96              38                8    12/2018
# 6                130              53               11    12/2018
# 7                 80              52                9    12/2018
# 8                 18              42                7    12/2018
# 9                 59              57               10    12/2018
# 10                31              41                7    12/2018
# 11                31              47                9    12/2018
# 12               128              54                8    12/2018
# 13               160              63                9    11/2018
# 14                28              36                8    12/2018
# 15                87              37                6    12/2018
# 16               175              34                7    11/2018
# 17                91              50                9    11/2018
# 18                30              49               10    11/2018
# 19                46              47                7    11/2018
# 20                73              61                9    11/2018
# 21                80              52                9    11/2018
# 22                71              49                9    12/2018
# 23                23              40                7    11/2018
# 24                33              57               11    12/2018
# 25                60              55               11    12/2018
# 26               118              61               10    11/2018
# 27                18              58               10    12/2018
# 28                87              65                9    12/2018
# 29               113              40                8    12/2018
# ...              ...             ...              ...        ...
# 1200             216              46                8    01/2017
# 1201             216              45                7    07/2016
# 1202             216              37                7    06/2016
# 1203             216              27                5    01/2017
# 1204             216              18                4    04/2018
# 1205             216              45                8    09/2017
# 1206             216              51                8    11/2016
# 1207             216              49                8    07/2017
# 1208             217              49               10    12/2016
# 1209             217              26                4    08/2016
# 1210             217              16                3    04/2017
# 1211             217              40                6    04/2016
# 1212             217              49                8    07/2016
# 1213             217              50                8    10/2016
# 1214             217              60                9    01/2018
# 1215             217              32                5    10/2016
# 1216             217              49                8    12/2018
# 1217             218              41                7    08/2018
# 1218             218              24                4    03/2018
# 1219             218              39                6    03/2016
# 1220             218              51                7    07/2016
# 1221             218              46                8    08/2018
# 1222             218              58                9    12/2017
# 1223             219              35                6    09/2016
# 1224             219              34                5    06/2017
# 1225             219              50                6    01/2016
# 1226             219              16                2    04/2017
# 1227             220              15                2    02/2017
# 1228             220              44                7    12/2016
# 1229             220              14                3    01/2018
#
# [1230 rows x 12 columns]

# %%
all_cnt = {}
for key in tqdm_notebook(CLASS_DICT):
    cnt = Counter()
    for text in tqdm_notebook(df_calc[df_calc['FAKE'] == key]['SIMPLE_CLEAN_TEXT']):
        cnt += Counter(str(text).split())

    all_cnt[key] = cnt.most_common()
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SIMPLE_CLEAN_TEXT'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-9488d548fe8c> in <module>
#       2 for key in tqdm_notebook(CLASS_DICT):
#       3     cnt = Counter()
# ----> 4     for text in tqdm_notebook(df_calc[df_calc['FAKE'] == key]['SIMPLE_CLEAN_TEXT']):
#       5         cnt += Counter(str(text).split())
#       6
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SIMPLE_CLEAN_TEXT'

# %%
fig, ax = plt.subplots(nrows=2, figsize=(15, 14))

n_most_common = 10

ax[0].bar([plv[0] for plv in all_cnt[0][:n_most_common]], [plv[1] for plv in all_cnt[0][:n_most_common]])
ax[0].set_title('Palavras mais comuns em textos de notícias verdadeiras', fontdict={'size': 16})
ax[0].set_ylim(0, 700)

ax[1].bar([plv[0] for plv in all_cnt[1][:n_most_common]], [plv[1] for plv in all_cnt[1][:n_most_common]])
ax[1].set_title('Palavras mais comuns em textos de notícias falsas', fontdict={'size': 16})
ax[1].set_ylim(0, 700)

plt.subplots_adjust(hspace=0.25)

for i in range(2):
    for tick in ax[i].get_xticklabels():
        tick.set_rotation(0)
        tick.set_fontsize(14)
    padd = [plv[1] for plv in all_cnt[i][:n_most_common]][0] * 0.01
    for j in range(n_most_common):
        ax[i].text(j, all_cnt[i][j][1] + padd, all_cnt[i][j][1], fontsize=14, horizontalalignment="center")

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.set_ylim(-500, 5000)
# ax.set_title("Distribuição dos documentos com relação à quantidade de tokens", fontdict={'size': 16})
ax = sns.boxplot(x='FAKE', y='TEXT_LEN_CHAR', data=df_calc)
ax.set_ylabel("Quantidade de caracteres")
ax.set_xlabel("Tipo de notícia")
ax.set_xticklabels(["Verdadeira", "Falsa"])
# Out:
# [Text(0, 0, 'Verdadeira'), Text(0, 0, 'Falsa')]

# %% [markdown]
# ## Saving result dataframe

# %%
with open(PROCESSED_DATA_PATH + 'df_prime_truncated.pkl', 'wb') as f:
    pkl.dump(df_calc, f)
