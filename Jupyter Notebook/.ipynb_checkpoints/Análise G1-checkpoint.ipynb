# %%
import numpy as np
import pandas as pd
import re
import string
import nltk
import time
import collections
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from wordcloud import WordCloud

from nltk.corpus import stopwords

# %%
g1_df = pd.read_json('data/g1.json')

# %%
g1_df['text'] = [''.join(sent) for sent in g1_df['text']]

# %%
g1_df['len'] = g1_df['text'].apply(len)

# %%
n = len(g1_df)
print('before:  ', g1_df.shape)
for i, item in g1_df.iterrows():
    if pd.isnull(item['date']) or g1_df['len'] <= 500:
        g1_df.drop(i, inplace=True)
        
print('after:   ', g1_df.shape)
print('removed: ', n - len(g1_df))
# Out:
# before:   (4346, 3)
# after:    (4265, 3)
# removed:  81

# %%
def date_to_str(dt):
    return dt.date().strftime("%Y-%m-%d")

# %%
date_to_str(g1_df['date'][0])
# Out:
# '2019-01-06'

# %%
g1_df['date'] = g1_df['date'].apply(date_to_str)

# %%
g1_df.head()
# Out:
#          date                                               text  \
# 0  2019-01-06   O presidente Jair Bolsonaro afirmou neste sáb...
# 1  2019-01-06   Relator da proposta de reforma da Previdência...
# 2  2019-05-31   A Procuradoria Geral da República (PGR) encam...
# 3  2019-05-30   A votação da medida provisória que estabelece...
# 4  2019-01-06   O presidente Jair Bolsonaro (PSL) afirmou, em...
#
#                                                title   len
# 0  Bolsonaro diz que quer manter estados e municí...  2724
# 1  Relator diz que déficit previdenciário de esta...  3706
# 2  PGR dá parecer a favor de indulto para ex-diri...  1166
# 3  Senado adia para a próxima segunda-feira votaç...  5166
# 4  A jornal argentino, Bolsonaro diz que Comissão...  1725

# %%
print('Quantidade média de caracteres: {}'.format(g1_df['len'].mean()))
print('Maior quantidade de caracteres: {}'.format(g1_df['len'].max()))
print('Menor quantidade de caracteres: {} (desconsiderando os que não tem mensagem)'.format(g1_df[g1_df['len'] != 0]['len'].min()))
# Out:
# Quantidade média de caracteres: 3171.1924970691675
# Maior quantidade de caracteres: 138871
# Menor quantidade de caracteres: 11 (desconsiderando os que não tem mensagem)

# %%
dates = []
for item in g1_df['date']:
    dates.append(str(item)[:4])

    
collections.Counter(dates)
# Out:
# Counter({'2019': 819, '2018': 1475, '2017': 1837, '2016': 134})

# %%
sw = stopwords.words('portuguese')
def limpar_string(frase):
    frase = str(frase)
    frase = frase.lower()
    frase = re.sub(r'-', ' ', frase)
    frase = re.sub(r'<\w+>|\(\w+\)|[^\w\s]|\d|¹|²|³|º|ª', '', frase)
    frase = re.sub(r'\s+', ' ', frase)
    frase = frase.translate(str.maketrans('', '', string.punctuation))
    return ' '.join([word for word in frase.split() if word not in sw and len(word) > 2])

# %%
g1_df['text'] = g1_df['text'].apply(limpar_string)

# %%
collections.Counter([wrd for lst in g1_df['text'] for wrd in lst.split()]).most_common()
# Out:
# [('presidente', 12608),
#  ('federal', 7863),
#  ('ministro', 7293),
#  ('temer', 7187),
#  ('governo', 6967),
#  ('ser', 6686),
#  ('disse', 5913),
#  ('nesta', 5900),
#  ('sobre', 5762),
#  ('câmara', 5571),
#  ('afirmou', 5291),
#  ('feira', 5235),
#  ('segundo', 4589),
#  ('ainda', 4391),
#  ('tribunal', 4214),
#  ('justiça', 4120),
#  ('supremo', 3843),
#  ('ministério', 3779),
#  ('república', 3544),
#  ('deputados', 3496),
#  ('decisão', 3315),
#  ('senado', 3314),
#  ('caso', 3309),
#  ('bolsonaro', 3291),
#  ('brasil', 3267),
#  ('deputado', 3160),
#  ('após', 3117),
#  ('contra', 3112),
#  ('geral', 3076),
#  ('nacional', 2998),
#  ('acordo', 2943),
#  ('ano', 2894),
#  ('ter', 2891),
#  ('proposta', 2809),
#  ('projeto', 2727),
#  ('anos', 2719),
#  ('stf', 2707),
#  ('defesa', 2687),
#  ('público', 2682),
#  ('lei', 2631),
#  ('michel', 2612),
#  ('vai', 2530),
#  ('texto', 2526),
#  ('pode', 2501),
#  ('reforma', 2473),
#  ('quarta', 2460),
#  ('terça', 2430),
#  ('comissão', 2399),
#  ('processo', 2381),
#  ('denúncia', 2368),
#  ('segunda', 2328),
#  ('pedido', 2296),
#  ('ministros', 2287),
#  ('senador', 2204),
#  ('país', 2175),
#  ('congresso', 2150),
#  ('casa', 2140),
#  ('relator', 2095),
#  ('plenário', 2062),
#  ('maia', 2059),
#  ('desta', 2047),
#  ('pmdb', 2045),
#  ('porque', 2041),
#  ('dia', 2033),
#  ('dias', 1980),
#  ('constituição', 1978),
#  ('dois', 1938),
#  ('segurança', 1920),
#  ('prisão', 1839),
#  ('rodrigo', 1830),
#  ('durante', 1817),
#  ('polícia', 1800),
#  ('além', 1781),
#  ('pública', 1733),
#  ('diz', 1727),
#  ('estado', 1722),
#  ('votação', 1721),
#  ('presidência', 1710),
#  ('partido', 1709),
#  ('semana', 1697),
#  ('quinta', 1697),
#  ('eleitoral', 1661),
#  ('trabalho', 1660),
#  ('parte', 1654),
#  ('paulo', 1627),
#  ('nota', 1626),
#  ('desde', 1623),
#  ('todos', 1618),
#  ('ação', 1608),
#  ('jato', 1606),
#  ('lava', 1604),
#  ('recursos', 1604),
#  ('outros', 1587),
#  ('parlamentares', 1550),
#  ('planalto', 1546),
#  ('pessoas', 1531),
#  ('medida', 1529),
#  ('dinheiro', 1527),
#  ('antes', 1507),
#  ('operação', 1502),
#  ('estados', 1496),
#  ('corrupção', 1481),
#  ('lula', 1480),
#  ('mandato', 1464),
#  ('deve', 1442),
#  ('qualquer', 1435),
#  ('política', 1431),
#  ('rio', 1428),
#  ('então', 1427),
#  ('palácio', 1418),
#  ('previdência', 1416),
#  ('fazer', 1400),
#  ('votos', 1390),
#  ('julgamento', 1382),
#  ('meio', 1374),
#  ('primeira', 1365),
#  ('direito', 1347),
#  ('novo', 1339),
#  ('psdb', 1331),
#  ('havia', 1331),
#  ('janeiro', 1326),
#  ('mil', 1321),
#  ('sido', 1317),
#  ('poder', 1311),
#  ('relação', 1305),
#  ('senadores', 1300),
#  ('união', 1300),
#  ('cargo', 1300),
#  ('milhões', 1274),
#  ('sessão', 1260),
#  ('forma', 1255),
#  ('base', 1250),
#  ('parlamentar', 1246),
#  ('passado', 1240),
#  ('brasília', 1225),
#  ('crime', 1224),
#  ('fim', 1221),
#  ('três', 1218),
#  ('corte', 1214),
#  ('fachin', 1200),
#  ('grupo', 1165),
#  ('informou', 1154),
#  ('final', 1152),
#  ('delação', 1148),
#  ('dilma', 1148),
#  ('momento', 1142),
#  ('reunião', 1141),
#  ('análise', 1138),
#  ('crimes', 1136),
#  ('sexta', 1136),
#  ('partidos', 1122),
#  ('luiz', 1114),
#  ('prazo', 1102),
#  ('investigações', 1100),
#  ('campanha', 1087),
#  ('procuradoria', 1085),
#  ('nova', 1079),
#  ('inquérito', 1073),
#  ('ações', 1066),
#  ('deste', 1063),
#  ('neste', 1062),
#  ('decreto', 1060),
#  ('primeiro', 1057),
#  ('dem', 1051),
#  ('líder', 1051),
#  ('agora', 1050),
#  ('vice', 1042),
#  ('empresas', 1036),
#  ('pena', 1034),
#  ('investigação', 1033),
#  ('empresa', 1033),
#  ('juiz', 1032),
#  ('cada', 1030),
#  ('pediu', 1020),
#  ('sistema', 1019),
#  ('social', 1009),
#  ('menos', 1008),
#  ('tempo', 1007),
#  ('declarou', 1004),
#  ('relatório', 998),
#  ('jair', 992),
#  ('janot', 992),
#  ('secretaria', 986),
#  ('joesley', 985),
#  ('medidas', 977),
#  ('civil', 976),
#  ('odebrecht', 974),
#  ('conselho', 963),
#  ('procurador', 954),
#  ('abaixo', 952),
#  ('vez', 948),
#  ('outro', 944),
#  ('parecer', 943),
#  ('exemplo', 931),
#  ('duas', 929),
#  ('aprovado', 927),
#  ('maior', 924),
#  ('poderá', 916),
#  ('aécio', 911),
#  ('apenas', 910),
#  ('especial', 909),
#  ('pgr', 909),
#  ('hoje', 899),
#  ('eleito', 882),
#  ('questão', 881),
#  ('início', 876),
#  ('penal', 872),
#  ('têm', 870),
#  ('partir', 869),
#  ('instância', 866),
#  ('políticos', 866),
#  ('assim', 865),
#  ('eduardo', 865),
#  ('voto', 863),
#  ('oficial', 860),
#  ('preso', 859),
#  ('onde', 859),
#  ('regras', 849),
#  ('apoio', 849),
#  ('emenda', 840),
#  ('atual', 840),
#  ('grande', 831),
#  ('provisória', 829),
#  ('analisar', 826),
#  ('nome', 825),
#  ('art', 825),
#  ('todo', 821),
#  ('dodge', 819),
#  ('públicos', 817),
#  ('pagamento', 817),
#  ('somente', 815),
#  ('valor', 814),
#  ('informações', 811),
#  ('objetivo', 807),
#  ('disso', 805),
#  ('votar', 803),
#  ('moro', 798),
#  ('direitos', 795),
#  ('fez', 795),
#  ('entrevista', 790),
#  ('assessoria', 790),
#  ('quatro', 790),
#  ('aprovação', 789),
#  ('possível', 786),
#  ('superior', 784),
#  ('posse', 779),
#  ('advogado', 778),
#  ('casos', 778),
#  ('mendes', 777),
#  ('afirma', 774),
#  ('outras', 773),
#  ('moraes', 773),
#  ('aprovada', 772),
#  ('eleição', 771),
#  ('última', 771),
#  ('tema', 769),
#  ('favor', 763),
#  ('ccj', 759),
#  ('prevê', 755),
#  ('meses', 751),
#  ('quais', 750),
#  ('ordem', 748),
#  ('razão', 744),
#  ('silva', 744),
#  ('podem', 742),
#  ('sendo', 740),
#  ('encontro', 739),
#  ('sob', 739),
#  ('executivo', 739),
#  ('gente', 738),
#  ('filho', 738),
#  ('contas', 734),
#  ('brasileiro', 730),
#  ('político', 726),
#  ('chegou', 720),
#  ('jbs', 720),
#  ('leia', 719),
#  ('possibilidade', 717),
#  ('precisa', 716),
#  ('outra', 715),
#  ('fundo', 714),
#  ('constitucional', 713),
#  ('eleições', 712),
#  ('área', 711),
#  ('mudanças', 710),
#  ('todas', 709),
#  ('situação', 708),
#  ('integrantes', 706),
#  ('gilmar', 706),
#  ('conta', 704),
#  ('caixa', 703),
#  ('decidiu', 702),
#  ('atualmente', 702),
#  ('liberdade', 700),
#  ('eunício', 700),
#  ('feito', 696),
#  ('batista', 696),
#  ('foro', 694),
#  ('mês', 692),
#  ('brasileira', 691),
#  ('renan', 689),
#  ('porém', 685),
#  ('veja', 685),
#  ('processos', 682),
#  ('imprensa', 678),
#  ('responsável', 678),
#  ('saúde', 677),
#  ('edson', 676),
#  ('pontos', 675),
#  ('federais', 675),
#  ('documento', 674),
#  ('bilhões', 672),
#  ('condenação', 672),
#  ('cinco', 671),
#  ('ricardo', 669),
#  ('advogados', 669),
#  ('período', 668),
#  ('propina', 667),
#  ('cunha', 665),
#  ('deverá', 664),
#  ('oposição', 663),
#  ('carlos', 663),
#  ('oliveira', 661),
#  ('crise', 659),
#  ('fatos', 653),
#  ('bancada', 653),
#  ('josé', 652),
#  ('judiciário', 650),
#  ('recurso', 650),
#  ('ministra', 648),
#  ('organização', 644),
#  ('vamos', 642),
#  ('ato', 639),
#  ('economia', 638),
#  ('roberto', 638),
#  ('conforme', 637),
#  ('dentro', 636),
#  ('passada', 631),
#  ('fato', 630),
#  ('maioria', 629),
#  ('sociedade', 628),
#  ('turma', 625),
#  ('dezembro', 624),
#  ('bem', 621),
#  ('próprio', 621),
#  ('vem', 620),
#  ('nenhum', 619),
#  ('pessoa', 619),
#  ('delações', 617),
#  ('lima', 615),
#  ('maio', 614),
#  ('defendeu', 614),
#  ('candidato', 614),
#  ('alexandre', 611),
#  ('cerca', 610),
#  ('provas', 606),
#  ('dar', 604),
#  ('toffoli', 604),
#  ('diante', 604),
#  ('marco', 602),
#  ('poderia', 600),
#  ('econômica', 600),
#  ('número', 598),
#  ('deu', 598),
#  ('sempre', 598),
#  ('raquel', 597),
#  ('recebeu', 597),
#  ('regime', 596),
#  ('mdb', 593),
#  ('sérgio', 593),
#  ('mello', 592),
#  ('entanto', 590),
#  ('empresário', 590),
#  ('assunto', 589),
#  ('feita', 589),
#  ('rede', 586),
#  ('fevereiro', 585),
#  ('executivos', 584),
#  ('aqui', 581),
#  ('órgão', 581),
#  ('reportagem', 580),
#  ('prática', 580),
#  ('discussão', 576),
#  ('comando', 576),
#  ('projetos', 575),
#  ('sim', 575),
#  ('governador', 573),
#  ('barroso', 572),
#  ('alguns', 570),
#  ('programa', 568),
#  ('tse', 568),
#  ('geddel', 566),
#  ('presos', 564),
#  ('força', 560),
#  ('lúcia', 560),
#  ('rousseff', 560),
#  ('quer', 559),
#  ('dizer', 557),
#  ('época', 556),
#  ('futuro', 553),
#  ('banco', 552),
#  ('questionado', 551),
#  ('manhã', 551),
#  ('premiada', 550),
#  ('região', 548),
#  ('pauta', 547),
#  ('servidores', 544),
#  ('procuradora', 543),
#  ('autoridades', 541),
#  ('diretor', 541),
#  ('valores', 540),
#  ('devem', 537),
#  ('aprovar', 536),
#  ('depoimento', 536),
#  ('nesse', 535),
#  ('noite', 535),
#  ('cármen', 535),
#  ('distrito', 535),
#  ('uso', 533),
#  ('trata', 530),
#  ('serviços', 530),
#  ('militares', 528),
#  ('íntegra', 526),
#  ('aurélio', 526),
#  ('mudança', 525),
#  ('moreira', 524),
#  ('gabinete', 524),
#  ('avaliação', 522),
#  ('cargos', 521),
#  ('fux', 520),
#  ('família', 520),
#  ('lista', 520),
#  ('acusação', 518),
#  ('último', 517),
#  ('líderes', 516),
#  ('secretário', 516),
#  ('petrobras', 514),
#  ('faz', 514),
#  ('vídeo', 514),
#  ('exercício', 512),
#  ('militar', 511),
#  ('tipo', 511),
#  ('deixar', 509),
#  ('forças', 509),
#  ('municípios', 508),
#  ('tarde', 507),
#  ('tramitação', 507),
#  ('padilha', 506),
#  ('manter', 504),
#  ('relações', 504),
#  ('apresentar', 503),
#  ('cabe', 503),
#  ('pasta', 502),
#  ('poderão', 501),
#  ('criminosa', 501),
#  ('países', 500),
#  ('próxima', 497),
#  ('mesma', 497),
#  ('risco', 497),
#  ('brasileiros', 496),
#  ('lavagem', 494),
#  ('discurso', 494),
#  ('fernando', 492),
#  ('declaração', 491),
#  ('propostas', 491),
#  ('públicas', 490),
#  ('apresentado', 490),
#  ('data', 488),
#  ('horas', 486),
#  ('acesso', 485),
#  ('mulher', 482),
#  ('abertura', 479),
#  ('atuação', 475),
#  ('vieira', 475),
#  ('franco', 473),
#  ('enquanto', 472),
#  ('nada', 471),
#  ('vida', 471),
#  ('abril', 471),
#  ('globo', 470),
#  ('acrescentou', 469),
#  ('quanto', 468),
#  ('apresentada', 467),
#  ('atos', 467),
#  ('atividades', 467),
#  ('junho', 466),
#  ('artigo', 465),
#  ('neves', 465),
#  ('marcelo', 464),
#  ('legislação', 463),
#  ('dados', 463),
#  ('aprovou', 461),
#  ('outubro', 460),
#  ('frente', 460),
#  ('receber', 458),
#  ('condições', 457),
#  ('pedir', 457),
#  ('nenhuma', 456),
#  ('demais', 455),
#  ('depoimentos', 455),
#  ('ficou', 455),
#  ('ficar', 454),
#  ('participação', 454),
#  ('troca', 453),
#  ('necessidade', 452),
#  ('combate', 451),
#  ('delatores', 451),
#  ('setembro', 451),
#  ('determinou', 450),
#  ('condenado', 450),
#  ('função', 449),
#  ('joão', 448),
#  ('sociais', 448),
#  ('mulheres', 447),
#  ('março', 446),
#  ('últimos', 445),
#  ('rocha', 445),
#  ('chefe', 442),
#  ('negou', 441),
#  ('gestão', 440),
#  ('inclusive', 440),
#  ('respeito', 440),
#  ('acho', 440),
#  ('vão', 440),
#  ('psl', 439),
#  ('presidentes', 438),
#  ('equipe', 437),
#  ('desenvolvimento', 435),
#  ('entendimento', 434),
#  ('seis', 434),
#  ('fiscal', 434),
#  ('candidatura', 434),
#  ('ocasião', 433),
#  ('passiva', 433),
#  ('setor', 432),
#  ('tudo', 431),
#  ('passou', 431),
#  ('argumentou', 430),
#  ('vista', 430),
#  ('criação', 429),
#  ('órgãos', 429),
#  ('pec', 428),
#  ('ponto', 428),
#  ('divulgada', 428),
#  ('violência', 427),
#  ('legislativo', 427),
#  ('ética', 425),
#  ('desse', 425),
#  ('receita', 425),
#  ('conversa', 424),
#  ('sul', 422),
#  ('decidir', 420),
#  ('privilegiado', 420),
#  ('mundo', 419),
#  ('junto', 418),
#  ('trabalhista', 418),
#  ('volta', 418),
#  ('pedidos', 417),
#  ('discutir', 417),
#  ('funaro', 416),
#  ('principais', 415),
#  ('preciso', 415),
#  ('tratar', 412),
#  ('agenda', 412),
#  ('importante', 411),
#  ('educação', 409),
#  ('resultado', 409),
#  ('autorização', 408),
#  ('estar', 408),
#  ('previsão', 407),
#  ('regional', 407),
#  ('colegiado', 405),
#  ('orçamento', 405),
#  ('dessa', 404),
#  ('candidatos', 402),
#  ('regra', 398),
#  ('deputada', 396),
#  ('alvo', 395),
#  ('acusações', 395),
#  ('vezes', 393),
#  ('mínimo', 393),
#  ('intervenção', 392),
#  ('políticas', 392),
#  ('pouco', 390),
#  ('policiais', 390),
#  ('judicial', 389),
#  ('indicação', 388),
#  ('anunciou', 388),
#  ('eventual', 387),
#  ('jornalistas', 386),
#  ('lado', 386),
#  ('jucá', 386),
#  ('explicou', 384),
#  ('plano', 384),
#  ('registro', 382),
#  ('decisões', 382),
#  ('aumento', 382),
#  ('possa', 381),
#  ('execução', 381),
#  ('garantir', 381),
#  ('jornal', 381),
#  ('associação', 381),
#  ('divulgou', 380),
#  ('total', 380),
#  ('membros', 380),
#  ('liminar', 379),
#  ('mesa', 379),
#  ('presidencial', 378),
#  ('caminhoneiros', 376),
#  ('trecho', 373),
#  ('minas', 373),
#  ('armas', 372),
#  ('trf', 371),
#  ('democracia', 371),
#  ('serem', 370),
#  ('dez', 370),
#  ('destacou', 370),
#  ('própria', 369),
#  ('portanto', 368),
#  ('luís', 368),
#  ('falta', 368),
#  ('apresentou', 368),
#  ('seguinte', 366),
#  ('toda', 366),
#  ('domingo', 365),
#  ('novos', 364),
#  ('prevista', 363),
#  ('interesse', 363),
#  ('controle', 363),
#  ('chamado', 362),
#  ('instituições', 362),
#  ('investigado', 361),
#  ('lúcio', 361),
#  ('apesar', 360),
#  ('econômico', 360),
#  ('completou', 359),
#  ('armadas', 359),
#  ('tentar', 358),
#  ('melhor', 357),
#  ('agosto', 357),
#  ('principal', 356),
#  ('estaduais', 353),
#  ('esquema', 353),
#  ('inácio', 353),
#  ('informação', 352),
#  ('único', 352),
#  ('calheiros', 351),
#  ('benefício', 350),
#  ('cerimônia', 350),
#  ('serviço', 350),
#  ('evitar', 350),
#  ('marun', 350),
#  ('conteúdo', 349),
#  ('população', 349),
#  ('novas', 349),
#  ('incluído', 348),
#  ('responsabilidade', 347),
#  ('estabelece', 347),
#  ('âmbito', 347),
#  ('henrique', 346),
#  ('seguida', 344),
#  ('evento', 344),
#  ('loures', 344),
#  ('pretende', 343),
#  ('ressaltou', 343),
#  ('jurídica', 343),
#  ('julho', 343),
#  ('capital', 343),
#  ('campanhas', 342),
#  ('sábado', 341),
#  ('código', 341),
#  ('busca', 341),
#  ('autoridade', 341),
#  ('críticas', 340),
#  ('começou', 340),
#  ('réu', 340),
#  ('benefícios', 339),
#  ('norte', 339),
#  ('chapa', 339),
#  ('votou', 338),
#  ('verdade', 338),
#  ('longo', 337),
#  ('embora', 337),
#  ('procuradores', 337),
#  ('falar', 336),
#  ('governadores', 335),
#  ('redução', 335),
#  ('fica', 335),
#  ('previsto', 335),
#  ('assumir', 334),
#  ('permite', 334),
#  ('juízes', 334),
#  ('celso', 333),
#  ('atividade', 333),
#  ('costa', 333),
#  ('passar', 333),
#  ('nunca', 332),
#  ('exército', 331),
#  ('participar', 331),
#  ('pessoal', 330),
#  ('pagar', 330),
#  ('algumas', 329),
#  ('presença', 328),
#  ('administração', 328),
#  ('fazenda', 328),
#  ('peemedebista', 328),
#  ('humanos', 327),
#  ('local', 327),
#  ('operações', 327),
#  ('impeachment', 326),
#  ('psb', 325),
#  ('ministérios', 325),
#  ('próximo', 325),
#  ('reformas', 324),
#  ('novembro', 324),
#  ('feitas', 323),
#  ('concessão', 322),
#  ('aposentadoria', 321),
#  ('general', 321),
#  ('posição', 320),
#  ('deixou', 320),
#  ('onyx', 320),
#  ('poderes', 318),
#  ('vários', 318),
#  ('audiência', 317),
#  ('pede', 317),
#  ('teori', 317),
#  ('transição', 316),
#  ('acordos', 316),
#  ('caberá', 316),
#  ('levar', 316),
#  ('eliseu', 316),
#  ('comunicação', 315),
#  ('enviado', 313),
#  ('votado', 312),
#  ('trabalhadores', 312),
#  ('instituto', 311),
#  ('afastamento', 311),
#  ('abuso', 311),
#  ('assuntos', 310),
#  ('diário', 310),
#  ('obstrução', 310),
#  ('contribuição', 309),
#  ('algum', 308),
#  ('necessário', 308),
#  ('rosa', 308),
#  ('fala', 308),
#  ('agentes', 307),
#  ('gastos', 306),
#  ('unidos', 306),
#  ('matéria', 305),
#  ('vigor', 305),
#  ('intenção', 305),
#  ('termos', 305),
#  ('deveria', 304),
#  ('vou', 304),
#  ('debate', 304),
#  ('problema', 303),
#  ('nomes', 303),
#  ('multa', 302),
#  ('pesquisa', 302),
#  ('acusado', 302),
#  ('investigados', 302),
#  ('colaboração', 301),
#  ('venezuela', 301),
#  ('ninguém', 301),
#  ('cumprir', 301),
#  ('ptb', 301),
#  ('expectativa', 300),
#  ('corpus', 300),
#  ('irregularidades', 300),
#  ('salário', 300),
#  ('investigar', 299),
#  ('stj', 299),
#  ('manifestação', 299),
#  ('cumprimento', 298),
#  ('guedes', 298),
#  ('legenda', 298),
#  ('manutenção', 297),
#  ('próximos', 296),
#  ('sentido', 296),
#  ('psol', 295),
#  ('suspensão', 295),
#  ('habeas', 294),
#  ('áreas', 294),
#  ('fase', 293),
#  ('respondeu', 292),
#  ('votações', 292),
#  ('eleitorais', 292),
#  ('ambiente', 291),
#  ('hora', 291),
#  ('tanto', 290),
#  ('indícios', 290),
#  ('aberto', 290),
#  ('andamento', 290),
#  ('lewandowski', 289),
#  ('entidades', 289),
#  ('contrário', 288),
#  ('weber', 288),
#  ('considerou', 288),
#  ('marcada', 288),
#  ('denúncias', 288),
#  ('documentos', 287),
#  ('maneira', 286),
#  ('julgado', 285),
#  ('lugar', 285),
#  ('tribunais', 284),
#  ('competência', 284),
#  ('gerais', 284),
#  ('jungmann', 284),
#  ('nomeação', 283),
#  ('delator', 283),
#  ('resposta', 282),
#  ('internacional', 282),
#  ('papel', 281),
#  ('suposta', 281),
#  ('senhor', 281),
#  ('deverão', 281),
#  ('viagem', 281),
#  ('arquivamento', 281),
#  ('mourão', 281),
#  ('quase', 280),
#  ('falou', 280),
#  ('comissões', 280),
#  ('ver', 279),
#  ('suspeita', 278),
#  ('prosseguimento', 278),
#  ('antonio', 277),
#  ('coisa', 277),
#  ('desses', 277),
#  ('saiba', 277),
#  ('pagamentos', 276),
#  ('mpf', 276),
#  ('prova', 276),
#  ('compromisso', 276),
#  ('chegar', 276),
#  ('logo', 276),
#  ('ensino', 276),
#  ('exterior', 276),
#  ('pronunciamento', 276),
#  ('urgência', 275),
#  ('despesas', 275),
#  ('doações', 275),
#  ('irá', 274),
#  ('proteção', 274),
#  ('psd', 274),
#  ('idade', 274),
#  ('defender', 274),
#  ('enviada', 273),
#  ('declarações', 273),
#  ('escreveu', 273),
#  ('contudo', 272),
#  ('sigilo', 272),
#  ('escolha', 272),
#  ('saída', 271),
#  ('presídios', 271),
#  ('voltou', 270),
#  ('inquéritos', 270),
#  ('anterior', 269),
#  ('povo', 269),
#  ('condição', 268),
#  ('residência', 268),
#  ('diálogo', 267),
#  ('contratos', 267),
#  ('tentativa', 267),
#  ('aliados', 267),
#  ('cassação', 266),
#  ('publicada', 265),
#  ('questões', 265),
#  ('mercado', 265),
#  ('recebido', 265),
#  ('obras', 264),
#  ('centro', 264),
#  ('opinião', 264),
#  ('emendas', 263),
#  ('temas', 263),
#  ('investimentos', 263),
#  ('haver', 263),
#  ('edição', 262),
#  ('existe', 262),
#  ('causa', 262),
#  ('saud', 262),
#  ('rodrigues', 261),
#  ('votaram', 261),
#  ('twitter', 261),
#  ('estadual', 261),
#  ('battisti', 261),
#  ('tomada', 260),
#  ('diretamente', 260),
#  ('representantes', 260),
#  ('assessor', 259),
#  ('exteriores', 259),
#  ('dívidas', 258),
#  ('citou', 258),
#  ('assumiu', 258),
#  ('apuração', 258),
#  ('validade', 257),
#  ('acima', 257),
#  ('procedimento', 257),
#  ('cidadão', 256),
#  ('detalhes', 255),
#  ('cedo', 255),
#  ('sessões', 255),
#  ('leis', 254),
#  ('nessa', 254),
#  ('disputa', 253),
#  ('envolvendo', 253),
#  ('prestação', 252),
#  ('trabalhos', 252),
#  ('morte', 252),
#  ('participou', 252),
#  ('tomar', 252),
#  ('agência', 252),
#  ('claro', 251),
#  ('enviou', 251),
#  ('roraima', 251),
#  ('alterações', 249),
#  ('autorizou', 249),
#  ('confiança', 249),
#  ('chamada', 248),
#  ('conhecimento', 248),
#  ('preço', 247),
#  ('sete', 247),
#  ('vara', 246),
#  ('menor', 246),
#  ('minutos', 246),
#  ('publicação', 246),
#  ('magistrado', 245),
#  ('criminal', 245),
#  ('ocorreu', 244),
#  ('trabalhar', 244),
#  ('antônio', 244),
#  ('cidades', 244),
#  ('transporte', 244),
#  ('pois', 243),
#  ('iniciativa', 243),
#  ('pra', 243),
#  ('arma', 243),
#  ('boa', 243),
#  ('diversos', 243),
#  ('alguém', 243),
#  ('grave', 242),
#  ('princípio', 242),
#  ('bom', 242),
#  ('cidade', 242),
#  ('continuar', 241),
#  ('podemos', 241),
#  ('institucional', 241),
#  ('defende', 240),
#  ('drogas', 240),
#  ('empresários', 240),
#  ('redes', 239),
#  ('maria', 239),
#  ('analisado', 238),
#  ('ideia', 238),
#  ('presentes', 238),
#  ('responder', 238),
#  ('prefeito', 238),
#  ('dono', 238),
#  ('haverá', 237),
#  ('requerimento', 237),
#  ('teto', 237),
#  ('alguma', 235),
#  ('assinado', 235),
#  ('garantia', 235),
#  ('diretora', 235),
#  ('energia', 235),
#  ('apresentação', 234),
#  ('lorenzoni', 234),
#  ('contato', 233),
#  ('perda', 233),
#  ('santos', 233),
#  ('limite', 232),
#  ('principalmente', 232),
#  ('punição', 232),
#  ('financiamento', 232),
#  ('denunciado', 232),
#  ('renda', 231),
#  ('paraná', 231),
#  ('compra', 230),
#  ('recesso', 230),
#  ('turno', 230),
#  ('funções', 230),
#  ('inicialmente', 229),
#  ('seguintes', 229),
#  ('apurar', 229),
#  ('semanas', 229),
#  ('mensagem', 229),
#  ('advocacia', 228),
#  ('linha', 228),
#  ('diversas', 228),
#  ('criticou', 228),
#  ('legal', 227),
#  ('sede', 227),
#  ('imposto', 227),
#  ('homens', 227),
#  ('impedir', 226),
#  ('favorável', 226),
#  ('vale', 225),
#  ('mínima', 225),
#  ...]

# %%
data = [wrd for lst in g1_df['text'][:] for wrd in lst.split()]
wordcloud = WordCloud(
                    background_color='white',
                    max_words=200,
                    max_font_size=40, 
                    random_state=42,
                    height=400,
                    width=800
                    ).generate(' '.join(data))

print(wordcloud)
fig = plt.figure(1, dpi=600)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word2.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x000001BF8933D198>

# %%
g1_df['fake'] = 0

# %%
import pickle

pickle.dump(g1_df, open('g1_limpo.pkl', 'wb'))
