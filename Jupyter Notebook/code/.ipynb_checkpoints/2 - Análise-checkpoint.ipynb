# %%
import pickle as pkl
import seaborn as sns
import matplotlib.pyplot as plt
import re
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import math

from tqdm import tqdm_notebook
from collections import Counter
from glob import glob

# %matplotlib inline

sns.set(style="darkgrid")

# %%
PATH = '../'

PROCESSED_DATA_PATH = os.path.join(PATH, 'data/processed/')

DF_FAKE_PATH = os.path.join(PROCESSED_DATA_PATH, 'df_fake_clean.pkl')
DF_LEGIT_PATH = os.path.join(PROCESSED_DATA_PATH, 'df_legit_clean.pkl')

# %%
df_fake = pkl.load(open(DF_FAKE_PATH, 'rb'))

df_legit = pkl.load(open(DF_LEGIT_PATH, 'rb'))

# %%
df = pd.concat((df_fake, df_legit), axis=0)

# %%
classes = [True, False]

# %%
df['TEXT_LEN_CHAR'] = df['TEXT_CLEAN'].apply(len)
df['TEXT_LEN_TOKEN'] = df['TEXT_CLEAN'].apply(str.split).apply(len)
df['TITLE_LEN_CHAR'] = df['TITLE_CLEAN'].apply(len)
df['TITLE_LEN_TOKEN'] = df['TITLE_CLEAN'].apply(str.split).apply(len)

# %%
df.head()
# Out:
#          DATE  FAKE                                         TEXT_CLEAN  \
# 0  03/08/2019     1  vamos assinar peticao cassacao mandato bolsona...
# 1  04/08/2019     1  lula vitima golpe politico merece estar preso ...
# 2  05/08/2019     1  professor contou dilma matou mario kozel filho...
# 3  03/08/2019     1  vergonha presidente oab mentiu pai morto milit...
# 4  06/08/2019     1  partido diabolico bandidos abrindo buracos est...
#
#                                          TITLE_CLEAN  TEXT_LEN_CHAR  \
# 0  peticao impeachment bolsonaro precisa milhoes ...            328
# 1  peticao lula livre contribui liberdade preside...            242
# 2          mario kozel filho assassinado dilma tiros            170
# 3  felipe santa cruz presidente oab mentiu sobre ...            158
# 4  esquerda abrindo buracos estradas nordeste con...            155
#
#    TEXT_LEN_TOKEN  TITLE_LEN_CHAR  TITLE_LEN_TOKEN
# 0              36              81                9
# 1              30              54                7
# 2              24              41                6
# 3              25              82               13
# 4              19              59                7

# %%
all_cnt = {}
for key in tqdm_notebook(classes):
    cnt = Counter()
    for text in tqdm_notebook(df[df['FAKE'] == key]['TEXT_CLEAN']):
        cnt += Counter(set(str(text).split()))

    all_cnt[key] = cnt.most_common()
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1251), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=15699), HTML(value='')))

# %%
def get_from_sublist(wrd, counter):
    lst = [elem[0] for elem in counter]
    if wrd in lst:
        return True, counter[lst.index(wrd)][1]
    return False, -1

# %%
n = 10
for key1 in all_cnt:
    print('========== {} ========== '.format(key1))
    total = len(df[df['FAKE'] == key1]['TEXT_CLEAN'])
    for wrd in all_cnt[key1][:n]:
        print('{}: {}/{} ({}%)'.format(wrd[0].upper(), wrd[1], total, round(wrd[1]/total * 100, 2)))
        lst = []
        for key2 in all_cnt:
            cond, val = get_from_sublist(wrd[0], all_cnt[key2])
            if key1 != key2 and cond:
                lst.append((wrd[0], val, key2))
        for item in sorted(lst, key=lambda x: -x[1]):
            print(' - {} documentos em {}'.format(item[1], item[2]))
                
        print()
    print()
# Out:
# ========== True ==========
# BRASIL: 336/1251 (26.86%)
#  - 5444 documentos em False
#
# PRESIDENTE: 288/1251 (23.02%)
#  - 10905 documentos em False
#
# LULA: 265/1251 (21.18%)
#  - 2238 documentos em False
#
# BOLSONARO: 263/1251 (21.02%)
#  - 1890 documentos em False
#
# SER: 238/1251 (19.02%)
#  - 10878 documentos em False
#
# BOATO: 222/1251 (17.75%)
#  - 35 documentos em False
#
# VAI: 216/1251 (17.27%)
#  - 4730 documentos em False
#
# DIZ: 179/1251 (14.31%)
#  - 4655 documentos em False
#
# TODOS: 175/1251 (13.99%)
#  - 6257 documentos em False
#
# DILMA: 169/1251 (13.51%)
#  - 3083 documentos em False
#
#
# ========== False ==========
# PRESIDENTE: 10905/15699 (69.46%)
#  - 288 documentos em True
#
# SER: 10878/15699 (69.29%)
#  - 238 documentos em True
#
# SOBRE: 9934/15699 (63.28%)
#  - 151 documentos em True
#
# FEIRA: 9535/15699 (60.74%)
#  - 72 documentos em True
#
# GOVERNO: 9457/15699 (60.24%)
#  - 147 documentos em True
#
# PAIS: 9095/15699 (57.93%)
#  - 158 documentos em True
#
# SEGUNDO: 9080/15699 (57.84%)
#  - 88 documentos em True
#
# AINDA: 9060/15699 (57.71%)
#  - 116 documentos em True
#
# ANOS: 8816/15699 (56.16%)
#  - 123 documentos em True
#
# CONTRA: 8084/15699 (51.49%)
#  - 163 documentos em True

# %%
df
# Out:
#              DATE  FAKE                                         TEXT_CLEAN  \
# 0      03/08/2019     1  vamos assinar peticao cassacao mandato bolsona...
# 1      04/08/2019     1  lula vitima golpe politico merece estar preso ...
# 2      05/08/2019     1  professor contou dilma matou mario kozel filho...
# 3      03/08/2019     1  vergonha presidente oab mentiu pai morto milit...
# 4      06/08/2019     1  partido diabolico bandidos abrindo buracos est...
# 5      06/08/2019     1  entra acao stf impedir bolsonaro reduza preco ...
# 6      06/08/2019     1  filha presidente oab anos idade recebeu mil re...
# 7      08/08/2019     1  vestido medico bolsonaro brinca urologista vou...
# 8      06/08/2019     1  toffoli glenn greenwald davi miranda flagrados...
# 9      09/08/2019     1  bolsonaro michelle gastaram milhoes cartao cor...
# 10     09/08/2019     1  ministro stf alexandre moraes proibiu receita ...
# 11     11/08/2019     1  mst policia federal forca tarefa confiscam tre...
# 12     15/08/2019     1  melhor descreveu marcha insensatez alexandre g...
# 13     14/08/2019     1  generais ramos ajax salvaram governo golpe par...
# 14     16/08/2019     1  tanto falar coco jair bolsonaro imagem relacio...
# 15     19/08/2019     1  urgente filho lula pego lava jato descobre tud...
# 16     11/08/2019     1  supostos audios vazados tentando associar prim...
# 17     12/08/2019     1  bolsonaro anda faixa presidencial virou presid...
# 18     13/08/2019     1  sentem favor land rover encontrada hacker nome...
# 19     20/08/2019     1  poliamor casamento pais filhos votado dia proj...
# 20     24/07/2019     1  fernanda costa ativista ideologia genero psol ...
# 21     24/07/2019     1  urgente glenn greenwald acaba ter decretada pr...
# 22     23/07/2019     1  miriam leitao segura fuzil furadeira foto tira...
# 23     21/07/2019     1  sabia benedita silva embaixadora news york ing...
# 24     23/07/2019     1  devolvam futuro diz estudante diretor une thie...
# 25     22/07/2019     1  sabia zelia cardoso mello antes ser ministra g...
# 26     24/07/2019     1  onde hoje zurram contra bolsonaro epoca luladr...
# 27     28/07/2019     1  vamos esparramar explicando visao brasileiro m...
# 28     28/07/2019     1  advogados lula mesmos adelio hackers glenn gre...
# 29     30/07/2019     1  carlos eugenio paz diz pai felipe santa cruz o...
# ...           ...   ...                                                ...
# 15996  31/05/2019     0  mesa diretora senado comandada renan calheiros...
# 15997  31/05/2019     0  plenario supremo tribunal federal stf iniciou ...
# 15998  31/05/2019     0  presidente supremo tribunal federal stf carmen...
# 15999  31/05/2019     0  presidente senado renan calheiros pmdb decidiu...
# 16000  31/05/2019     0  camara deputados aprovou nesta terca feira pro...
# 16001  31/05/2019     0  ministro marco aurelio mello tratou ironia nes...
# 16002  31/05/2019     0  procurador geral republica rodrigo janot procu...
# 16003  31/05/2019     0  recusar noite segunda feira receber notificaca...
# 16004  31/05/2019     0  ministro marco aurelio mello supremo tribunal ...
# 16005  31/05/2019     0  presidente supremo tribunal federal stf minist...
# 16006  31/05/2019     0  forca tarefa formada procuradores operacao lav...
# 16007  31/05/2019     0  formado direito universidade federal alagoas u...
# 16008  31/05/2019     0  presidente camara deputados rodrigo maia avali...
# 16009  31/05/2019     0  confira abaixo repercussao politica ministro s...
# 16010  31/05/2019     0  alem processar punir corruptos procuradores ju...
# 16011  31/05/2019     0  ministro supremo tribunal federal stf marco au...
# 16012  31/05/2019     0  manifestacoes favor operacao lava jato contra ...
# 16013  31/05/2019     0  apos supremo tribunal federal stf tornar reu p...
# 16014  31/05/2019     0  senador roberto requiao pmdb relator defensor ...
# 16015  31/05/2019     0  presidente camara rodrigo maia dem divulgou no...
# 16016  31/05/2019     0  presidente michel temer lamentou neste domingo...
# 16017  31/05/2019     0  presidente senado renan calheiros pmdb divulgo...
# 16018  31/05/2019     0  assessoria presidente camara rodrigo maia dem ...
# 16019  31/05/2019     0  grupo senadores apresentou nesta quinta feira ...
# 16020  31/05/2019     0  presidente nacional ordem advogados brasil oab...
# 16021  31/05/2019     0  presidente senado renan calheiros pmdb divulgo...
# 16022  31/05/2019     0  governador santa catarina raimundo colombo anu...
# 16023  31/05/2019     0  presidente senado renan calheiros pmdb afirmou...
# 16024  31/05/2019     0  ministro luiz edson fachin supremo tribunal fe...
# 16025  31/05/2019     0  governo federal publicou nesta quarta feira po...
#
#                                              TITLE_CLEAN  TEXT_LEN_CHAR  \
# 0      peticao impeachment bolsonaro precisa milhoes ...            328
# 1      peticao lula livre contribui liberdade preside...            242
# 2              mario kozel filho assassinado dilma tiros            170
# 3      felipe santa cruz presidente oab mentiu sobre ...            158
# 4      esquerda abrindo buracos estradas nordeste con...            155
# 5      entra acao stf impedir bolsonaro reduza preco ...            886
# 6      filha presidente oab recebeu mil lei rouanet a...            553
# 7      bolsonaro veste medico diz urologista vou mete...            396
# 8      toffoli glenn greenwald david miranda flagrado...            391
# 9      bolsonaro michelle gastaram milhoes cartao cor...             71
# 10     walter braga netto critica decisao stf sobre r...            548
# 11     joao pedro stedile lider mst tres fazendas par...            680
# 12     alexandre garcia diz torcer contra bolsonaro t...            200
# 13     general ajax invadiu gabinete toffoli ameacou ...           2024
# 14     charlie hebdo publica charge bolsonaro fazendo...            486
# 15              lulinha pego lava jato lula surta cadeia            473
# 16     pcc divulga nota repudio apos citar ligacao fa...           1749
# 17     bolsonaro anda faixa presidencial virou presid...             56
# 18     manuela avila dona land rover encontrada hacke...            441
# 19     pcdob sugere projeto legaliza casamento pais f...            580
# 20     fernanda costa ativista ideologia genero psol ...             75
# 21     glenn greenwald prisao decretada impedido sair...            302
# 22     miriam leitao segura fuzil furadeira foto tira...             64
# 23     benedita silva embaixadora nova york eua saber...            197
# 24     thiego lula silva une anos anos curso ciencias...            556
# 25     zelia cardoso mello aloysio nunes embaixadores...            509
# 26     lula disse nordestinos ignorantes pobres compa...            299
# 27     embaixada brasil eua lula livre paredes sala m...            870
# 28     advogados lula mesmos adelio hackers glenn gre...             57
# 29     fernando santa cruz pai presidente oab morto c...            677
# ...                                                  ...            ...
# 15996  senado pede stf anule acao sobre reus linha su...           1622
# 15997  stf comeca julgar afastamento renan presidenci...           2274
# 15998  carmen diz pautara caso renan urgencia relator...           1206
# 15999  apos ser afastado comando senado renan cancela...           1397
# 16000  camara aprova projeto cria novo estatuto migracao           1343
# 16001  marco aurelio chama grotesca recusa renan cump...           2371
# 16002     manifesta preocupacao projeto abuso autoridade           1750
# 16003   antes afastamento renan cancela sessao congresso           1015
# 16004  marco aurelio mello decide levar plenario stf ...           2635
# 16005  carmen lucia reune presidentes tribunais estad...            958
# 16006  forca tarefa operacao lava jato ganha premio i...           4398
# 16007       relembre trajetoria politica renan calheiros           2188
# 16008  maia congresso precisa reunir janeiro apenas p...           2021
# 16009  saiba meio politico reagiu afastamento renan c...           4069
# 16010  juiz deve estimular virtude civica alem punir ...           1927
# 16011  ministro stf afasta renan calheiros presidenci...           6064
# 16012  manifestacoes favor lava jato reunem milhares ...          10581
# 16013  senadores citam constrangimento renan ter vira...           2203
# 16014  abuso autoridade requiao diz sugestao moro gen...           4753
# 16015  nada feito forma velada diz maia sobre pacote ...           3448
# 16016  ferreira gullar deixa vazio imenso literatura ...            594
# 16017        renan calheiros diz manifestacoes legitimas           1962
# 16018  presidencia camara diz recebe manifestacoes at...           1677
# 16019  senadores apresentam versao alternativa projet...           2442
# 16020  oab pede afastamento imediato renan presidenci...           3860
# 16021  apos virar reu renan diz provara inocencia lon...           2521
# 16022   governador anuncia temer ira chapeco nesta sexta           1131
# 16023  alvo inqueritos renan diz considera lava jato ...           1646
# 16024  relator vota tornar renan reu desvio dinheiro ...           3361
# 16025  feriados veja lista pontos facultativos feriad...            840
#
#        TEXT_LEN_TOKEN  TITLE_LEN_CHAR  TITLE_LEN_TOKEN
# 0                  36              81                9
# 1                  30              54                7
# 2                  24              41                6
# 3                  25              82               13
# 4                  19              59                7
# 5                 114              57                9
# 6                  75              62               10
# 7                  48              64                9
# 8                  49              71                8
# 9                   9              65                8
# 10                 72              73               11
# 11                 91              63                9
# 12                 28              62                9
# 13                254              79               11
# 14                 67              67                9
# 15                 68              40                7
# 16                219              50                8
# 17                  7              50                6
# 18                 59              63                9
# 19                 78              68                9
# 20                 10              69                9
# 21                 38              53                7
# 22                  9              58                8
# 23                 24              59                9
# 24                 73              54                9
# 25                 67              50                7
# 26                 38              55                7
# 27                116              60                9
# 28                  8              51                7
# 29                 90              88               12
# ...               ...             ...              ...
# 15996             208              66               10
# 15997             281              54                7
# 15998             153              54                8
# 15999             173              72                9
# 16000             167              49                7
# 16001             292              64                9
# 16002             189              46                5
# 16003             123              48                6
# 16004             340              67               10
# 16005             114              50                6
# 16006             509              53                8
# 16007             281              44                5
# 16008             244              56                7
# 16009             517              54                7
# 16010             233              76               11
# 16011             777              54                7
# 16012            1312              67                9
# 16013             287              56                8
# 16014             575              65                9
# 16015             411              59                9
# 16016              76              55                8
# 16017             244              43                5
# 16018             197              60                7
# 16019             288              70                8
# 16020             471              54                7
# 16021             314              57                9
# 16022             140              48                7
# 16023             201              53                8
# 16024             418              53                8
# 16025             104              58                7
#
# [16950 rows x 8 columns]

# %%
def get_size(cls):
    return len(df[df['FAKE'] == cls])

# %%
df_plot = df.rename(columns={"TEXT_LEN_TOKEN": "Quantidade de tokens"})
# df_plot['FAKE'] = df_plot['FAKE'].replace({0: "Noticia verdadeira", 1: "Noticia falsa"})
ax = df_plot.groupby("FAKE").boxplot(column=["Quantidade de tokens"], figsize=(15, 8), layout=(1, 2), fontsize=15)
ax[0].get_figure().suptitle('Quantidade de tokens para cada classe', fontsize=20)
ax[0].set_title("Notícia falsa", fontsize=15)
ax[1].set_title("Notícia verdadeira", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Notícia verdadeira')

# %%
fig, ax = plt.subplots(2, 1, figsize=(15, 10))
fig.subplots_adjust(top=1.4)
for i, cls in enumerate(sorted(classes, key=get_size, reverse=True)):
#     n_bins = 2 * len(set(df[df['FAKE'] == cls]['TEXT_LEN_TOKEN'].apply(lambda x: round(x / 100) * 100)))
    n_bins = 50
    x_min = math.floor(min(df[df['FAKE'] == cls]['TEXT_LEN_TOKEN']) / 100) * 100
    x_max = math.ceil(max(df[df['FAKE'] == cls]['TEXT_LEN_TOKEN']) / 100) * 100
    x_step = int(math.pow(10, math.ceil(math.log(math.floor((x_max - x_min) / 100), 10))))
    print(x_step)
    ax[i].set(xlim=(x_min, x_max))
    ax[i].hist(df[df['FAKE'] == cls]['TEXT_LEN_TOKEN'], bins=n_bins, align='mid')
    ax[i].set_xticklabels(range(x_min, x_max, x_step), rotation=90)
    
    ax[i].set_title('Tamanho do Corpus - {}'.format(cls))
    ax[i].set_xlabel('Número de tokens (por documento)');
    ax[i].set_ylabel('Número total de documentos');
# Out:
# 100
# 10

# %%
df_fake['TEXT_CLEAN'].apply(str.split).apply(len).mean()
# Out:
# 55.98800959232614

# %%
df_legit['TEXT_CLEAN'].apply(str.split).apply(len).mean()
# Out:
# 401.18689088476975

# %%
max(df_fake['TEXT_CLEAN'].apply(str.split).apply(len))
# Out:
# 575

# %%
max(df_legit['TEXT_CLEAN'].apply(str.split).apply(len))
# Out:
# 3262

# %%
from wordcloud import WordCloud

data = [wrd for lst in df_fake['TEXT_CLEAN'] for wrd in lst.split()]
wordcloud = WordCloud(
                    background_color='white',
                    max_words=50,
                    max_font_size=80, 
                    random_state=42,
                    height=400,
                    width=800
                    ).generate(' '.join(data))

print(wordcloud)
fig = plt.figure(1, dpi=200)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# fig.savefig("plots/word1.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x000001FC84C24390>

# %%
data = [wrd for lst in df_legit['TEXT_CLEAN'] for wrd in lst.split()]
wordcloud = WordCloud(
                    background_color='white',
                    max_words=50,
                    max_font_size=80, 
                    random_state=42,
                    height=400,
                    width=800
                    ).generate(' '.join(data))

print(wordcloud)
fig = plt.figure(1, dpi=200)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x000001FC847E0E48>
